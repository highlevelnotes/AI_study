# %%
import pandas as pd
import numpy as np
from scipy.stats import skew
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from math import sqrt
from sklearn.metrics import roc_auc_score
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import gc

NFOLDS = 3
SEED = 0
NROWS = None

data = pd.read_csv('./input/application_train.csv')
test = pd.read_csv('./input/application_test.csv')
prev = pd.read_csv('./input/previous_application.csv')

categorical_feats = [
    f for f in data.columns if data[f].dtype == 'object'
]

for f_ in categorical_feats:
    data[f_], indexer = pd.factorize(data[f_])
    test[f_] = indexer.get_indexer(test[f_])

gc.enable()

y_train = data['TARGET']
del data['TARGET']

prev_cat_features = [
    f_ for f_ in prev.columns if prev[f_].dtype == 'object'
]
for f_ in prev_cat_features:
    prev[f_], _ = pd.factorize(prev[f_])

avg_prev = prev.groupby('SK_ID_CURR').mean()
cnt_prev = prev[['SK_ID_CURR', 'SK_ID_PREV']].groupby('SK_ID_CURR').count()
avg_prev['nb_app'] = cnt_prev['SK_ID_PREV']
del avg_prev['SK_ID_PREV']

x_train = data.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')
x_test = test.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')

x_train = x_train.fillna(0)
x_test = x_test.fillna(0)

ntrain = x_train.shape[0]
ntest = x_test.shape[0]

excluded_feats = ['SK_ID_CURR']
features = [f_ for f_ in x_train.columns if f_ not in excluded_feats]

x_train = x_train[features]
x_test = x_test[features]

kf = KFold(n_splits=NFOLDS, shuffle=True, random_state=SEED)

class SklearnWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)
    
    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)
    
    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]

class CatboostWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_seed'] = seed
        self.clf = clf(**params)
    
    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)
    
    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]

class LightGBMWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['feature_fraction_seed'] = seed
        params['bagging_seed'] = seed
        self.clf = clf(**params)
    
    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)
    
    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]

class XgbWrapper(object):
    def __init__(self, seed=0, params=None):
        self.param = params
        self.param['seed'] = seed
        self.nrounds = params.pop('nrounds', 250)
    
    def train(self, x_train, y_train):
        dtrain = xgb.DMatrix(x_train, label=y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)
    
    def predict(self, x):
        return self.gbdt.predict(xgb.DMatrix(x))

def get_oof(clf):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest))

    for i, (train_index, test_index) in enumerate(kf.split(x_train)):
        x_tr = x_train.loc[train_index]
        y_tr = y_train.loc[train_index]
        x_te = x_train.loc[test_index]

        clf.train(x_tr, y_tr)

        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i, :] = clf.predict(x_test)
    
    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)

et_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.5,
    'max_depth': 12,
    'min_samples_leaf': 2
}

rf_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.2,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

xgb_params = {
    'seed': 0,
    'colsample_bytree': 0.7,
    'silent': 1,
    'subsample': 0.7,
    'learning_rate': 0.075,
    'objective': 'binary:logistic',
    'max_depth': 4,
    'num_parallel_tree': 1,
    'min_child_weight': 1,
    'nrounds': 200
}

catboost_params = {
    'iterations': 200,
    'learning_rate': 0.5,
    'depth': 3,
    'l2_leaf_reg': 40,
    'bootstrap_type': 'Bernoulli',
    'subsample': 0.7,
    'scale_pos_weight': 5,
    'eval_metric': 'AUC',
    'od_type': 'Iter',
    'allow_writing_files': False
}

lightgbm_params = {
    'n_estimators': 200,
    'learning_rate': 0.1,
    'num_leaves': 123,
    'colsample_bytree': 0.8,
    'subsample': 0.9,
    'max_depth': 15,
    'reg_alpha': 0.1,
    'reg_lambda': 0.1,
    'min_split_gain': 0.01,
    'min_child_weight': 2
}

xg = XgbWrapper(seed=SEED, params=xgb_params)
et = SklearnWrapper(clf=ExtraTreesClassifier, seed=SEED, params=et_params)
rf = SklearnWrapper(clf=RandomForestClassifier, seed=SEED, params=rf_params)
cb = CatboostWrapper(clf=CatBoostClassifier, seed=SEED, params=catboost_params)
lg = LightGBMWrapper(clf=LGBMClassifier, seed=SEED, params=lightgbm_params)

xg_oof_train, xg_oof_test = get_oof(xg)
et_oof_train, et_oof_test = get_oof(et)
rf_oof_train, rf_oof_test = get_oof(rf)
cb_oof_train, cb_oof_test = get_oof(cb)

print('XG-CV: {}'.format(sqrt(mean_squared_error(y_train, xg_oof_train))))
print('ET-CV: {}'.format(sqrt(mean_squared_error(y_train, et_oof_train))))
print('RF-CV: {}'.format(sqrt(mean_squared_error(y_train, rf_oof_train))))
print('RF-CV: {}'.format(sqrt(mean_squared_error(y_train, cb_oof_train))))

x_train = np.concatenate((xg_oof_train, et_oof_train, rf_oof_train, cb_oof_train), axis=1)
x_test = np.concatenate((xg_oof_test, et_oof_test, rf_oof_test, cb_oof_test), axis=1)

print('{}, {}'.format(x_train.shape, x_test.shape))

logistic_regression = LogisticRegression()
logistic_regression.fit(x_train, y_train)

test['TARGET'] = logistic_regression.predict_proba(x_test)[:,1]

test[['SK_ID_CURR', 'TARGET']].to_csv('first_submission.csv', index=False, float_format='%.8f')
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:200: UserWarning: [23:26:15] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:200: UserWarning: [23:26:25] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:200: UserWarning: [23:26:34] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "silent" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 0:	total: 198ms	remaining: 39.4s
# 1:	total: 253ms	remaining: 25s
# 2:	total: 296ms	remaining: 19.5s
# 3:	total: 331ms	remaining: 16.2s
# 4:	total: 374ms	remaining: 14.6s
# 5:	total: 414ms	remaining: 13.4s
# 6:	total: 455ms	remaining: 12.5s
# 7:	total: 491ms	remaining: 11.8s
# 8:	total: 530ms	remaining: 11.3s
# 9:	total: 567ms	remaining: 10.8s
# 10:	total: 605ms	remaining: 10.4s
# 11:	total: 649ms	remaining: 10.2s
# 12:	total: 694ms	remaining: 9.98s
# 13:	total: 734ms	remaining: 9.75s
# 14:	total: 775ms	remaining: 9.56s
# 15:	total: 818ms	remaining: 9.4s
# 16:	total: 857ms	remaining: 9.22s
# 17:	total: 893ms	remaining: 9.02s
# 18:	total: 929ms	remaining: 8.85s
# 19:	total: 962ms	remaining: 8.66s
# 20:	total: 1s	remaining: 8.55s
# 21:	total: 1.04s	remaining: 8.43s
# 22:	total: 1.08s	remaining: 8.35s
# 23:	total: 1.14s	remaining: 8.36s
# 24:	total: 1.19s	remaining: 8.36s
# 25:	total: 1.24s	remaining: 8.28s
# 26:	total: 1.27s	remaining: 8.15s
# 27:	total: 1.31s	remaining: 8.03s
# 28:	total: 1.34s	remaining: 7.91s
# 29:	total: 1.38s	remaining: 7.83s
# 30:	total: 1.43s	remaining: 7.77s
# 31:	total: 1.47s	remaining: 7.7s
# 32:	total: 1.5s	remaining: 7.61s
# 33:	total: 1.54s	remaining: 7.54s
# 34:	total: 1.59s	remaining: 7.5s
# 35:	total: 1.63s	remaining: 7.43s
# 36:	total: 1.67s	remaining: 7.35s
# 37:	total: 1.71s	remaining: 7.28s
# 38:	total: 1.74s	remaining: 7.2s
# 39:	total: 1.78s	remaining: 7.13s
# 40:	total: 1.82s	remaining: 7.07s
# 41:	total: 1.86s	remaining: 7s
# 42:	total: 1.9s	remaining: 6.95s
# 43:	total: 1.94s	remaining: 6.88s
# 44:	total: 1.98s	remaining: 6.83s
# 45:	total: 2.03s	remaining: 6.79s
# 46:	total: 2.07s	remaining: 6.74s
# 47:	total: 2.11s	remaining: 6.69s
# 48:	total: 2.15s	remaining: 6.63s
# 49:	total: 2.19s	remaining: 6.58s
# 50:	total: 2.25s	remaining: 6.59s
# 51:	total: 2.3s	remaining: 6.54s
# 52:	total: 2.33s	remaining: 6.47s
# 53:	total: 2.37s	remaining: 6.41s
# 54:	total: 2.41s	remaining: 6.36s
# 55:	total: 2.45s	remaining: 6.31s
# 56:	total: 2.49s	remaining: 6.25s
# 57:	total: 2.53s	remaining: 6.19s
# 58:	total: 2.56s	remaining: 6.13s
# 59:	total: 2.6s	remaining: 6.07s
# 60:	total: 2.65s	remaining: 6.04s
# 61:	total: 2.69s	remaining: 5.98s
# 62:	total: 2.73s	remaining: 5.93s
# 63:	total: 2.78s	remaining: 5.9s
# 64:	total: 2.81s	remaining: 5.84s
# 65:	total: 2.85s	remaining: 5.79s
# 66:	total: 2.89s	remaining: 5.73s
# 67:	total: 2.92s	remaining: 5.68s
# 68:	total: 2.96s	remaining: 5.63s
# 69:	total: 3s	remaining: 5.58s
# 70:	total: 3.04s	remaining: 5.53s
# 71:	total: 3.09s	remaining: 5.49s
# 72:	total: 3.13s	remaining: 5.45s
# 73:	total: 3.17s	remaining: 5.39s
# 74:	total: 3.21s	remaining: 5.34s
# 75:	total: 3.24s	remaining: 5.29s
# 76:	total: 3.28s	remaining: 5.24s
# 77:	total: 3.32s	remaining: 5.2s
# 78:	total: 3.36s	remaining: 5.15s
# 79:	total: 3.41s	remaining: 5.11s
# 80:	total: 3.44s	remaining: 5.06s
# 81:	total: 3.48s	remaining: 5.01s
# 82:	total: 3.52s	remaining: 4.97s
# 83:	total: 3.57s	remaining: 4.93s
# 84:	total: 3.62s	remaining: 4.9s
# 85:	total: 3.69s	remaining: 4.89s
# 86:	total: 3.73s	remaining: 4.84s
# 87:	total: 3.77s	remaining: 4.79s
# 88:	total: 3.81s	remaining: 4.75s
# 89:	total: 3.85s	remaining: 4.71s
# 90:	total: 3.89s	remaining: 4.66s
# 91:	total: 3.92s	remaining: 4.61s
# 92:	total: 3.97s	remaining: 4.57s
# 93:	total: 4.01s	remaining: 4.52s
# 94:	total: 4.05s	remaining: 4.47s
# 95:	total: 4.08s	remaining: 4.43s
# 96:	total: 4.12s	remaining: 4.38s
# 97:	total: 4.16s	remaining: 4.33s
# 98:	total: 4.2s	remaining: 4.29s
# 99:	total: 4.24s	remaining: 4.24s
# 100:	total: 4.27s	remaining: 4.19s
# 101:	total: 4.31s	remaining: 4.14s
# 102:	total: 4.34s	remaining: 4.09s
# 103:	total: 4.38s	remaining: 4.05s
# 104:	total: 4.43s	remaining: 4.01s
# 105:	total: 4.47s	remaining: 3.96s
# 106:	total: 4.51s	remaining: 3.92s
# 107:	total: 4.55s	remaining: 3.88s
# 108:	total: 4.59s	remaining: 3.83s
# 109:	total: 4.63s	remaining: 3.79s
# 110:	total: 4.67s	remaining: 3.75s
# 111:	total: 4.72s	remaining: 3.71s
# 112:	total: 4.76s	remaining: 3.66s
# 113:	total: 4.8s	remaining: 3.62s
# 114:	total: 4.85s	remaining: 3.59s
# 115:	total: 4.9s	remaining: 3.55s
# 116:	total: 4.94s	remaining: 3.51s
# 117:	total: 4.98s	remaining: 3.46s
# 118:	total: 5.02s	remaining: 3.42s
# 119:	total: 5.06s	remaining: 3.37s
# 120:	total: 5.1s	remaining: 3.33s
# 121:	total: 5.14s	remaining: 3.29s
# 122:	total: 5.19s	remaining: 3.25s
# 123:	total: 5.23s	remaining: 3.2s
# 124:	total: 5.27s	remaining: 3.16s
# 125:	total: 5.31s	remaining: 3.12s
# 126:	total: 5.35s	remaining: 3.07s
# 127:	total: 5.39s	remaining: 3.03s
# 128:	total: 5.43s	remaining: 2.99s
# 129:	total: 5.47s	remaining: 2.94s
# 130:	total: 5.51s	remaining: 2.9s
# 131:	total: 5.55s	remaining: 2.86s
# 132:	total: 5.59s	remaining: 2.81s
# 133:	total: 5.63s	remaining: 2.77s
# 134:	total: 5.66s	remaining: 2.73s
# 135:	total: 5.71s	remaining: 2.69s
# 136:	total: 5.75s	remaining: 2.64s
# 137:	total: 5.79s	remaining: 2.6s
# 138:	total: 5.83s	remaining: 2.56s
# 139:	total: 5.87s	remaining: 2.52s
# 140:	total: 5.91s	remaining: 2.47s
# 141:	total: 5.95s	remaining: 2.43s
# 142:	total: 6.01s	remaining: 2.39s
# 143:	total: 6.05s	remaining: 2.35s
# 144:	total: 6.09s	remaining: 2.31s
# 145:	total: 6.13s	remaining: 2.27s
# 146:	total: 6.17s	remaining: 2.23s
# 147:	total: 6.22s	remaining: 2.18s
# 148:	total: 6.25s	remaining: 2.14s
# 149:	total: 6.29s	remaining: 2.1s
# 150:	total: 6.33s	remaining: 2.06s
# 151:	total: 6.37s	remaining: 2.01s
# 152:	total: 6.42s	remaining: 1.97s
# 153:	total: 6.46s	remaining: 1.93s
# 154:	total: 6.5s	remaining: 1.89s
# 155:	total: 6.54s	remaining: 1.84s
# 156:	total: 6.58s	remaining: 1.8s
# 157:	total: 6.63s	remaining: 1.76s
# 158:	total: 6.67s	remaining: 1.72s
# 159:	total: 6.71s	remaining: 1.68s
# 160:	total: 6.76s	remaining: 1.64s
# 161:	total: 6.8s	remaining: 1.59s
# 162:	total: 6.84s	remaining: 1.55s
# 163:	total: 6.88s	remaining: 1.51s
# 164:	total: 6.92s	remaining: 1.47s
# 165:	total: 6.96s	remaining: 1.43s
# 166:	total: 7.01s	remaining: 1.38s
# 167:	total: 7.04s	remaining: 1.34s
# 168:	total: 7.08s	remaining: 1.3s
# 169:	total: 7.14s	remaining: 1.26s
# 170:	total: 7.18s	remaining: 1.22s
# 171:	total: 7.23s	remaining: 1.18s
# 172:	total: 7.27s	remaining: 1.13s
# 173:	total: 7.32s	remaining: 1.09s
# 174:	total: 7.36s	remaining: 1.05s
# 175:	total: 7.4s	remaining: 1.01s
# 176:	total: 7.44s	remaining: 966ms
# 177:	total: 7.47s	remaining: 924ms
# 178:	total: 7.51s	remaining: 882ms
# 179:	total: 7.55s	remaining: 839ms
# 180:	total: 7.59s	remaining: 797ms
# 181:	total: 7.63s	remaining: 755ms
# 182:	total: 7.67s	remaining: 712ms
# 183:	total: 7.71s	remaining: 670ms
# 184:	total: 7.75s	remaining: 629ms
# 185:	total: 7.79s	remaining: 586ms
# 186:	total: 7.83s	remaining: 544ms
# 187:	total: 7.87s	remaining: 502ms
# 188:	total: 7.91s	remaining: 460ms
# 189:	total: 7.95s	remaining: 418ms
# 190:	total: 7.99s	remaining: 377ms
# 191:	total: 8.03s	remaining: 335ms
# 192:	total: 8.08s	remaining: 293ms
# 193:	total: 8.12s	remaining: 251ms
# 194:	total: 8.16s	remaining: 209ms
# 195:	total: 8.23s	remaining: 168ms
# 196:	total: 8.27s	remaining: 126ms
# 197:	total: 8.31s	remaining: 83.9ms
# 198:	total: 8.34s	remaining: 41.9ms
# 199:	total: 8.38s	remaining: 0us
# 0:	total: 49.6ms	remaining: 9.88s
# 1:	total: 94.3ms	remaining: 9.34s
# 2:	total: 133ms	remaining: 8.72s
# 3:	total: 182ms	remaining: 8.9s
# 4:	total: 228ms	remaining: 8.89s
# 5:	total: 307ms	remaining: 9.94s
# 6:	total: 350ms	remaining: 9.66s
# 7:	total: 389ms	remaining: 9.34s
# 8:	total: 426ms	remaining: 9.04s
# 9:	total: 462ms	remaining: 8.78s
# 10:	total: 499ms	remaining: 8.58s
# 11:	total: 544ms	remaining: 8.53s
# 12:	total: 587ms	remaining: 8.44s
# 13:	total: 633ms	remaining: 8.41s
# 14:	total: 675ms	remaining: 8.32s
# 15:	total: 718ms	remaining: 8.26s
# 16:	total: 759ms	remaining: 8.16s
# 17:	total: 798ms	remaining: 8.07s
# 18:	total: 840ms	remaining: 8.01s
# 19:	total: 881ms	remaining: 7.93s
# 20:	total: 921ms	remaining: 7.85s
# 21:	total: 962ms	remaining: 7.78s
# 22:	total: 1.01s	remaining: 7.76s
# 23:	total: 1.05s	remaining: 7.7s
# 24:	total: 1.09s	remaining: 7.64s
# 25:	total: 1.13s	remaining: 7.53s
# 26:	total: 1.16s	remaining: 7.46s
# 27:	total: 1.2s	remaining: 7.38s
# 28:	total: 1.24s	remaining: 7.3s
# 29:	total: 1.28s	remaining: 7.25s
# 30:	total: 1.32s	remaining: 7.18s
# 31:	total: 1.36s	remaining: 7.15s
# 32:	total: 1.41s	remaining: 7.12s
# 33:	total: 1.45s	remaining: 7.07s
# 34:	total: 1.5s	remaining: 7.08s
# 35:	total: 1.54s	remaining: 7.03s
# 36:	total: 1.58s	remaining: 6.96s
# 37:	total: 1.62s	remaining: 6.9s
# 38:	total: 1.66s	remaining: 6.83s
# 39:	total: 1.7s	remaining: 6.78s
# 40:	total: 1.73s	remaining: 6.73s
# 41:	total: 1.77s	remaining: 6.66s
# 42:	total: 1.81s	remaining: 6.61s
# 43:	total: 1.85s	remaining: 6.55s
# 44:	total: 1.88s	remaining: 6.49s
# 45:	total: 1.92s	remaining: 6.44s
# 46:	total: 1.96s	remaining: 6.39s
# 47:	total: 2.01s	remaining: 6.36s
# 48:	total: 2.04s	remaining: 6.3s
# 49:	total: 2.08s	remaining: 6.26s
# 50:	total: 2.13s	remaining: 6.23s
# 51:	total: 2.17s	remaining: 6.18s
# 52:	total: 2.21s	remaining: 6.14s
# 53:	total: 2.25s	remaining: 6.08s
# 54:	total: 2.29s	remaining: 6.04s
# 55:	total: 2.34s	remaining: 6.02s
# 56:	total: 2.39s	remaining: 5.99s
# 57:	total: 2.43s	remaining: 5.94s
# 58:	total: 2.47s	remaining: 5.89s
# 59:	total: 2.5s	remaining: 5.84s
# 60:	total: 2.54s	remaining: 5.78s
# 61:	total: 2.58s	remaining: 5.75s
# 62:	total: 2.62s	remaining: 5.7s
# 63:	total: 2.67s	remaining: 5.67s
# 64:	total: 2.72s	remaining: 5.65s
# 65:	total: 2.76s	remaining: 5.61s
# 66:	total: 2.8s	remaining: 5.56s
# 67:	total: 2.84s	remaining: 5.51s
# 68:	total: 2.88s	remaining: 5.46s
# 69:	total: 2.92s	remaining: 5.42s
# 70:	total: 2.96s	remaining: 5.38s
# 71:	total: 3s	remaining: 5.33s
# 72:	total: 3.04s	remaining: 5.29s
# 73:	total: 3.09s	remaining: 5.26s
# 74:	total: 3.13s	remaining: 5.22s
# 75:	total: 3.17s	remaining: 5.17s
# 76:	total: 3.21s	remaining: 5.12s
# 77:	total: 3.25s	remaining: 5.08s
# 78:	total: 3.29s	remaining: 5.04s
# 79:	total: 3.33s	remaining: 5s
# 80:	total: 3.37s	remaining: 4.96s
# 81:	total: 3.41s	remaining: 4.91s
# 82:	total: 3.46s	remaining: 4.87s
# 83:	total: 3.5s	remaining: 4.83s
# 84:	total: 3.53s	remaining: 4.78s
# 85:	total: 3.57s	remaining: 4.74s
# 86:	total: 3.61s	remaining: 4.69s
# 87:	total: 3.65s	remaining: 4.64s
# 88:	total: 3.68s	remaining: 4.59s
# 89:	total: 3.72s	remaining: 4.55s
# 90:	total: 3.76s	remaining: 4.51s
# 91:	total: 3.81s	remaining: 4.47s
# 92:	total: 3.86s	remaining: 4.44s
# 93:	total: 3.9s	remaining: 4.39s
# 94:	total: 3.94s	remaining: 4.35s
# 95:	total: 3.98s	remaining: 4.31s
# 96:	total: 4.01s	remaining: 4.26s
# 97:	total: 4.06s	remaining: 4.22s
# 98:	total: 4.09s	remaining: 4.17s
# 99:	total: 4.13s	remaining: 4.13s
# 100:	total: 4.17s	remaining: 4.09s
# 101:	total: 4.22s	remaining: 4.05s
# 102:	total: 4.25s	remaining: 4s
# 103:	total: 4.29s	remaining: 3.96s
# 104:	total: 4.33s	remaining: 3.92s
# 105:	total: 4.38s	remaining: 3.88s
# 106:	total: 4.41s	remaining: 3.84s
# 107:	total: 4.45s	remaining: 3.79s
# 108:	total: 4.49s	remaining: 3.75s
# 109:	total: 4.53s	remaining: 3.71s
# 110:	total: 4.57s	remaining: 3.66s
# 111:	total: 4.6s	remaining: 3.62s
# 112:	total: 4.64s	remaining: 3.57s
# 113:	total: 4.67s	remaining: 3.52s
# 114:	total: 4.71s	remaining: 3.48s
# 115:	total: 4.75s	remaining: 3.44s
# 116:	total: 4.79s	remaining: 3.39s
# 117:	total: 4.82s	remaining: 3.35s
# 118:	total: 4.86s	remaining: 3.31s
# 119:	total: 4.9s	remaining: 3.27s
# 120:	total: 4.95s	remaining: 3.23s
# 121:	total: 4.99s	remaining: 3.19s
# 122:	total: 5.03s	remaining: 3.15s
# 123:	total: 5.07s	remaining: 3.11s
# 124:	total: 5.11s	remaining: 3.07s
# 125:	total: 5.15s	remaining: 3.03s
# 126:	total: 5.19s	remaining: 2.98s
# 127:	total: 5.23s	remaining: 2.94s
# 128:	total: 5.28s	remaining: 2.91s
# 129:	total: 5.33s	remaining: 2.87s
# 130:	total: 5.37s	remaining: 2.83s
# 131:	total: 5.41s	remaining: 2.79s
# 132:	total: 5.45s	remaining: 2.75s
# 133:	total: 5.49s	remaining: 2.71s
# 134:	total: 5.53s	remaining: 2.66s
# 135:	total: 5.58s	remaining: 2.63s
# 136:	total: 5.62s	remaining: 2.59s
# 137:	total: 5.66s	remaining: 2.54s
# 138:	total: 5.7s	remaining: 2.5s
# 139:	total: 5.74s	remaining: 2.46s
# 140:	total: 5.78s	remaining: 2.42s
# 141:	total: 5.82s	remaining: 2.38s
# 142:	total: 5.86s	remaining: 2.33s
# 143:	total: 5.89s	remaining: 2.29s
# 144:	total: 5.94s	remaining: 2.25s
# 145:	total: 5.98s	remaining: 2.21s
# 146:	total: 6.01s	remaining: 2.17s
# 147:	total: 6.05s	remaining: 2.13s
# 148:	total: 6.09s	remaining: 2.08s
# 149:	total: 6.13s	remaining: 2.04s
# 150:	total: 6.17s	remaining: 2s
# 151:	total: 6.21s	remaining: 1.96s
# 152:	total: 6.26s	remaining: 1.92s
# 153:	total: 6.33s	remaining: 1.89s
# 154:	total: 6.37s	remaining: 1.85s
# 155:	total: 6.41s	remaining: 1.81s
# 156:	total: 6.45s	remaining: 1.76s
# 157:	total: 6.49s	remaining: 1.72s
# 158:	total: 6.52s	remaining: 1.68s
# 159:	total: 6.56s	remaining: 1.64s
# 160:	total: 6.6s	remaining: 1.6s
# 161:	total: 6.64s	remaining: 1.56s
# 162:	total: 6.67s	remaining: 1.51s
# 163:	total: 6.71s	remaining: 1.47s
# 164:	total: 6.76s	remaining: 1.43s
# 165:	total: 6.8s	remaining: 1.39s
# 166:	total: 6.84s	remaining: 1.35s
# 167:	total: 6.89s	remaining: 1.31s
# 168:	total: 6.93s	remaining: 1.27s
# 169:	total: 6.97s	remaining: 1.23s
# 170:	total: 7.01s	remaining: 1.19s
# 171:	total: 7.05s	remaining: 1.15s
# 172:	total: 7.08s	remaining: 1.1s
# 173:	total: 7.12s	remaining: 1.06s
# 174:	total: 7.16s	remaining: 1.02s
# 175:	total: 7.2s	remaining: 982ms
# 176:	total: 7.24s	remaining: 941ms
# 177:	total: 7.29s	remaining: 901ms
# 178:	total: 7.33s	remaining: 860ms
# 179:	total: 7.38s	remaining: 820ms
# 180:	total: 7.42s	remaining: 779ms
# 181:	total: 7.46s	remaining: 738ms
# 182:	total: 7.5s	remaining: 697ms
# 183:	total: 7.54s	remaining: 655ms
# 184:	total: 7.58s	remaining: 615ms
# 185:	total: 7.62s	remaining: 573ms
# 186:	total: 7.66s	remaining: 532ms
# 187:	total: 7.71s	remaining: 492ms
# 188:	total: 7.75s	remaining: 451ms
# 189:	total: 7.79s	remaining: 410ms
# 190:	total: 7.83s	remaining: 369ms
# 191:	total: 7.87s	remaining: 328ms
# 192:	total: 7.91s	remaining: 287ms
# 193:	total: 7.95s	remaining: 246ms
# 194:	total: 7.99s	remaining: 205ms
# 195:	total: 8.03s	remaining: 164ms
# 196:	total: 8.07s	remaining: 123ms
# 197:	total: 8.11s	remaining: 81.9ms
# 198:	total: 8.15s	remaining: 40.9ms
# 199:	total: 8.19s	remaining: 0us
# 0:	total: 52ms	remaining: 10.4s
# 1:	total: 95.7ms	remaining: 9.47s
# 2:	total: 136ms	remaining: 8.91s
# 3:	total: 177ms	remaining: 8.67s
# 4:	total: 218ms	remaining: 8.48s
# 5:	total: 261ms	remaining: 8.42s
# 6:	total: 299ms	remaining: 8.23s
# 7:	total: 344ms	remaining: 8.26s
# 8:	total: 389ms	remaining: 8.27s
# 9:	total: 426ms	remaining: 8.09s
# 10:	total: 469ms	remaining: 8.06s
# 11:	total: 512ms	remaining: 8.02s
# 12:	total: 552ms	remaining: 7.94s
# 13:	total: 590ms	remaining: 7.84s
# 14:	total: 628ms	remaining: 7.75s
# 15:	total: 666ms	remaining: 7.66s
# 16:	total: 706ms	remaining: 7.6s
# 17:	total: 742ms	remaining: 7.5s
# 18:	total: 777ms	remaining: 7.41s
# 19:	total: 822ms	remaining: 7.4s
# 20:	total: 863ms	remaining: 7.35s
# 21:	total: 899ms	remaining: 7.27s
# 22:	total: 940ms	remaining: 7.24s
# 23:	total: 985ms	remaining: 7.23s
# 24:	total: 1.02s	remaining: 7.16s
# 25:	total: 1.07s	remaining: 7.2s
# 26:	total: 1.11s	remaining: 7.15s
# 27:	total: 1.16s	remaining: 7.11s
# 28:	total: 1.2s	remaining: 7.09s
# 29:	total: 1.24s	remaining: 7.04s
# 30:	total: 1.28s	remaining: 7.01s
# 31:	total: 1.32s	remaining: 6.94s
# 32:	total: 1.36s	remaining: 6.88s
# 33:	total: 1.4s	remaining: 6.83s
# 34:	total: 1.44s	remaining: 6.8s
# 35:	total: 1.48s	remaining: 6.74s
# 36:	total: 1.51s	remaining: 6.68s
# 37:	total: 1.55s	remaining: 6.61s
# 38:	total: 1.58s	remaining: 6.54s
# 39:	total: 1.61s	remaining: 6.46s
# 40:	total: 1.65s	remaining: 6.39s
# 41:	total: 1.69s	remaining: 6.34s
# 42:	total: 1.73s	remaining: 6.31s
# 43:	total: 1.76s	remaining: 6.26s
# 44:	total: 1.8s	remaining: 6.19s
# 45:	total: 1.83s	remaining: 6.14s
# 46:	total: 1.87s	remaining: 6.09s
# 47:	total: 1.91s	remaining: 6.04s
# 48:	total: 1.94s	remaining: 5.97s
# 49:	total: 1.97s	remaining: 5.92s
# 50:	total: 2.01s	remaining: 5.87s
# 51:	total: 2.04s	remaining: 5.81s
# 52:	total: 2.08s	remaining: 5.76s
# 53:	total: 2.12s	remaining: 5.72s
# 54:	total: 2.16s	remaining: 5.69s
# 55:	total: 2.2s	remaining: 5.66s
# 56:	total: 2.25s	remaining: 5.64s
# 57:	total: 2.28s	remaining: 5.59s
# 58:	total: 2.32s	remaining: 5.54s
# 59:	total: 2.35s	remaining: 5.49s
# 60:	total: 2.39s	remaining: 5.45s
# 61:	total: 2.43s	remaining: 5.4s
# 62:	total: 2.46s	remaining: 5.36s
# 63:	total: 2.51s	remaining: 5.33s
# 64:	total: 2.54s	remaining: 5.29s
# 65:	total: 2.58s	remaining: 5.24s
# 66:	total: 2.62s	remaining: 5.19s
# 67:	total: 2.65s	remaining: 5.15s
# 68:	total: 2.69s	remaining: 5.11s
# 69:	total: 2.73s	remaining: 5.07s
# 70:	total: 2.77s	remaining: 5.04s
# 71:	total: 2.84s	remaining: 5.04s
# 72:	total: 2.88s	remaining: 5.01s
# 73:	total: 2.91s	remaining: 4.96s
# 74:	total: 2.95s	remaining: 4.92s
# 75:	total: 2.99s	remaining: 4.88s
# 76:	total: 3.03s	remaining: 4.84s
# 77:	total: 3.06s	remaining: 4.79s
# 78:	total: 3.1s	remaining: 4.75s
# 79:	total: 3.14s	remaining: 4.71s
# 80:	total: 3.17s	remaining: 4.66s
# 81:	total: 3.21s	remaining: 4.62s
# 82:	total: 3.25s	remaining: 4.58s
# 83:	total: 3.29s	remaining: 4.54s
# 84:	total: 3.35s	remaining: 4.53s
# 85:	total: 3.41s	remaining: 4.52s
# 86:	total: 3.48s	remaining: 4.52s
# 87:	total: 3.54s	remaining: 4.51s
# 88:	total: 3.6s	remaining: 4.49s
# 89:	total: 3.67s	remaining: 4.48s
# 90:	total: 3.72s	remaining: 4.46s
# 91:	total: 3.78s	remaining: 4.44s
# 92:	total: 3.83s	remaining: 4.41s
# 93:	total: 3.9s	remaining: 4.4s
# 94:	total: 3.96s	remaining: 4.38s
# 95:	total: 4.03s	remaining: 4.36s
# 96:	total: 4.09s	remaining: 4.34s
# 97:	total: 4.14s	remaining: 4.31s
# 98:	total: 4.2s	remaining: 4.29s
# 99:	total: 4.27s	remaining: 4.27s
# 100:	total: 4.33s	remaining: 4.25s
# 101:	total: 4.39s	remaining: 4.22s
# 102:	total: 4.46s	remaining: 4.2s
# 103:	total: 4.52s	remaining: 4.17s
# 104:	total: 4.57s	remaining: 4.13s
# 105:	total: 4.63s	remaining: 4.1s
# 106:	total: 4.69s	remaining: 4.08s
# 107:	total: 4.75s	remaining: 4.05s
# 108:	total: 4.81s	remaining: 4.02s
# 109:	total: 4.88s	remaining: 3.99s
# 110:	total: 4.95s	remaining: 3.96s
# 111:	total: 5.01s	remaining: 3.94s
# 112:	total: 5.07s	remaining: 3.9s
# 113:	total: 5.13s	remaining: 3.87s
# 114:	total: 5.19s	remaining: 3.84s
# 115:	total: 5.26s	remaining: 3.81s
# 116:	total: 5.32s	remaining: 3.77s
# 117:	total: 5.38s	remaining: 3.74s
# 118:	total: 5.45s	remaining: 3.71s
# 119:	total: 5.51s	remaining: 3.67s
# 120:	total: 5.58s	remaining: 3.64s
# 121:	total: 5.65s	remaining: 3.61s
# 122:	total: 5.72s	remaining: 3.58s
# 123:	total: 5.78s	remaining: 3.54s
# 124:	total: 5.84s	remaining: 3.5s
# 125:	total: 5.89s	remaining: 3.46s
# 126:	total: 5.96s	remaining: 3.42s
# 127:	total: 6.01s	remaining: 3.38s
# 128:	total: 6.08s	remaining: 3.35s
# 129:	total: 6.14s	remaining: 3.3s
# 130:	total: 6.21s	remaining: 3.27s
# 131:	total: 6.28s	remaining: 3.23s
# 132:	total: 6.35s	remaining: 3.2s
# 133:	total: 6.42s	remaining: 3.16s
# 134:	total: 6.49s	remaining: 3.12s
# 135:	total: 6.55s	remaining: 3.08s
# 136:	total: 6.62s	remaining: 3.04s
# 137:	total: 6.68s	remaining: 3s
# 138:	total: 6.75s	remaining: 2.96s
# 139:	total: 6.81s	remaining: 2.92s
# 140:	total: 6.87s	remaining: 2.87s
# 141:	total: 6.93s	remaining: 2.83s
# 142:	total: 6.99s	remaining: 2.79s
# 143:	total: 7.06s	remaining: 2.75s
# 144:	total: 7.12s	remaining: 2.7s
# 145:	total: 7.18s	remaining: 2.65s
# 146:	total: 7.24s	remaining: 2.61s
# 147:	total: 7.3s	remaining: 2.56s
# 148:	total: 7.36s	remaining: 2.52s
# 149:	total: 7.43s	remaining: 2.48s
# 150:	total: 7.48s	remaining: 2.43s
# 151:	total: 7.53s	remaining: 2.38s
# 152:	total: 7.56s	remaining: 2.32s
# 153:	total: 7.6s	remaining: 2.27s
# 154:	total: 7.64s	remaining: 2.22s
# 155:	total: 7.68s	remaining: 2.17s
# 156:	total: 7.72s	remaining: 2.11s
# 157:	total: 7.75s	remaining: 2.06s
# 158:	total: 7.79s	remaining: 2.01s
# 159:	total: 7.82s	remaining: 1.96s
# 160:	total: 7.86s	remaining: 1.9s
# 161:	total: 7.89s	remaining: 1.85s
# 162:	total: 7.93s	remaining: 1.8s
# 163:	total: 7.97s	remaining: 1.75s
# 164:	total: 8s	remaining: 1.7s
# 165:	total: 8.04s	remaining: 1.65s
# 166:	total: 8.07s	remaining: 1.59s
# 167:	total: 8.11s	remaining: 1.54s
# 168:	total: 8.14s	remaining: 1.49s
# 169:	total: 8.18s	remaining: 1.44s
# 170:	total: 8.21s	remaining: 1.39s
# 171:	total: 8.24s	remaining: 1.34s
# 172:	total: 8.28s	remaining: 1.29s
# 173:	total: 8.31s	remaining: 1.24s
# 174:	total: 8.35s	remaining: 1.19s
# 175:	total: 8.38s	remaining: 1.14s
# 176:	total: 8.42s	remaining: 1.09s
# 177:	total: 8.45s	remaining: 1.04s
# 178:	total: 8.49s	remaining: 996ms
# 179:	total: 8.52s	remaining: 947ms
# 180:	total: 8.56s	remaining: 898ms
# 181:	total: 8.59s	remaining: 850ms
# 182:	total: 8.63s	remaining: 801ms
# 183:	total: 8.66s	remaining: 753ms
# 184:	total: 8.69s	remaining: 705ms
# 185:	total: 8.73s	remaining: 657ms
# 186:	total: 8.76s	remaining: 609ms
# 187:	total: 8.8s	remaining: 562ms
# 188:	total: 8.83s	remaining: 514ms
# 189:	total: 8.87s	remaining: 467ms
# 190:	total: 8.9s	remaining: 419ms
# 191:	total: 8.94s	remaining: 372ms
# 192:	total: 8.97s	remaining: 325ms
# 193:	total: 9.01s	remaining: 279ms
# 194:	total: 9.04s	remaining: 232ms
# 195:	total: 9.07s	remaining: 185ms
# 196:	total: 9.1s	remaining: 139ms
# 197:	total: 9.14s	remaining: 92.3ms
# 198:	total: 9.17s	remaining: 46.1ms
# 199:	total: 9.21s	remaining: 0us
# XG-CV: 0.25977091922273576
# ET-CV: 0.26296502347137407
# RF-CV: 0.2629852624591803
# RF-CV: 0.33124038832606534
# (307511, 4), (48744, 4)
