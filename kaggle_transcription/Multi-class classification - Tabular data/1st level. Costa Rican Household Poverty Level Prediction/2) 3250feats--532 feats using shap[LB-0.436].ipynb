# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale=2.2)
plt.style.use('seaborn-v0_8')

from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.model_selection import StratifiedKFold, train_test_split, ShuffleSplit
from sklearn.metrics import f1_score
import itertools
import lightgbm as lgb
import xgboost as xgb
from xgboost import XGBClassifier
import shap
from tqdm import tqdm
import featuretools as ft
import warnings
warnings.filterwarnings('ignore')
import time
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\woodwork\__init__.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# # 1. Check datasets
#
# ## 1.1 Read dataset

# %%
df_train = pd.read_csv('./input/train.csv')
df_test = pd.read_csv('./input/test.csv')

# %%
print('df_train shape:', df_train.shape, '   ', 'df_test shape: ', df_test.shape)
# Out:
# df_train shape: (9557, 143)     df_test shape:  (23856, 142)

# %%
df_train.head()
# Out:
#              Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  v18q1  \
# 0  ID_279628684  190000.0       0      3       0     1       1     0    NaN
# 1  ID_f29eb3ddd  135000.0       0      4       0     1       1     1    1.0
# 2  ID_68de51c94       NaN       0      8       0     1       1     0    NaN
# 3  ID_d671db89c  180000.0       0      5       0     1       1     1    1.0
# 4  ID_d56d6f5f5  180000.0       0      5       0     1       1     1    1.0
#
#    r4h1  ...  SQBescolari  SQBage  SQBhogar_total  SQBedjefe  SQBhogar_nin  \
# 0     0  ...          100    1849               1        100             0
# 1     0  ...          144    4489               1        144             0
# 2     0  ...          121    8464               1          0             0
# 3     0  ...           81     289              16        121             4
# 4     0  ...          121    1369              16        121             4
#
#    SQBovercrowding  SQBdependency  SQBmeaned  agesq  Target
# 0         1.000000            0.0      100.0   1849       4
# 1         1.000000           64.0      144.0   4489       4
# 2         0.250000           64.0      121.0   8464       4
# 3         1.777778            1.0      121.0    289       4
# 4         1.777778            1.0      121.0   1369       4
#
# [5 rows x 143 columns]

# %%
df_test.head()
# Out:
#              Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  v18q1  \
# 0  ID_2f6873615       NaN       0      5       0     1       1     0    NaN
# 1  ID_1c78846d2       NaN       0      5       0     1       1     0    NaN
# 2  ID_e5442cf6a       NaN       0      5       0     1       1     0    NaN
# 3  ID_a8db26a79       NaN       0     14       0     1       1     1    1.0
# 4  ID_a62966799  175000.0       0      4       0     1       1     1    1.0
#
#    r4h1  ...  age  SQBescolari  SQBage  SQBhogar_total  SQBedjefe  \
# 0     1  ...    4            0      16               9          0
# 1     1  ...   41          256    1681               9          0
# 2     1  ...   41          289    1681               9          0
# 3     0  ...   59          256    3481               1        256
# 4     0  ...   18          121     324               1          0
#
#    SQBhogar_nin  SQBovercrowding  SQBdependency  SQBmeaned  agesq
# 0             1             2.25           0.25     272.25     16
# 1             1             2.25           0.25     272.25   1681
# 2             1             2.25           0.25     272.25   1681
# 3             0             1.00           0.00     256.00   3481
# 4             1             0.25          64.00        NaN    324
#
# [5 rows x 142 columns]

# %% [markdown]
# ## 1.2 Make description df

# %%
description = [
    ('v2a1', 'Monthly rent payment'),
    ('hacdor', ' =1 Overcrowding by bedrooms'),
    ('rooms', ' number of all rooms in the house'),
    ('hacapo', ' =1 Overcrowding by rooms'),
    ('v14a', ' =1 has toilet in the household'),
    ('refrig', ' =1 if the household has refrigerator'),
    ('v18q', ' owns a tablet'),
    ('v18q1', ' number of tablets household owns'),
    ('r4h1', ' Males younger than 12 years of age'),
    ('r4h2', ' Males 12 years of age and older'),
    ('r4h3', ' Total males in the household'),
    ('r4m1', ' Females younger than 12 years of age'),
    ('r4m2', ' Females 12 years of age and older'),
    ('r4m3', ' Total females in the household'),
    ('r4t1', ' persons younger than 12 years of age'),
    ('r4t2', ' persons 12 years of age and older'),
    ('r4t3', ' Total persons in the household'),
    ('tamhog', ' size of the household'),
    ('tamviv', ' number of persons living in the household'),
    ('escolari', ' years of schooling'),
    ('rez_esc', ' Years behind in school'),
    ('hhsize', ' household size'),
    ('paredblolad', ' =1 if predominant material on the outside wall is block or brick'),
    ('paredzocalo', ' =1 if predominant material on the outside wall is socket (wood, zinc or absbesto'),
    ('paredpreb', ' =1 if predominant material on the outside wall is prefabricated or cement'),
    ('pareddes', ' =1 if predominant material on the outside wall is waste material'),
    ('paredmad', ' =1 if predominant material on the outside wall is wood'),
    ('paredzinc', ' =1 if predominant material on the outside wall is zinc'),
    ('paredfibras', ' =1 if predominant material on the outside wall is natural fibers'),
    ('paredother', ' =1 if predominant material on the outside wall is other'),
    ('pisomoscer', ' =1 if predominant material on the floor is mosaic ceramic terrazo'),
    ('pisocemento', ' =1 if predominant material on the floor is cement'),
    ('pisoother', ' =1 if predominant material on the floor is other'),
    ('pisonatur', ' =1 if predominant material on the floor is natural material'),
    ('pisonotiene', ' =1 if no floor at the household'),
    ('pisomadera', ' =1 if predominant material on the floor is wood'),
    ('techozinc', ' =1 if predominant material on the roof is metal foil or zinc'),
    ('techoentrepiso', ' =1 if predominant material on the roof is fiber cement, mezzanine '),
    ('techocane', ' =1 if predominant material on the roof is natural fibers'),
    ('techootro', ' =1 if predominant material on the roof is other'),
    ('cielorazo', ' =1 if the hosue has ceiling'),
    ('abastaguadentro', ' =1 if water provision inside the dwelling'),
    ('abastaguafuera', ' =1 if water provision outside the dwelling'),
    ('abastaguano', ' =1 if no water provision'),
    ('public', ' =1 electricy from CNFL, ICE, ESPH/JASEC'),
    ('planpri', ' =1 electricity from private plant'),
    ('noelec', ' =1 no electricity in the dwelling'),
    ('coopele', ' =1 electricity from cooperative'),
    ('sanitario1', ' =1 no toilet in the dwelling'),
    ('sanitario2', ' =1 toilet connected to sewer or cesspool'),
    ('sanitario3', ' =1 toilet connected to septic tank'),
    ('sanitario5', ' =1 toilet connected to black hole or letrine'),
    ('sanitario6', ' =1 toilet connected to other system'),
    ('energcocinar1', ' =1 no main source of energy used for cooking (no kitchen)'),
    ('energcocinar2', ' =1 main source of energy used for cooking electricity'),
    ('energcocinar3', ' =1 main source of energy used for cooking gas'),
    ('energcocinar4', ' =1 main source of energy used for cooking wood charcoal'),
    ('elimbasu1', ' =1 if rubbish disposal mainly by tanker truck'),
    ('elimbasu2', ' =1 if rubbish disposal mainly by botan hollow or buried'),
    ('elimbasu3', ' =1 if rubbish disposal mainly by burning'),
    ('elimbasu4', ' =1 if rubbish disposal mainly by throwing in an unoccupied space'),
    ('elimbasu5', ' =1 if rubbish disposal mainly by throwing in river, creek or sea'),
    ('elimbasu6', ' =1 if rubbish disposal mainly other'),
    ('epared1', ' =1 if walls are bad'),
    ('epared2', ' =1 if walls are regular'),
    ('epared3', ' =1 if walls are good'),
    ('etecho1', ' =1 if roof are bad'),
    ('etecho2', ' =1 if roof are regular'),
    ('etecho3', ' =1 if roof are good'),
    ('eviv1', ' =1 if floor are bad'),
    ('eviv2', ' =1 if floor are regular'),
    ('eviv3', ' =1 if floor are good'),
    ('dis', ' =1 if disable person'),
    ('male', ' =1 if male'),
    ('female', ' =1 if female'),
    ('estadocivil1', ' =1 if less than 10 years old'),
    ('estadocivil2', ' =1 if free or coupled union'),
    ('estadocivil3', ' =1 if married'),
    ('estadocivil4', ' =1 if divorced'),
    ('estadocivil5', ' =1 if separated'),
    ('estadocivil6', ' =1 if widow/er'),
    ('estadocivil7', ' =1 if single'),
    ('parentesco1', ' =1 if household head'),
    ('parentesco2', ' =1 if spouse/partner'),
    ('parentesco3', ' =1 if son/daughter'),
    ('parentesco4', ' =1 if stepson/daughter'),
    ('parentesco5', ' =1 if son/daughter in law'),
    ('parentesco6', ' =1 if grandson/daughter'),
    ('parentesco7', ' =1 if mother/father'),
    ('parentesco8', ' =1 if father/mother in law'),
    ('parentesco9', ' =1 if brother/sister'),
    ('parentesco10', ' =1 if brother/sister in law'),
    ('parentesco11', ' =1 if other family member'),
    ('parentesco12', ' =1 if other non family member'),
    ('idhogar', ' Household level identifier'),
    ('hogar_nin', ' Number of children 0 to 19 in household'),
    ('hogar_adul', ' Number of adults in household'),
    ('hogar_mayor', ' # of individuals 65+ in the household'),
    ('hogar_total', ' # of total individuals in the household'),
    ('dependency', ' Dependency rate'),
    ('edjefe', ' years of education of male head of household'),
    ('edjefa', ' years of education of female head of household'),
    ('meaneduc', ' average years of education for adults (18+)'),
    ('instlevel1', ' =1 no level of education'),
    ('instlevel2', ' =1 incomplete primary'),
    ('instlevel3', ' =1 complete primary'),
    ('instlevel4', ' =1 incomplete academic secondary level'),
    ('instlevel5', ' =1 complete academic secondary level'),
    ('instlevel6', ' =1 incomplete technical secondary level'),
    ('instlevel7', ' =1 complete technical secondary level'),
    ('instlevel8', ' =1 undergraduate and higher education'),
    ('instlevel9', ' =1 postgraduate higher education'),
    ('bedrooms', ' number of bedrooms'),
    ('overcrowding', ' # persons per room'),
    ('tipovivi1', ' =1 own and fully paid house'),
    ('tipovivi2', ' =1 own, paying in installments'),
    ('tipovivi3', ' =1 rented'),
    ('tipovivi4', ' =1 precarious'),
    ('tipovivi5', ' =1 other(assigned)'),
    ('computer', ' =1 if the household has notebook or desktop computer, borrowed'),
    ('television', ' =1 if the household has TV'),
    ('mobilephone', ' =1 if mobile phone'),
    ('qmobilephone', ' # of mobile phones'),
    ('lugar1', ' =1 region Central'),
    ('lugar2', ' =1 region Chorotega'),
    ('lugar3', ' =1 region PacÃƒÂ­fico central'),
    ('lugar4', ' =1 region Brunca'),
    ('lugar5', ' =1 region Huetar AtlÃƒÂ¡ntica'),
    ('lugar6', ' =1 region Huetar Norte'),
    ('area1', ' =1 zona urbana'),
    ('area2', ' =2 zona rural'),
    ('age', ' Age in years'),
    ('SQBescolari', ' escolari squared'),
    ('SQBage', ' age squared'),
    ('SQBhogar_total', ' hogar_total squared'),
    ('SQBedjefe', ' edjefe squared'),
    ('SQBhogar_nin', ' hogar_nin squared'),
    ('SQBovercrowding', ' overcrowding squared'),
    ('SQBdependency', ' dependency squared'),
    ('SQBmeaned', ' meaned squared'),
    ('agesq', ' Age sqaured'),
]

description = pd.DataFrame(description, columns=['varname', 'description'])

# %%
description
# Out:
#              varname                        description
# 0               v2a1               Monthly rent payment
# 1             hacdor        =1 Overcrowding by bedrooms
# 2              rooms   number of all rooms in the house
# 3             hacapo           =1 Overcrowding by rooms
# 4               v14a     =1 has toilet in the household
# ..               ...                                ...
# 136     SQBhogar_nin                  hogar_nin squared
# 137  SQBovercrowding               overcrowding squared
# 138    SQBdependency                 dependency squared
# 139        SQBmeaned                     meaned squared
# 140            agesq                        Age sqaured
#
# [141 rows x 2 columns]

# %% [markdown]
# ## 1.3 Check null data

# %%
total = df_train.isnull().sum().sort_values(ascending=False)
percent = 100 * (df_train.isnull().sum() / df_train.isnull().count()).sort_values(ascending=False)
missing_df = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_df.head(20)
# Out:
#            Total    Percent
# rez_esc     7928  82.954902
# v18q1       7342  76.823271
# v2a1        6860  71.779847
# meaneduc       5   0.052318
# SQBmeaned      5   0.052318
# rooms          0   0.000000
# Id             0   0.000000
# refrig         0   0.000000
# v18q           0   0.000000
# r4h1           0   0.000000
# r4h2           0   0.000000
# r4h3           0   0.000000
# hacapo         0   0.000000
# v14a           0   0.000000
# hacdor         0   0.000000
# r4m3           0   0.000000
# r4m2           0   0.000000
# r4m1           0   0.000000
# r4t1           0   0.000000
# tamhog         0   0.000000

# %% [markdown]
# ## 1.4 Fill missing values
#
# * Below cell is from this kernel. https://www.kaggle.com/skooch/lgbm-w-random-split-2

# %%
# df_train.loc[(df_train['edjefa'] == 'yes') & (df_train['parentesco1'] == 1), 'edjefa'] = df_train.loc[(df_train['edjefa'] == 'yes') & (df_train['parentesco1'] == 1), 'escolari']
# df_train.loc[(df_train['edjefe'] == 'yes') & (df_train['parentesco1'] == 1), 'edjefe'] = df_train.loc[(df_train['edjefe'] == 'yes') & (df_train['parentesco1'] == 1), 'escolari']

# df_test.loc[(df_test['edjefa'] == 'yes') & (df_test['parentesco1'] == 1), 'edjefa'] = df_test.loc[(df_test['edjefa'] == 'yes') & (df_test['parentesco1'] == 1), 'escolari']
# df_test.loc[(df_test['edjefe'] == 'yes') & (df_test['parentesco1'] == 1), 'edjefe'] = df_test.loc[(df_test['edjefe'] == 'yes') & (df_test['parentesco1'] == 1), 'escolari']

# df_train.loc[df_train['edjefa'] == 'yes', 'edjefa'] = 4
# df_train.loc[df_train['edjefe'] == 'yes', 'edjefe'] = 4

# df_test.loc[df_test['edjefa'] == 'yes', 'edjefa'] = 4
# df_test.loc[df_test['edjefe'] == 'yes', 'edjefe'] = 4

# df_train['edjef'] = np.max(df_train[['edjefa', 'edjefe']], axis=1)
# df_test['edjef'] = np.max(df_test[['edjefa', 'edjefe']], axis=1)

# df_train.loc[(df_train.v14a == 1) & (df_train.sanitario1 == 1) & (df_train.abastaguano == 0), 'v14a'] = 0
# df_train.loc[(df_train.v14a == 1) & (df_train.sanitario1 == 1) & (df_train.abastaguano == 0), 'sanitario1'] = 0

# df_test.loc[(df_test.v14a == 1) & (df_test.sanitario1 == 1) & (df_test.abastaguano == 0), 'v14a'] = 0
# df_test.loc[(df_test.v14a == 1) & (df_test.sanitario1 == 1) & (df_test.abastaguano == 0), 'sanitario1'] = 0

# %%
df_train.loc[(df_train['edjefa'] == 'yes') & (df_train['parentesco1'] == 1), 'edjefa'] = df_train.loc[(df_train['edjefa'] == 'yes') & (df_train['parentesco1'] == 1), 'escolari']
df_train.loc[(df_train['edjefe'] == 'yes') & (df_train['parentesco1'] == 1), 'edjefe'] = df_train.loc[(df_train['edjefe'] == 'yes') & (df_train['parentesco1'] == 1), 'escolari']

df_test.loc[(df_test['edjefa'] == 'yes') & (df_test['parentesco1'] == 1), 'edjefa'] = df_test.loc[(df_test['edjefa'] == 'yes') & (df_test['parentesco1'] == 1), 'escolari']
df_test.loc[(df_test['edjefe'] == 'yes') & (df_test['parentesco1'] == 1), 'edjefe'] = df_test.loc[(df_test['edjefe'] == 'yes') & (df_test['parentesco1'] == 1), 'escolari']

df_train.loc[df_train['edjefa'] == 'yes', 'edjefa'] = 4
df_train.loc[df_train['edjefe'] == 'yes', 'edjefe'] = 4

df_test.loc[df_test['edjefa'] == 'yes', 'edjefa'] = 4
df_test.loc[df_test['edjefe'] == 'yes', 'edjefe'] = 4

df_train['edjef'] = df_train[['edjefa', 'edjefe']].replace('no', 0).astype(float).max(axis=1)
df_test['edjef'] = df_test[['edjefa', 'edjefe']].replace('no', 0).astype(float).max(axis=1)

df_train.loc[(df_train.v14a == 1) & (df_train.sanitario1 == 1) & (df_train.abastaguano == 0), 'v14a'] = 0
df_train.loc[(df_train.v14a == 1) & (df_train.sanitario1 == 1) & (df_train.abastaguano == 0), 'sanitario1'] = 0

df_test.loc[(df_test.v14a == 1) & (df_test.sanitario1 == 1) & (df_test.abastaguano == 0), 'v14a'] = 0
df_test.loc[(df_test.v14a == 1) & (df_test.sanitario1 == 1) & (df_test.abastaguano == 0), 'sanitario1'] = 0

# %% [markdown]
# ### rez_esc, SQBmeaned
#
# * rez_esc : Years behind in school -> filled with 0
# * SQBmeaned : square of the mean years of education of adults (>=18) in the household agesq, Age squared -> same with rez_esc -> filled with 0

# %%
df_train['rez_esc'].fillna(0, inplace=True)
df_test['rez_esc'].fillna(0, inplace=True)

# %%
df_train['SQBmeaned'].fillna(0, inplace=True)
df_test['SQBmeaned'].fillna(0, inplace=True)

# %% [markdown]
# ### meaneduc
#
# * meaneduc: average years of education for adults (18+) -> filled with 0

# %%
df_train['meaneduc'].fillna(0, inplace=True)
df_test['meaneduc'].fillna(0, inplace=True)

# %% [markdown]
# ### v18q1
#
# * v18q1: number of tablets household owns -> if v18q(Do you own a tablet?) == 1, there are some values. If not, only NaN values in v18q1. See below 3 cells.

# %%
df_train['v18q'].value_counts()
# Out:
# v18q
# 0    7342
# 1    2215
# Name: count, dtype: int64

# %% [markdown]
# * v18q1: number of tablets household owns -> if v18q == 1, there are some values. If not, only NaN values there. See below two cells.

# %%
df_train.loc[df_train['v18q'] == 1, 'v18q1'].value_counts()
# Out:
# v18q1
# 1.0    1586
# 2.0     444
# 3.0     129
# 4.0      37
# 5.0      13
# 6.0       6
# Name: count, dtype: int64

# %%
df_train.loc[df_train['v18q'] == 0, 'v18q1'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df_train['v18q1'].fillna(0, inplace=True)
df_test['v18q1'].fillna(0, inplace=True)

# %% [markdown]
# * v2a1: number of tablets household owns -> if tipovivi3(rented?) == 1, there are some values. If not, there are also some values.
# * NaN value could be replaced by 0.

# %%
df_train['tipovivi3'].value_counts()
# Out:
# tipovivi3
# 0    7821
# 1    1736
# Name: count, dtype: int64

# %%
sns.kdeplot(df_train.loc[df_train['tipovivi3'] == 1, 'v2a1'], label='Monthly rent payment of household(rented=1)')
sns.kdeplot(df_train.loc[df_train['tipovivi3'] == 0, 'v2a1'], label='Monthly rent payment of household(rented=0)')
plt.xscale('log')
plt.show()

# %%
df_train['v2a1'].fillna(0, inplace=True)
df_test['v2a1'].fillna(0, inplace=True)

# %%
total = df_train.isnull().sum().sort_values(ascending=False)
percent = 100 * (df_train.isnull().sum() / df_train.isnull().count()).sort_values(ascending=False)
missing_df = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_df.head(20)
# Out:
#         Total  Percent
# Id          0      0.0
# v2a1        0      0.0
# hacdor      0      0.0
# rooms       0      0.0
# hacapo      0      0.0
# v14a        0      0.0
# refrig      0      0.0
# v18q        0      0.0
# v18q1       0      0.0
# r4h1        0      0.0
# r4h2        0      0.0
# r4h3        0      0.0
# r4m1        0      0.0
# r4m2        0      0.0
# r4m3        0      0.0
# r4t1        0      0.0
# r4t2        0      0.0
# r4t3        0      0.0
# tamhog      0      0.0
# tamviv      0      0.0

# %%
total = df_test.isnull().sum().sort_values(ascending=False)
percent = 100 * (df_test.isnull().sum() / df_test.isnull().count()).sort_values(ascending=False)
missing_df = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_df.head(20)
# Out:
#         Total  Percent
# Id          0      0.0
# v2a1        0      0.0
# hacdor      0      0.0
# rooms       0      0.0
# hacapo      0      0.0
# v14a        0      0.0
# refrig      0      0.0
# v18q        0      0.0
# v18q1       0      0.0
# r4h1        0      0.0
# r4h2        0      0.0
# r4h3        0      0.0
# r4m1        0      0.0
# r4m2        0      0.0
# r4m3        0      0.0
# r4t1        0      0.0
# r4t2        0      0.0
# r4t3        0      0.0
# tamhog      0      0.0
# tamviv      0      0.0

# %% [markdown]
# **For now, there are no NaN values.**
#
# # 2. Feature engineering
#
# ## 2.1 Object features

# %%
features_object = [col for col in df_train.columns if df_train[col].dtype=='object']

# %%
features_object
# Out:
# ['Id', 'idhogar', 'dependency', 'edjefe', 'edjefa']

# %% [markdown]
# ### dependency

# %%
df_train['dependency'] = np.sqrt(df_train['SQBdependency'])
df_test['dependency'] = np.sqrt(df_test['SQBdependency'])

# %% [markdown]
# ### edjefe
#
# * edjefe, years of education of male head of household, based on the interaction of escolari (years of education), head of household and gender, yes=1 and no=0
# * replace yes -> 1 and no -> 0

# %%
def replace_edjefe(x):
    if x == 'yes':
        return 1
    elif x == 'no':
        return 0
    else:
        return x

df_train['edjefe'] = df_train['edjefe'].apply(replace_edjefe).astype(float)
df_test['edjefe'] = df_test['edjefe'].apply(replace_edjefe).astype(float)

# %% [markdown]
# ### edjefa
#
# * edjefa, years of education of female head of household, based on the interaction of escolari (years of education), head of household and gender, yes=1 and no=0
# * replace yes -> 1 and no -> 0

# %%
def replace_edjefa(x):
    if x == 'yes':
        return 1
    elif x == 'no':
        return 0
    else:
        return x

df_train['edjefa'] = df_train['edjefa'].apply(replace_edjefa).astype(float)
df_test['edjefa'] = df_test['edjefa'].apply(replace_edjefa).astype(float)

# %%
df_train['edjef'] = np.max(df_train[['edjefa', 'edjefe']], axis=1)
df_test['edjef'] = np.max(df_test[['edjefa', 'edjefe']], axis=1)

# %% [markdown]
# ### roof and electricity
#
# * I referred to https://www.kaggle.com/mineshjethva/exploratory-data-analysis-lightgbm. Thanks!

# %%
df_train['roof_waste_material'] = np.nan
df_test['roof_waste_material'] = np.nan
df_train['electricity_other'] = np.nan
df_test['electricity_other'] = np.nan

def fill_roof_exception(x):
    if (x['techozinc'] == 0) and (x['techoentrepiso'] == 0) and (x['techocane'] == 0) and (x['techootro'] == 0):
        return 1
    else:
        return 0

def fill_no_electricity(x):
    if (x['public'] == 0) and (x['planpri'] == 0) and (x['noelec'] == 0) and (x['coopele'] == 0):
        return 1
    else:
        return 0

df_train['roof_waste_material'] = df_train.apply(lambda x: fill_roof_exception(x), axis=1)
df_test['roof_waste_material'] = df_test.apply(lambda x: fill_roof_exception(x), axis=1)
df_train['electricity_other'] = df_train.apply(lambda x: fill_no_electricity(x), axis=1)
df_test['electricity_other'] = df_test.apply(lambda x: fill_no_electricity(x), axis=1)

# %% [markdown]
# ## 2.2 Extract cat features
#
# * According to data scription, there are many binary category features.

# %%
binary_cat_features = [col for col in df_train.columns if df_train[col].value_counts().shape[0] == 2]

# %% [markdown]
# ## 2.3 Make new features using continuous feature

# %%
continuous_features = [col for col in df_train.columns if col not in binary_cat_features]
continuous_features = [col for col in continuous_features if col not in features_object]
continuous_features = [col for col in continuous_features if col not in ['Id', 'Target', 'idhogar']]

# %%
print('There are {} continuous features'.format(len(continuous_features)))
for col in continuous_features:
    print('{}: {}'.format(col, description.loc[description['varname'] == col, 'description'].values))
# Out:
# There are 37 continuous features
# v2a1: ['Monthly rent payment']
# rooms: [' number of all rooms in the house']
# v18q1: [' number of tablets household owns']
# r4h1: [' Males younger than 12 years of age']
# r4h2: [' Males 12 years of age and older']
# r4h3: [' Total males in the household']
# r4m1: [' Females younger than 12 years of age']
# r4m2: [' Females 12 years of age and older']
# r4m3: [' Total females in the household']
# r4t1: [' persons younger than 12 years of age']
# r4t2: [' persons 12 years of age and older']
# r4t3: [' Total persons in the household']
# tamhog: [' size of the household']
# tamviv: [' number of persons living in the household']
# escolari: [' years of schooling']
# rez_esc: [' Years behind in school']
# hhsize: [' household size']
# elimbasu5: [' =1 if rubbish disposal mainly by throwing in river, creek or sea']
# hogar_nin: [' Number of children 0 to 19 in household']
# hogar_adul: [' Number of adults in household']
# hogar_mayor: [' # of individuals 65+ in the household']
# hogar_total: [' # of total individuals in the household']
# meaneduc: [' average years of education for adults (18+)']
# bedrooms: [' number of bedrooms']
# overcrowding: [' # persons per room']
# qmobilephone: [' # of mobile phones']
# age: [' Age in years']
# SQBescolari: [' escolari squared']
# SQBage: [' age squared']
# SQBhogar_total: [' hogar_total squared']
# SQBedjefe: [' edjefe squared']
# SQBhogar_nin: [' hogar_nin squared']
# SQBovercrowding: [' overcrowding squared']
# SQBdependency: [' dependency squared']
# SQBmeaned: [' meaned squared']
# agesq: [' Age sqaured']
# edjef: []

# %% [markdown]
# * hhsize: household size
# * tamhog: size of the household
#
# What is different?
#
# * As you can see, the meaning of two features are same but the exact number are different. Are they different?
# * I don't know. For now, I decided to drop one feature 'tamhog'

# %%
df_train['edjef'].value_counts()
# Out:
# edjef
# 6.0     2792
# 11.0    1150
# 9.0      723
# 8.0      474
# 15.0     473
# 3.0      459
# 0.0      435
# 7.0      413
# 4.0      400
# 5.0      398
# 14.0     328
# 17.0     278
# 2.0      278
# 16.0     247
# 10.0     207
# 12.0     185
# 13.0     155
# 1.0       65
# 21.0      48
# 18.0      22
# 19.0      18
# 20.0       9
# Name: count, dtype: int64

# %%
df_train.drop('tamhog', axis=1, inplace=True)
df_test.drop('tamhog', axis=1, inplace=True)

# %% [markdown]
# ### Squared features
#
# * There are many squared features. Actually, tree models like lightgbm don't need them. But at this kernel, I want to use lightgbm as feature filter model and set entity-ebedding as classifier. So let's keep them.
#
# ### Family features
#
# * hogar_nin, hogar_adul, hogar_mayor, hogar_total, r4h1, r4h2, r4h3, r4m1, r4m2, r4m3, r4t1, r4t2, r4t3, tamhog, tamviv, rez_esc, escolari
# * Family size features (subtract, ratio)

# %%
df_train['adult'] = df_train['hogar_adul'] - df_train['hogar_mayor']
df_train['dependency_count'] = df_train['hogar_nin'] + df_train['hogar_mayor']
df_train['dependency'] = df_train['dependency_count'] / df_train['adult']
df_train['child_percent'] = df_train['hogar_nin'] / df_train['hogar_total']
df_train['elder_percent'] = df_train['hogar_mayor'] / df_train['hogar_total']
df_train['adult_percent'] = df_train['hogar_adul'] / df_train['hogar_total']
df_train['males_younger_12_years_percent'] = df_train['r4h1'] / df_train['hogar_total']
df_train['males_older_12_years_percent'] = df_train['r4h2'] / df_train['hogar_total']
df_train['males_percent'] = df_train['r4h3'] / df_train['hogar_total']
df_train['females_younger_12_years_percent'] = df_train['r4m1'] / df_train['hogar_total']
df_train['females_older_12_years_percent'] = df_train['r4m2'] / df_train['hogar_total']
df_train['females_percent'] = df_train['r4m3'] / df_train['hogar_total']
df_train['persons_younger_12_years_percent'] = df_train['r4t1'] / df_train['hogar_total']
df_train['persons_older_12_years_percent'] = df_train['r4t2'] / df_train['hogar_total']
df_train['persons_percent'] = df_train['r4t3'] / df_train['hogar_total']

# %%
df_test['adult'] = df_test['hogar_adul'] - df_test['hogar_mayor']
df_test['dependency_count'] = df_test['hogar_nin'] + df_test['hogar_mayor']
df_test['dependency'] = df_test['dependency_count'] / df_test['adult']
df_test['child_percent'] = df_test['hogar_nin'] / df_test['hogar_total']
df_test['elder_percent'] = df_test['hogar_mayor'] / df_test['hogar_total']
df_test['adult_percent'] = df_test['hogar_adul'] / df_test['hogar_total']
df_test['males_younger_12_years_percent'] = df_test['r4h1'] / df_test['hogar_total']
df_test['males_older_12_years_percent'] = df_test['r4h2'] / df_test['hogar_total']
df_test['males_percent'] = df_test['r4h3'] / df_test['hogar_total']
df_test['females_younger_12_years_percent'] = df_test['r4m1'] / df_test['hogar_total']
df_test['females_older_12_years_percent'] = df_test['r4m2'] / df_test['hogar_total']
df_test['females_percent'] = df_test['r4m3'] / df_test['hogar_total']
df_test['persons_younger_12_years_percent'] = df_test['r4t1'] / df_test['hogar_total']
df_test['persons_older_12_years_percent'] = df_test['r4t2'] / df_test['hogar_total']
df_test['persons_percent'] = df_test['r4t3'] / df_test['hogar_total']

# %%
df_train['males_younger_12_years_in_household_size'] = df_train['r4h1'] / df_train['hhsize']
df_train['males_older_12_years_in_household_size'] = df_train['r4h2'] / df_train['hhsize']
df_train['males_in_household_size'] = df_train['r4h3'] / df_train['hhsize']
df_train['females_younger_12_years_in_household_size'] = df_train['r4m1'] / df_train['hhsize']
df_train['females_older_12_years_in_household_size'] = df_train['r4m2'] / df_train['hhsize']
df_train['females_in_household_size'] = df_train['r4m3'] / df_train['hogar_total']
df_train['persons_younger_12_years_in_household_size'] = df_train['r4t1'] / df_train['hhsize']
df_train['persons_older_12_years_in_household_size'] = df_train['r4t2'] / df_train['hhsize']
df_train['persons_in_household_size'] = df_train['r4t3'] / df_train['hhsize']

# %%
df_test['males_younger_12_years_in_household_size'] = df_test['r4h1'] / df_test['hhsize']
df_test['males_older_12_years_in_household_size'] = df_test['r4h2'] / df_test['hhsize']
df_test['males_in_household_size'] = df_test['r4h3'] / df_test['hhsize']
df_test['females_younger_12_years_in_household_size'] = df_test['r4m1'] / df_test['hhsize']
df_test['females_older_12_years_in_household_size'] = df_test['r4m2'] / df_test['hhsize']
df_test['females_in_household_size'] = df_test['r4m3'] / df_test['hogar_total']
df_test['persons_younger_12_years_in_household_size'] = df_test['r4t1'] / df_test['hhsize']
df_test['persons_older_12_years_in_household_size'] = df_test['r4t2'] / df_test['hhsize']
df_test['persons_in_household_size'] = df_test['r4t3'] / df_test['hhsize']

# %%
df_train['overcrowding_room_and_bedroom'] = (df_train['hacdor'] + df_train['hacapo']) / 2
df_test['overcrowding_room_and_bedroom'] = (df_test['hacdor'] + df_test['hacapo']) / 2

# %%
df_train['escolari_age'] = df_train['escolari'] / df_train['age']
df_test['escolari_age'] = df_test['escolari'] / df_test['age']

df_train['age_12_19'] = df_train['hogar_nin'] - df_train['r4t1']
df_test['age_12_19'] = df_test['hogar_nin'] - df_test['r4t1']

# %%
df_train['phones-per-capita'] = df_train['qmobilephone'] / df_train['tamviv']
df_train['tablets-per-capita'] = df_train['v18q1'] / df_train['tamviv']
df_train['rooms-per-capita'] = df_train['rooms'] / df_train['tamviv']
df_train['rent-per-capita'] = df_train['v2a1'] / df_train['tamviv']

# %%
df_test['phones-per-capita'] = df_test['qmobilephone'] / df_test['tamviv']
df_test['tablets-per-capita'] = df_test['v18q1'] / df_test['tamviv']
df_test['rooms-per-capita'] = df_test['rooms'] / df_test['tamviv']
df_test['rent-per-capita'] = df_test['v2a1'] / df_test['tamviv']

# %% [markdown]
# * You can see that "Total persons in the household" != "# of total individuals in the household".
# * Somewhat weird. But for now I will keep it.

# %%
(df_train['hogar_total'] == df_train['r4t3']).sum()
# Out:
# np.int64(9509)

# %% [markdown]
# ### Rent per family features
#
# * I will reduce the number of features using shap, so let's generate many features!! Hope catch some fortune features :)

# %%
family_size_features = ['adult', 'hogar_adul', 'hogar_mayor', 'hogar_nin', 'hogar_total', 'r4h1', 'r4h2', 'r4h3', 'r4m1', 'r4m2', 'r4m3', 'r4t1', 'r4t2', 'r4t3', 'hhsize']
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('v2a1', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['v2a1'] / df_train[col]
    df_test[new_col_name] = df_test['v2a1'] / df_test[col]

# %% [markdown]
# * Ratio feature can have infinite values. So let them be filled with 0.

# %%
for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)

    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %% [markdown]
# ### Room per family features

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('rooms', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['bedrooms'] / df_train[col]
    df_test[new_col_name] = df_test['bedrooms'] / df_test[col]

for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)

    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 205) (23856, 204)

# %% [markdown]
# ### Tabulet per family features

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('v18q1', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['v18q1'] / df_train[col]
    df_test[new_col_name] = df_test['v18q1'] / df_test[col]

for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)

    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %% [markdown]
# ### phone per family features

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('qmobilephone', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['qmobilephone'] / df_train[col]
    df_test[new_col_name] = df_test['qmobilephone'] / df_test[col]

for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)
    
    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %% [markdown]
# ### rez_esc(Years behind in school) per family features

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('rez_esc', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['rez_esc'] / df_train[col]
    df_test[new_col_name] = df_train['rez_esc'] / df_test[col]

for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)

    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %%
df_train['rez_esc_age'] = df_train['rez_esc'] / df_train['age']
df_train['rez_esc_escolari'] = df_train['rez_esc'] / df_train['escolari']

df_test['rez_esc_age'] = df_test['rez_esc'] / df_test['age']
df_test['rez_esc_escolari'] = df_test['rez_esc'] / df_test['escolari']

# %% [markdown]
# ### Rich features
#
# * I think the more richer, the larger number of phhones and tabulet

# %%
df_train['tabulet_x_qmobilephone'] = df_train['v18q1'] * df_train['qmobilephone']
df_test['tabulet_x_qmobilephone'] = df_test['v18q1'] * df_test['qmobilephone']

# %% [markdown]
# * wall, roof, floor may be key factor.
# * Let's multiply each of them. Because they are binary cat features, so multification of each features generates new categorical features.

# %%
for col1 in ['epared1', 'epared2', 'epared3']:
    for col2 in ['etecho1', 'etecho2', 'etecho3']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

for col1 in ['epared1', 'epared2', 'epared3']:
    for col2 in ['eviv1', 'eviv2', 'eviv3']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

for col1 in ['etecho1', 'etecho2', 'etecho3']:
    for col2 in ['eviv1', 'eviv2', 'eviv3']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %% [markdown]
# * combination using three features

# %%
for col1 in ['epared1', 'epared2', 'epared3']:
    for col2 in ['etecho1', 'etecho2', 'etecho3']:
        for col3 in ['eviv1', 'eviv2', 'eviv3']:
            new_col_name = 'new_{}_x_{}_x_{}'.format(col1, col2, col3)
            df_train[new_col_name] = df_train[col1] * df_train[col2] * df_train[col3]
            df_test[new_col_name] = df_test[col1] * df_test[col2] * df_test[col3]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 307) (23856, 306)

# %% [markdown]
# * I want to mix electricity and energy features -> energy features

# %%
for col1 in ['public', 'planpri', 'noelec', 'coopele']:
    for col2 in ['energcocinar1', 'energcocinar2', 'energcocinar3', 'energcocinar4']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %% [markdown]
# * I want to mix toilet and rubbish disposal features -> other_infra features

# %%
for col1 in ['sanitario1', 'sanitario2', 'sanitario3', 'sanitario5', 'sanitario6']:
    for col2 in ['elimbasu1', 'elimbasu2', 'elimbasu3', 'elimbasu4', 'elimbasu5', 'elimbasu6']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %% [markdown]
# * I want to mix toilet and water provision features -> water features

# %%
for col1 in ['abastaguadentro', 'abastaguafuera', 'abastaguano']:
    for col2 in ['sanitario1', 'sanitario2', 'sanitario3', 'sanitario5', 'sanitario6']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 368) (23856, 367)

# %% [markdown]
# * I want mix education and area features -> education_zone_features

# %%
for col1 in ['area1', 'area2']:
    for col2 in ['instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %% [markdown]
# * Mix region and education

# %%
for col1 in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
    for col2 in ['instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 440) (23856, 439)

# %% [markdown]
# * Multiply television / mobilephone / computer / tabulet / refrigerator -> electronics features

# %%
df_train['electronics'] = df_train['computer'] * df_train['mobilephone'] * df_train['television'] * df_train['v18q'] * df_train['refrig']
df_test['electronics'] = df_test['computer'] * df_test['mobilephone'] * df_test['television'] * df_test['v18q'] * df_test['refrig']

df_train['no_appliances'] = df_train['refrig'] + df_train['computer'] + df_train['television'] + df_train['mobilephone']
df_test['no_appliances'] = df_test['refrig'] + df_test['computer'] + df_test['television'] + df_test['mobilephone']

# %% [markdown]
# * Mix wall material of roof, floor, wall

# %%
for col1 in ['paredblolad', 'paredzocalo', 'paredpreb', 'pareddes', 'paredmad', 'paredzinc', 'paredfibras', 'paredother']:
    for col2 in ['pisomoscer', 'pisocemento', 'pisoother', 'pisonatur', 'pisonotiene', 'pisomadera']:
        new_col_name = 'new_{}_x_{}'.format(col, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

for col1 in ['pisomoscer', 'pisocemento', 'pisoother', 'pisonatur', 'pisonotiene', 'pisomadera']:
    for col2 in ['techozinc', 'techoentrepiso', 'techocane', 'techootro']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

for col1 in ['paredblolad', 'paredzocalo', 'paredpreb', 'pareddes', 'paredmad', 'paredzinc', 'paredfibras', 'paredother']:
    for col2 in ['techozinc', 'techoentrepiso', 'techocane', 'techootro']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]
    
for col1 in ['paredblolad', 'paredzocalo', 'paredpreb', 'pareddes', 'paredmad', 'paredzinc', 'paredfibras', 'paredother']:
    for col2 in ['pisomoscer', 'pisocemento', 'pisoother', 'pisonatur', 'pisonotiene', 'pisomadera']:
        for col3 in ['techozinc', 'techoentrepiso', 'techocane', 'techootro']:
            new_col_name = 'new_{}_x_{}_x_{}'.format(col1, col2, col3)
            df_train[new_col_name] = df_train[col1] * df_train[col2] * df_train[col3]
            df_test[new_col_name] = df_test[col1] * df_test[col2] * df_test[col3]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 696) (23856, 695)

# %% [markdown]
# * Wow! Without any aggregation features, we have 446 features for now. Actually mixing the materials of walls make thousands of features. I don't want to do that because of computational costs!
#
# ### Remove feature with only one value

# %%
cols_with_only_one_value = []
for col in df_train.columns:
    if col == 'Target':
        continue
    if df_train[col].value_counts().shape[0] == 1 or df_test[col].value_counts().shape[0] == 1:
        print(col)
        cols_with_only_one_value.append(col)
# Out:
# elimbasu5
# new_planpri_x_energcocinar1
# new_planpri_x_energcocinar2
# new_planpri_x_energcocinar3
# new_planpri_x_energcocinar4
# new_noelec_x_energcocinar2
# new_sanitario1_x_elimbasu4
# new_sanitario1_x_elimbasu5
# new_sanitario1_x_elimbasu6
# new_sanitario2_x_elimbasu4
# new_sanitario2_x_elimbasu5
# new_sanitario2_x_elimbasu6
# new_sanitario3_x_elimbasu5
# new_sanitario5_x_elimbasu4
# new_sanitario5_x_elimbasu5
# new_sanitario5_x_elimbasu6
# new_sanitario6_x_elimbasu2
# new_sanitario6_x_elimbasu4
# new_sanitario6_x_elimbasu5
# new_sanitario6_x_elimbasu6
# new_abastaguafuera_x_sanitario6
# new_abastaguano_x_sanitario2
# new_abastaguano_x_sanitario6
# new_new_rez_esc_per_hhsize_x_pisoother
# new_new_rez_esc_per_hhsize_x_pisonatur
# new_new_rez_esc_per_hhsize_x_pisonotiene
# new_new_rez_esc_per_hhsize_x_pisomadera
# new_pisocemento_x_techocane
# new_pisocemento_x_techootro
# new_pisoother_x_techoentrepiso
# new_pisoother_x_techocane
# new_pisoother_x_techootro
# new_pisonatur_x_techozinc
# new_pisonatur_x_techoentrepiso
# new_pisonatur_x_techocane
# new_pisonatur_x_techootro
# new_pisonotiene_x_techoentrepiso
# new_pisonotiene_x_techocane
# new_pisonotiene_x_techootro
# new_pisomadera_x_techocane
# new_pisomadera_x_techootro
# new_paredzocalo_x_techoentrepiso
# new_paredzocalo_x_techocane
# new_paredzocalo_x_techootro
# new_paredpreb_x_techootro
# new_pareddes_x_techoentrepiso
# new_pareddes_x_techocane
# new_pareddes_x_techootro
# new_paredmad_x_techocane
# new_paredmad_x_techootro
# new_paredzinc_x_techoentrepiso
# new_paredzinc_x_techocane
# new_paredzinc_x_techootro
# new_paredfibras_x_techoentrepiso
# new_paredfibras_x_techootro
# new_paredother_x_techoentrepiso
# new_paredother_x_techocane
# new_paredother_x_techootro
# new_paredblolad_x_pisocemento_x_techocane
# new_paredblolad_x_pisocemento_x_techootro
# new_paredblolad_x_pisoother_x_techoentrepiso
# new_paredblolad_x_pisoother_x_techocane
# new_paredblolad_x_pisoother_x_techootro
# new_paredblolad_x_pisonatur_x_techozinc
# new_paredblolad_x_pisonatur_x_techoentrepiso
# new_paredblolad_x_pisonatur_x_techocane
# new_paredblolad_x_pisonatur_x_techootro
# new_paredblolad_x_pisonotiene_x_techozinc
# new_paredblolad_x_pisonotiene_x_techoentrepiso
# new_paredblolad_x_pisonotiene_x_techocane
# new_paredblolad_x_pisonotiene_x_techootro
# new_paredblolad_x_pisomadera_x_techocane
# new_paredblolad_x_pisomadera_x_techootro
# new_paredzocalo_x_pisomoscer_x_techoentrepiso
# new_paredzocalo_x_pisomoscer_x_techocane
# new_paredzocalo_x_pisomoscer_x_techootro
# new_paredzocalo_x_pisocemento_x_techoentrepiso
# new_paredzocalo_x_pisocemento_x_techocane
# new_paredzocalo_x_pisocemento_x_techootro
# new_paredzocalo_x_pisoother_x_techozinc
# new_paredzocalo_x_pisoother_x_techoentrepiso
# new_paredzocalo_x_pisoother_x_techocane
# new_paredzocalo_x_pisoother_x_techootro
# new_paredzocalo_x_pisonatur_x_techozinc
# new_paredzocalo_x_pisonatur_x_techoentrepiso
# new_paredzocalo_x_pisonatur_x_techocane
# new_paredzocalo_x_pisonatur_x_techootro
# new_paredzocalo_x_pisonotiene_x_techoentrepiso
# new_paredzocalo_x_pisonotiene_x_techocane
# new_paredzocalo_x_pisonotiene_x_techootro
# new_paredzocalo_x_pisomadera_x_techoentrepiso
# new_paredzocalo_x_pisomadera_x_techocane
# new_paredzocalo_x_pisomadera_x_techootro
# new_paredpreb_x_pisomoscer_x_techootro
# new_paredpreb_x_pisocemento_x_techoentrepiso
# new_paredpreb_x_pisocemento_x_techocane
# new_paredpreb_x_pisocemento_x_techootro
# new_paredpreb_x_pisoother_x_techoentrepiso
# new_paredpreb_x_pisoother_x_techocane
# new_paredpreb_x_pisoother_x_techootro
# new_paredpreb_x_pisonatur_x_techozinc
# new_paredpreb_x_pisonatur_x_techoentrepiso
# new_paredpreb_x_pisonatur_x_techocane
# new_paredpreb_x_pisonatur_x_techootro
# new_paredpreb_x_pisonotiene_x_techoentrepiso
# new_paredpreb_x_pisonotiene_x_techocane
# new_paredpreb_x_pisonotiene_x_techootro
# new_paredpreb_x_pisomadera_x_techoentrepiso
# new_paredpreb_x_pisomadera_x_techocane
# new_paredpreb_x_pisomadera_x_techootro
# new_pareddes_x_pisomoscer_x_techozinc
# new_pareddes_x_pisomoscer_x_techoentrepiso
# new_pareddes_x_pisomoscer_x_techocane
# new_pareddes_x_pisomoscer_x_techootro
# new_pareddes_x_pisocemento_x_techoentrepiso
# new_pareddes_x_pisocemento_x_techocane
# new_pareddes_x_pisocemento_x_techootro
# new_pareddes_x_pisoother_x_techozinc
# new_pareddes_x_pisoother_x_techoentrepiso
# new_pareddes_x_pisoother_x_techocane
# new_pareddes_x_pisoother_x_techootro
# new_pareddes_x_pisonatur_x_techozinc
# new_pareddes_x_pisonatur_x_techoentrepiso
# new_pareddes_x_pisonatur_x_techocane
# new_pareddes_x_pisonatur_x_techootro
# new_pareddes_x_pisonotiene_x_techoentrepiso
# new_pareddes_x_pisonotiene_x_techocane
# new_pareddes_x_pisonotiene_x_techootro
# new_pareddes_x_pisomadera_x_techozinc
# new_pareddes_x_pisomadera_x_techoentrepiso
# new_pareddes_x_pisomadera_x_techocane
# new_pareddes_x_pisomadera_x_techootro
# new_paredmad_x_pisomoscer_x_techocane
# new_paredmad_x_pisomoscer_x_techootro
# new_paredmad_x_pisocemento_x_techocane
# new_paredmad_x_pisocemento_x_techootro
# new_paredmad_x_pisoother_x_techozinc
# new_paredmad_x_pisoother_x_techoentrepiso
# new_paredmad_x_pisoother_x_techocane
# new_paredmad_x_pisoother_x_techootro
# new_paredmad_x_pisonatur_x_techozinc
# new_paredmad_x_pisonatur_x_techoentrepiso
# new_paredmad_x_pisonatur_x_techocane
# new_paredmad_x_pisonatur_x_techootro
# new_paredmad_x_pisonotiene_x_techoentrepiso
# new_paredmad_x_pisonotiene_x_techocane
# new_paredmad_x_pisonotiene_x_techootro
# new_paredmad_x_pisomadera_x_techocane
# new_paredmad_x_pisomadera_x_techootro
# new_paredzinc_x_pisomoscer_x_techoentrepiso
# new_paredzinc_x_pisomoscer_x_techocane
# new_paredzinc_x_pisomoscer_x_techootro
# new_paredzinc_x_pisocemento_x_techoentrepiso
# new_paredzinc_x_pisocemento_x_techocane
# new_paredzinc_x_pisocemento_x_techootro
# new_paredzinc_x_pisoother_x_techozinc
# new_paredzinc_x_pisoother_x_techoentrepiso
# new_paredzinc_x_pisoother_x_techocane
# new_paredzinc_x_pisoother_x_techootro
# new_paredzinc_x_pisonatur_x_techozinc
# new_paredzinc_x_pisonatur_x_techoentrepiso
# new_paredzinc_x_pisonatur_x_techocane
# new_paredzinc_x_pisonatur_x_techootro
# new_paredzinc_x_pisonotiene_x_techoentrepiso
# new_paredzinc_x_pisonotiene_x_techocane
# new_paredzinc_x_pisonotiene_x_techootro
# new_paredzinc_x_pisomadera_x_techoentrepiso
# new_paredzinc_x_pisomadera_x_techocane
# new_paredzinc_x_pisomadera_x_techootro
# new_paredfibras_x_pisomoscer_x_techoentrepiso
# new_paredfibras_x_pisomoscer_x_techocane
# new_paredfibras_x_pisomoscer_x_techootro
# new_paredfibras_x_pisocemento_x_techoentrepiso
# new_paredfibras_x_pisocemento_x_techocane
# new_paredfibras_x_pisocemento_x_techootro
# new_paredfibras_x_pisoother_x_techozinc
# new_paredfibras_x_pisoother_x_techoentrepiso
# new_paredfibras_x_pisoother_x_techocane
# new_paredfibras_x_pisoother_x_techootro
# new_paredfibras_x_pisonatur_x_techozinc
# new_paredfibras_x_pisonatur_x_techoentrepiso
# new_paredfibras_x_pisonatur_x_techocane
# new_paredfibras_x_pisonatur_x_techootro
# new_paredfibras_x_pisonotiene_x_techozinc
# new_paredfibras_x_pisonotiene_x_techoentrepiso
# new_paredfibras_x_pisonotiene_x_techocane
# new_paredfibras_x_pisonotiene_x_techootro
# new_paredfibras_x_pisomadera_x_techozinc
# new_paredfibras_x_pisomadera_x_techoentrepiso
# new_paredfibras_x_pisomadera_x_techocane
# new_paredfibras_x_pisomadera_x_techootro
# new_paredother_x_pisomoscer_x_techoentrepiso
# new_paredother_x_pisomoscer_x_techocane
# new_paredother_x_pisomoscer_x_techootro
# new_paredother_x_pisocemento_x_techoentrepiso
# new_paredother_x_pisocemento_x_techocane
# new_paredother_x_pisocemento_x_techootro
# new_paredother_x_pisoother_x_techozinc
# new_paredother_x_pisoother_x_techoentrepiso
# new_paredother_x_pisoother_x_techocane
# new_paredother_x_pisoother_x_techootro
# new_paredother_x_pisonatur_x_techozinc
# new_paredother_x_pisonatur_x_techoentrepiso
# new_paredother_x_pisonatur_x_techocane
# new_paredother_x_pisonatur_x_techootro
# new_paredother_x_pisonotiene_x_techozinc
# new_paredother_x_pisonotiene_x_techoentrepiso
# new_paredother_x_pisonotiene_x_techocane
# new_paredother_x_pisonotiene_x_techootro
# new_paredother_x_pisomadera_x_techozinc
# new_paredother_x_pisomadera_x_techoentrepiso
# new_paredother_x_pisomadera_x_techocane
# new_paredother_x_pisomadera_x_techootro

# %% [markdown]
# * Let's remove them!

# %%
df_train.drop(cols_with_only_one_value, axis=1, inplace=True)
df_test.drop(cols_with_only_one_value, axis=1, inplace=True)

# %% [markdown]
# ### Check whether both train and test have same features

# %%
cols_train = np.array(sorted([col for col in df_train.columns if col != 'Target']))
cols_test = np.array(sorted(df_test.columns))

# %%
(cols_train == cols_test).sum() == len(cols_train)
# Out:
# np.True_

# %% [markdown]
# * Good, Let's move!
#
# ## 2.4 aggregation features
#
# * In this competition, each samples are member of specific household(idhogar). So let's aggregate based on 'idhogar' values.
#
# ### Aggregation for family features

# %%
def max_min(x):
    return x.max() - x.min()

# %%
agg_train = pd.DataFrame()
agg_test = pd.DataFrame()

for item in tqdm(family_size_features):
    for i, function in enumerate(['mean', 'std', 'min', 'max', 'sum', 'count', max_min]):
        group_train = df_train[item].groupby(df_train['idhogar']).agg(function)
        group_test = df_test[item].groupby(df_test['idhogar']).agg(function)

        if i == 6:
            new_col = item + '_new_' + 'max_min'
        else:
            new_col = item + '_new_' + function
        agg_train[new_col] = group_train
        agg_test[new_col] = group_test

print('new aggregate train set has {} rows, and {} features'.format(agg_train.shape[0], agg_train.shape[1]))
print('new aggregate test set has {} rows, and {} features'.format(agg_test.shape[0], agg_test.shape[1]))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# 100%|██████████| 15/15 [00:08<00:00,  1.80it/s]
# new aggregate train set has 2988 rows, and 105 features
# new aggregate test set has 7352 rows, and 105 features

# %%
aggr_list = ['rez_esc', 'dis', 'male', 'female', 'estadocivil1', 'estadocivil2', 'estadocivil3', 'estadocivil4', 'estadocivil5', 'estadocivil6', 'estadocivil7', 'parentesco2', 'parentesco3', 'parentesco4', 'parentesco5', 'parentesco6', 'parentesco7', 'parentesco8', 'parentesco9', 'parentesco10', 'parentesco11', 'parentesco12', 'instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9', 'epared1', 'epared2', 'epared3', 'etecho1', 'etecho2', 'etecho3', 'eviv1', 'eviv2', 'eviv3', 'refrig', 'television', 'mobilephone', 'area1', 'area2', 'v18q', 'edjef']

for item in tqdm(aggr_list):
    for function in ['count', 'sum']:
        group_train = df_train[item].groupby(df_train['idhogar']).agg(function)
        group_test = df_test[item].groupby(df_test['idhogar']).agg(function)
        new_col = item + '_new1_' + function
        agg_train[new_col] = group_train
        agg_test[new_col] = group_test
print('new aggregate train set has {} rows, and {} features'.format(agg_train.shape[0], agg_train.shape[1]))
print('new aggregate test set has {} rows, and {} features'.format(agg_test.shape[0], agg_test.shape[1]))
# Out:
# 100%|██████████| 47/47 [00:01<00:00, 40.72it/s]
# new aggregate train set has 2988 rows, and 199 features
# new aggregate test set has 7352 rows, and 199 features

# %%
aggr_list = ['escolari', 'age', 'escolari_age', 'dependency', 'bedrooms', 'overcrowding', 'rooms', 'qmobilephone', 'v18q1']

for item in tqdm(aggr_list):
    for function in ['mean', 'std', 'min', 'max', 'sum', 'count', max_min]:
        group_train = df_train[item].groupby(df_train['idhogar']).agg(function)
        group_test = df_test[item].groupby(df_test['idhogar']).agg(function)
        if i == 6:
            new_col = item + '_new2_' + 'max_min'
        else:
            new_col = item + '_new2_' + function
        agg_train[new_col] = group_train
        agg_test[new_col] = group_test

print('new aggregate train set has {} rows, and {} features'.format(agg_train.shape[0], agg_train.shape[1]))
print('new aggregate test set has {} rows, and {} features'.format(agg_test.shape[0], agg_test.shape[1]))
# Out:
# 100%|██████████| 9/9 [00:04<00:00,  1.86it/s]
# new aggregate train set has 2988 rows, and 208 features
# new aggregate test set has 7352 rows, and 208 features

# %%
agg_test = agg_test.reset_index()
agg_train = agg_train.reset_index()

train_agg = pd.merge(df_train, agg_train, on='idhogar')
test = pd.merge(df_test, agg_test, on='idhogar')

train_agg.fillna(value=0, inplace=True)
test.fillna(value=0, inplace=True)

print('train shape:', train_agg.shape, 'test shape:', test.shape)
# Out:
# train shape: (9557, 691) test shape: (23856, 690)

# %%
aggr_list = ['rez_esc', 'dis', 'male', 'female', 'estadocivil1', 'estadocivil2', 'estadocivil3', 'estadocivil4', 'estadocivil5', 'estadocivil6', 'estadocivil7', 'parentesco2', 'parentesco3', 'parentesco4', 'parentesco5', 'parentesco6', 'parentesco7', 'parentesco8', 'parentesco9', 'parentesco10', 'parentesco11', 'parentesco12', 'instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9', 'epared1', 'epared2', 'epared3', 'etecho1', 'etecho2', 'etecho3', 'eviv1', 'eviv2', 'eviv3', 'refrig', 'television', 'mobilephone', 'area1', 'area2', 'v18q', 'edjef']

for lugar in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
    group_train = df_train[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_train.columns = [lugar, 'idhogar'] + ['new3_{}_idhogar_{}'.format(lugar, col) for col in group_train][2:]

    group_test = df_test[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_test.columns = [lugar, 'idhogar'] + ['new3_{}_idhogar_{}'.format(lugar, col) for col in group_test][2:]

    train_agg = pd.merge(train_agg, group_train, on=[lugar, 'idhogar'])
    test = pd.merge(test, group_test, on=[lugar, 'idhogar'])

print('train shape:', train_agg.shape, 'test shape:', test.shape)
# Out:
# train shape: (9557, 973) test shape: (23856, 972)

# %%
aggr_list = ['rez_esc', 'dis', 'male', 'female', 'estadocivil1', 'estadocivil2', 'estadocivil3', 'estadocivil4', 'estadocivil5', 'estadocivil6', 'estadocivil7', 'parentesco2', 'parentesco3', 'parentesco4', 'parentesco5', 'parentesco6', 'parentesco7', 'parentesco8', 'parentesco9', 'parentesco10', 'parentesco11', 'parentesco12', 'instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9', 'epared1', 'epared2', 'epared3', 'etecho1', 'etecho2', 'etecho3', 'eviv1', 'eviv2', 'eviv3', 'refrig', 'television', 'mobilephone', 'area1', 'area2', 'v18q', 'edjef']

for lugar in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
    group_train = df_train[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_train.columns = [lugar, 'idhogar'] + ['new4_{}_idhogar_{}'.format(lugar, col) for col in group_train][2:]

    group_test = df_test[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_test.columns = [lugar, 'idhogar'] + ['new4_{}_idhogar_{}'.format(lugar, col) for col in group_test][2:]

    train_agg = pd.merge(train_agg, group_train, on=[lugar, 'idhogar'])
    test = pd.merge(test, group_test, on=[lugar, 'idhogar'])

print('train shape:', train_agg.shape, 'test shape:', test.shape)
# Out:
# train shape: (9557, 1255) test shape: (23856, 1254)

# %%
cols_nums = ['age', 'meaneduc', 'dependency', 'hogar_nin', 'hogar_adul', 'hogar_mayor', 'hogar_total', 'bedrooms', 'overcrowding']

for function in tqdm(['mean', 'std', 'min', 'max', 'sum', 'count', max_min]):
    for lugar in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
        group_train = df_train[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).agg(function).reset_index()
        group_train.columns = [lugar, 'idhogar'] + ['new5_{}_idhogar_{}_{}'.format(lugar, col, function) for col in group_train][2:]

        group_test = df_test[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).agg(function).reset_index()
        group_test.columns = [lugar, 'idhogar'] + ['new5_{}_idhogar_{}_{}'.format(lugar, col, function) for col in group_test][2:]

        train_agg = pd.merge(train_agg, group_train, on=[lugar, 'idhogar'])
        test = pd.merge(test, group_test, on=[lugar, 'idhogar'])
    
print('train shape:', train_agg.shape, 'test shape:', test.shape)
# Out:
# 100%|██████████| 7/7 [03:01<00:00, 25.95s/it]
# train shape: (9557, 3229) test shape: (23856, 3228)

# %% [markdown]
# * According to data descriptions, ONLY the heads of household are used in scoring.
# * All household members are included in test + the sample submission, but only heads of households are scored.

# %%
train = train_agg.query('parentesco1==1')

# %%
train['dependency'].replace(np.inf, 0, inplace=True)
test['dependency'].replace(np.inf, 0, inplace=True)

# %%
submission = test[['Id']]

train.drop(columns=['idhogar', 'Id', 'agesq', 'hogar_adul', 'SQBescolari', 'SQBage', 'SQBhogar_total', 'SQBedjefe', 'SQBhogar_nin', 'SQBovercrowding', 'SQBdependency', 'SQBmeaned'], inplace=True)
test.drop(columns=['idhogar', 'Id', 'agesq', 'hogar_adul', 'SQBescolari', 'SQBage', 'SQBhogar_total', 'SQBedjefe', 'SQBhogar_nin', 'SQBovercrowding', 'SQBdependency', 'SQBmeaned'], inplace=True)

correlation = train.corr()
correlation = correlation['Target'].sort_values(ascending=False)

# %%
print('final_data size', train.shape, test.shape)
# Out:
# final_data size (2973, 3217) (23856, 3216)

# %%
print(f'The most 20 positive feature: \n{correlation.head(40)}')
# Out:
# The most 20 positive feature:
# Target                                1.000000
# new5_lugar6_idhogar_edjef_max         0.334254
# new5_lugar4_idhogar_edjef_max         0.334254
# new5_lugar2_idhogar_edjef_max         0.334254
# new5_lugar3_idhogar_edjef_max         0.334254
# new5_lugar1_idhogar_edjef_max         0.334254
# new5_lugar5_idhogar_edjef_max         0.334254
# new5_lugar1_idhogar_edjef_mean        0.333873
# new5_lugar2_idhogar_edjef_mean        0.333873
# new5_lugar6_idhogar_edjef_mean        0.333873
# new5_lugar4_idhogar_edjef_mean        0.333873
# new5_lugar5_idhogar_edjef_mean        0.333873
# new5_lugar3_idhogar_edjef_mean        0.333873
# edjef                                 0.333791
# new5_lugar6_idhogar_edjef_min         0.333791
# new5_lugar4_idhogar_edjef_min         0.333791
# new5_lugar5_idhogar_edjef_min         0.333791
# new5_lugar3_idhogar_edjef_min         0.333791
# new5_lugar1_idhogar_edjef_min         0.333791
# new5_lugar2_idhogar_edjef_min         0.333791
# escolari                              0.333791
# meaneduc                              0.331489
# new5_lugar6_idhogar_instlevel8_max    0.317815
# new5_lugar1_idhogar_instlevel8_max    0.317815
# new5_lugar3_idhogar_instlevel8_max    0.317815
# new5_lugar5_idhogar_instlevel8_max    0.317815
# new5_lugar2_idhogar_instlevel8_max    0.317815
# new5_lugar4_idhogar_instlevel8_max    0.317815
# phones-per-capita                     0.299026
# new5_lugar1_idhogar_instlevel8_std    0.298251
# new5_lugar2_idhogar_instlevel8_std    0.298251
# new5_lugar6_idhogar_instlevel8_std    0.298251
# new5_lugar5_idhogar_instlevel8_std    0.298251
# new5_lugar4_idhogar_instlevel8_std    0.298251
# new5_lugar3_idhogar_instlevel8_std    0.298251
# new_epared3_x_eviv3                   0.298196
# cielorazo                             0.295249
# new4_lugar3_idhogar_instlevel8        0.294277
# new4_lugar6_idhogar_instlevel8        0.294277
# new5_lugar3_idhogar_instlevel8_sum    0.294277
# Name: Target, dtype: float64

# %%
print(f'The most 20 negative feature: \n{correlation.tail(20)}')
# Out:
# The most 20 negative feature:
# new5_lugar5_idhogar_television_<function max_min at 0x000002D1BB136E80>    NaN
# new5_lugar5_idhogar_mobilephone_<function max_min at 0x000002D1BB136E80>   NaN
# new5_lugar5_idhogar_area1_<function max_min at 0x000002D1BB136E80>         NaN
# new5_lugar5_idhogar_area2_<function max_min at 0x000002D1BB136E80>         NaN
# new5_lugar5_idhogar_v18q_<function max_min at 0x000002D1BB136E80>          NaN
# new5_lugar6_idhogar_epared1_<function max_min at 0x000002D1BB136E80>       NaN
# new5_lugar6_idhogar_epared2_<function max_min at 0x000002D1BB136E80>       NaN
# new5_lugar6_idhogar_epared3_<function max_min at 0x000002D1BB136E80>       NaN
# new5_lugar6_idhogar_etecho1_<function max_min at 0x000002D1BB136E80>       NaN
# new5_lugar6_idhogar_etecho2_<function max_min at 0x000002D1BB136E80>       NaN
# new5_lugar6_idhogar_etecho3_<function max_min at 0x000002D1BB136E80>       NaN
# new5_lugar6_idhogar_eviv1_<function max_min at 0x000002D1BB136E80>         NaN
# new5_lugar6_idhogar_eviv2_<function max_min at 0x000002D1BB136E80>         NaN
# new5_lugar6_idhogar_eviv3_<function max_min at 0x000002D1BB136E80>         NaN
# new5_lugar6_idhogar_refrig_<function max_min at 0x000002D1BB136E80>        NaN
# new5_lugar6_idhogar_television_<function max_min at 0x000002D1BB136E80>    NaN
# new5_lugar6_idhogar_mobilephone_<function max_min at 0x000002D1BB136E80>   NaN
# new5_lugar6_idhogar_area1_<function max_min at 0x000002D1BB136E80>         NaN
# new5_lugar6_idhogar_area2_<function max_min at 0x000002D1BB136E80>         NaN
# new5_lugar6_idhogar_v18q_<function max_min at 0x000002D1BB136E80>          NaN
# Name: Target, dtype: float64

# %% [markdown]
# # 4. Feature selection using shap

# %%
binary_cat_features = [col for col in train.columns if train[col].value_counts().shape[0] == 2]
object_features = ['edjefe', 'edjefa']

categorical_feats = binary_cat_features + object_features

# %%
def evaluate_macroF1_lgb(truth, predictions):
    pred_labels = predictions.reshape(len(np.unique(truth)), -1).argmax(axis=0)
    f1 = f1_score(truth, pred_labels, average='macro')
    return ('macroF1', f1, True)

# %%
y = train['Target']
train.drop(columns=['Target'], inplace=True)

# %%
def print_execution_time(start):
    end = time.time()
    hours, rem = divmod(end-start, 3600)
    minutes, seconds = divmod(rem, 60)
    print('*' * 20, 'Execution ended in {:0>2}h {:0>2}m {:05.2f}s'.format(int(hours), int(minutes), seconds), '*'*20)

# %%
def extract_good_features_using_shap_LGB(params, SEED):
    clf = lgb.LGBMClassifier(objective='multiclass',
                             random_state=1989,
                             max_depth=params['max_depth'],
                             learning_rate=params['learning_rate'],
                            #  silent=True,
                             verbose=-1,
                             metric='multi_logloss',
                             n_jobs=-1,
                             n_estimators=10000,
                             class_weight='balanced',
                             colsample_bytree=params['colsample_bytree'],
                             min_split_gain=params['min_split_gain'],
                             bagging_freq=params['bagging_freq'],
                             min_child_weight=params['min_child_weight'],
                             num_leaves=params['num_leaves'],
                             subsample=params['subsample'],
                             reg_alpha=params['reg_alpha'],
                             reg_lambda=params['reg_lambda'],
                             num_class=len(np.unique(y)),
                             bagging_seed=SEED,
                             seed=SEED,
                             )
    
    kfold = 5
    kf = StratifiedKFold(n_splits=kfold, shuffle=True)
    feat_importance_df = pd.DataFrame()

    for i, (train_index, test_index) in enumerate(kf.split(train, y)):
        print('=' * 30, '{} of {} folds'.format(i+1, kfold), '='*30)
        start = time.time()
        X_train, X_val = train.iloc[train_index], train.iloc[test_index]
        y_train, y_val = y.iloc[train_index], y.iloc[test_index]
        clf.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)], eval_metric=evaluate_macroF1_lgb, categorical_feature=categorical_feats,
                callbacks=[lgb.early_stopping(stopping_rounds=500), lgb.log_evaluation(period=500)])
        shap_values = shap.TreeExplainer(clf.booster_).shap_values(X_train)
        fold_importance_df = pd.DataFrame()
        fold_importance_df['feature'] = X_train.columns
        # fold_importance_df['shap_values'] = abs(np.array(shap_values)[:, :].mean(1).mean(0))
        shap_arr = np.abs(np.array(shap_values))
        if shap_arr.shape[0] == len(X_train):  
            fold_importance_df['shap_values'] = shap_arr.mean(axis=0).mean(axis=-1)
        else:  
            fold_importance_df['shap_values'] = shap_arr.mean(axis=1).mean(axis=0)

        fold_importance_df['feat_imp'] = clf.feature_importances_
        feat_importance_df = pd.concat([feat_importance_df, fold_importance_df])
        print_execution_time(start)
    
    feat_importance_df_shap = feat_importance_df.groupby('feature').mean().sort_values('shap_values', ascending=False).reset_index()
    
    return feat_importance_df_shap

# %%
total_shap_df = pd.DataFrame()
NUM_ITERATIONS = 50
for SEED in range(NUM_ITERATIONS):
    print('#' * 40, '{} of {} iterations'.format(SEED+1, NUM_ITERATIONS), '#'*40)
    params = {'max_depth': np.random.choice([5, 6, 7, 8, 10, 12, -1]),
              'learning_rate': np.random.rand() * 0.02,
              'colsample_bytree': np.random.rand() * (1 - 0.5) + 0.5,
              'subsample': np.random.rand() * (1 - 0.5) + 0.5,
              'min_split_gain': np.random.rand() * 0.2,
              'num_leaves': np.random.choice([32, 48, 64]),
              'reg_alpha': np.random.rand() * 2,
              'reg_lambda': np.random.rand() * 2,
              'bagging_freq': np.random.randint(4) + 1,
              'min_child_weight': np.random.randint(100) + 20
            }
    temp_shap_df = extract_good_features_using_shap_LGB(params, SEED)
    total_shap_df = pd.concat([total_shap_df, temp_shap_df])
# Out:
# ######################################## 1 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.08182	training's macroF1: 0.215704	valid_1's multi_logloss: 1.09782	valid_1's macroF1: 0.225437
# Early stopping, best iteration is:
# [347]	training's multi_logloss: 1.11296	training's macroF1: 0.21288	valid_1's multi_logloss: 1.10397	valid_1's macroF1: 0.233806
# ******************** Execution ended in 00h 00m 28.98s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.09012	training's macroF1: 0.212569	valid_1's multi_logloss: 1.08831	valid_1's macroF1: 0.219178
# Early stopping, best iteration is:
# [457]	training's multi_logloss: 1.09759	training's macroF1: 0.215786	valid_1's multi_logloss: 1.09225	valid_1's macroF1: 0.221857
# ******************** Execution ended in 00h 00m 35.81s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.08122	training's macroF1: 0.206334	valid_1's multi_logloss: 1.06884	valid_1's macroF1: 0.221012
# Early stopping, best iteration is:
# [10]	training's multi_logloss: 1.36138	training's macroF1: 0.208477	valid_1's multi_logloss: 1.35061	valid_1's macroF1: 0.229301
# ******************** Execution ended in 00h 00m 21.74s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.07231	training's macroF1: 0.206603	valid_1's multi_logloss: 1.10297	valid_1's macroF1: 0.181372
# Early stopping, best iteration is:
# [11]	training's multi_logloss: 1.35671	training's macroF1: 0.205535	valid_1's multi_logloss: 1.34919	valid_1's macroF1: 0.194412
# ******************** Execution ended in 00h 00m 22.36s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.07629	training's macroF1: 0.20183	valid_1's multi_logloss: 1.07357	valid_1's macroF1: 0.23359
# Early stopping, best iteration is:
# [276]	training's multi_logloss: 1.12807	training's macroF1: 0.196424	valid_1's multi_logloss: 1.09055	valid_1's macroF1: 0.241537
# ******************** Execution ended in 00h 00m 33.80s ********************
# ######################################## 2 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.25483	training's macroF1: 0.20466	valid_1's multi_logloss: 1.23005	valid_1's macroF1: 0.206788
# [1000]	training's multi_logloss: 1.18072	training's macroF1: 0.205791	valid_1's multi_logloss: 1.16328	valid_1's macroF1: 0.210353
# Early stopping, best iteration is:
# [828]	training's multi_logloss: 1.20229	training's macroF1: 0.205152	valid_1's multi_logloss: 1.1804	valid_1's macroF1: 0.220294
# ******************** Execution ended in 00h 01m 04.58s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.26034	training's macroF1: 0.21553	valid_1's multi_logloss: 1.2215	valid_1's macroF1: 0.218223
# [1000]	training's multi_logloss: 1.18846	training's macroF1: 0.214772	valid_1's multi_logloss: 1.14746	valid_1's macroF1: 0.217082
# Early stopping, best iteration is:
# [697]	training's multi_logloss: 1.22825	training's macroF1: 0.216453	valid_1's multi_logloss: 1.1861	valid_1's macroF1: 0.224353
# ******************** Execution ended in 00h 00m 45.51s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.25595	training's macroF1: 0.201964	valid_1's multi_logloss: 1.22826	valid_1's macroF1: 0.193533
# Early stopping, best iteration is:
# [21]	training's multi_logloss: 1.3786	training's macroF1: 0.203343	valid_1's multi_logloss: 1.37568	valid_1's macroF1: 0.218376
# ******************** Execution ended in 00h 00m 21.75s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.26188	training's macroF1: 0.195848	valid_1's multi_logloss: 1.2241	valid_1's macroF1: 0.215519
# Early stopping, best iteration is:
# [15]	training's multi_logloss: 1.38095	training's macroF1: 0.200192	valid_1's multi_logloss: 1.37848	valid_1's macroF1: 0.237184
# ******************** Execution ended in 00h 00m 21.25s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.25877	training's macroF1: 0.19818	valid_1's multi_logloss: 1.21397	valid_1's macroF1: 0.216945
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 1.38473	training's macroF1: 0.205909	valid_1's multi_logloss: 1.38404	valid_1's macroF1: 0.233116
# ******************** Execution ended in 00h 00m 15.40s ********************
# ######################################## 3 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.18466	training's macroF1: 0.20944	valid_1's multi_logloss: 1.11793	valid_1's macroF1: 0.192206
# Early stopping, best iteration is:
# [471]	training's multi_logloss: 1.19024	training's macroF1: 0.207982	valid_1's multi_logloss: 1.12327	valid_1's macroF1: 0.194982
# ******************** Execution ended in 00h 00m 24.32s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.19026	training's macroF1: 0.212243	valid_1's multi_logloss: 1.1124	valid_1's macroF1: 0.18807
# Early stopping, best iteration is:
# [224]	training's multi_logloss: 1.25981	training's macroF1: 0.210647	valid_1's multi_logloss: 1.204	valid_1's macroF1: 0.203672
# ******************** Execution ended in 00h 00m 20.64s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.17801	training's macroF1: 0.201638	valid_1's multi_logloss: 1.15303	valid_1's macroF1: 0.202664
# Early stopping, best iteration is:
# [27]	training's multi_logloss: 1.3626	training's macroF1: 0.204811	valid_1's multi_logloss: 1.35444	valid_1's macroF1: 0.23566
# ******************** Execution ended in 00h 00m 17.19s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.17472	training's macroF1: 0.208435	valid_1's multi_logloss: 1.1563	valid_1's macroF1: 0.240429
# Early stopping, best iteration is:
# [389]	training's multi_logloss: 1.19793	training's macroF1: 0.206951	valid_1's multi_logloss: 1.17529	valid_1's macroF1: 0.24438
# ******************** Execution ended in 00h 00m 24.15s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.181	training's macroF1: 0.194419	valid_1's multi_logloss: 1.13573	valid_1's macroF1: 0.237986
# Early stopping, best iteration is:
# [56]	training's multi_logloss: 1.34095	training's macroF1: 0.202056	valid_1's multi_logloss: 1.32407	valid_1's macroF1: 0.245015
# ******************** Execution ended in 00h 00m 16.02s ********************
# ######################################## 4 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.00266	training's macroF1: 0.207652	valid_1's multi_logloss: 1.0448	valid_1's macroF1: 0.217989
# Early stopping, best iteration is:
# [174]	training's multi_logloss: 1.13306	training's macroF1: 0.203861	valid_1's multi_logloss: 1.10128	valid_1's macroF1: 0.228822
# ******************** Execution ended in 00h 00m 19.90s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.988631	training's macroF1: 0.205137	valid_1's multi_logloss: 1.07437	valid_1's macroF1: 0.218992
# Early stopping, best iteration is:
# [34]	training's multi_logloss: 1.29452	training's macroF1: 0.196495	valid_1's multi_logloss: 1.26979	valid_1's macroF1: 0.234479
# ******************** Execution ended in 00h 00m 19.45s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.00433	training's macroF1: 0.207553	valid_1's multi_logloss: 1.04792	valid_1's macroF1: 0.20159
# Early stopping, best iteration is:
# [20]	training's multi_logloss: 1.33014	training's macroF1: 0.213844	valid_1's multi_logloss: 1.31094	valid_1's macroF1: 0.212526
# ******************** Execution ended in 00h 00m 15.78s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.992655	training's macroF1: 0.198947	valid_1's multi_logloss: 1.0389	valid_1's macroF1: 0.181998
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.38283	training's macroF1: 0.194968	valid_1's multi_logloss: 1.38144	valid_1's macroF1: 0.228473
# ******************** Execution ended in 00h 00m 16.42s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.00279	training's macroF1: 0.194358	valid_1's multi_logloss: 1.07338	valid_1's macroF1: 0.215677
# Early stopping, best iteration is:
# [29]	training's multi_logloss: 1.31063	training's macroF1: 0.188633	valid_1's multi_logloss: 1.28779	valid_1's macroF1: 0.223119
# ******************** Execution ended in 00h 00m 19.72s ********************
# ######################################## 5 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04654	training's macroF1: 0.205115	valid_1's multi_logloss: 1.14575	valid_1's macroF1: 0.215735
# Early stopping, best iteration is:
# [342]	training's multi_logloss: 1.08429	training's macroF1: 0.203864	valid_1's multi_logloss: 1.14176	valid_1's macroF1: 0.21291
# ******************** Execution ended in 00h 00m 22.82s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05184	training's macroF1: 0.19768	valid_1's multi_logloss: 1.05779	valid_1's macroF1: 0.180104
# Early stopping, best iteration is:
# [88]	training's multi_logloss: 1.22136	training's macroF1: 0.2074	valid_1's multi_logloss: 1.1665	valid_1's macroF1: 0.198206
# ******************** Execution ended in 00h 00m 16.05s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05459	training's macroF1: 0.205997	valid_1's multi_logloss: 1.05309	valid_1's macroF1: 0.213183
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 1.36526	training's macroF1: 0.201469	valid_1's multi_logloss: 1.35549	valid_1's macroF1: 0.228219
# ******************** Execution ended in 00h 00m 15.92s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.0576	training's macroF1: 0.195301	valid_1's multi_logloss: 1.05612	valid_1's macroF1: 0.217429
# Early stopping, best iteration is:
# [35]	training's multi_logloss: 1.30369	training's macroF1: 0.192515	valid_1's multi_logloss: 1.2616	valid_1's macroF1: 0.228337
# ******************** Execution ended in 00h 00m 15.73s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04925	training's macroF1: 0.204108	valid_1's multi_logloss: 1.06913	valid_1's macroF1: 0.202492
# Early stopping, best iteration is:
# [470]	training's multi_logloss: 1.05553	training's macroF1: 0.206037	valid_1's multi_logloss: 1.07057	valid_1's macroF1: 0.206887
# ******************** Execution ended in 04h 05m 29.16s ********************
# ######################################## 6 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.09743	training's macroF1: 0.213904	valid_1's multi_logloss: 1.1105	valid_1's macroF1: 0.2526
# Early stopping, best iteration is:
# [99]	training's multi_logloss: 1.25385	training's macroF1: 0.207074	valid_1's multi_logloss: 1.22979	valid_1's macroF1: 0.275473
# ******************** Execution ended in 00h 00m 22.58s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11301	training's macroF1: 0.201504	valid_1's multi_logloss: 1.09573	valid_1's macroF1: 0.169859
# Early stopping, best iteration is:
# [13]	training's multi_logloss: 1.36436	training's macroF1: 0.214136	valid_1's multi_logloss: 1.35301	valid_1's macroF1: 0.209842
# ******************** Execution ended in 00h 00m 18.41s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11152	training's macroF1: 0.204296	valid_1's multi_logloss: 1.07303	valid_1's macroF1: 0.199361
# Early stopping, best iteration is:
# [6]	training's multi_logloss: 1.3763	training's macroF1: 0.208617	valid_1's multi_logloss: 1.37169	valid_1's macroF1: 0.21268
# ******************** Execution ended in 00h 00m 11.26s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.10852	training's macroF1: 0.205473	valid_1's multi_logloss: 1.10322	valid_1's macroF1: 0.210755
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 1.37905	training's macroF1: 0.19599	valid_1's multi_logloss: 1.37639	valid_1's macroF1: 0.222896
# ******************** Execution ended in 00h 00m 07.29s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11678	training's macroF1: 0.21711	valid_1's multi_logloss: 1.07176	valid_1's macroF1: 0.236432
# Early stopping, best iteration is:
# [415]	training's multi_logloss: 1.1326	training's macroF1: 0.219264	valid_1's multi_logloss: 1.07889	valid_1's macroF1: 0.243673
# ******************** Execution ended in 00h 00m 10.49s ********************
# ######################################## 7 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.787603	training's macroF1: 0.204062	valid_1's multi_logloss: 1.0148	valid_1's macroF1: 0.21106
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.38013	training's macroF1: 0.199672	valid_1's multi_logloss: 1.3793	valid_1's macroF1: 0.215703
# ******************** Execution ended in 00h 00m 10.48s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.786335	training's macroF1: 0.212215	valid_1's multi_logloss: 1.00965	valid_1's macroF1: 0.213443
# Early stopping, best iteration is:
# [13]	training's multi_logloss: 1.32048	training's macroF1: 0.203	valid_1's multi_logloss: 1.30936	valid_1's macroF1: 0.225095
# ******************** Execution ended in 00h 00m 08.08s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.786007	training's macroF1: 0.209854	valid_1's multi_logloss: 1.06662	valid_1's macroF1: 0.192672
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 1.36563	training's macroF1: 0.21417	valid_1's multi_logloss: 1.36203	valid_1's macroF1: 0.21632
# ******************** Execution ended in 00h 00m 09.53s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.785833	training's macroF1: 0.193886	valid_1's multi_logloss: 1.01526	valid_1's macroF1: 0.199179
# Early stopping, best iteration is:
# [42]	training's multi_logloss: 1.21768	training's macroF1: 0.193797	valid_1's multi_logloss: 1.19936	valid_1's macroF1: 0.233528
# ******************** Execution ended in 00h 00m 10.38s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.78837	training's macroF1: 0.212227	valid_1's multi_logloss: 1.00722	valid_1's macroF1: 0.216589
# Early stopping, best iteration is:
# [382]	training's multi_logloss: 0.845669	training's macroF1: 0.210687	valid_1's multi_logloss: 1.01313	valid_1's macroF1: 0.227844
# ******************** Execution ended in 00h 00m 17.20s ********************
# ######################################## 8 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.32886	training's macroF1: 0.211611	valid_1's multi_logloss: 1.31035	valid_1's macroF1: 0.198902
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 1.38578	training's macroF1: 0.21897	valid_1's multi_logloss: 1.3856	valid_1's macroF1: 0.204772
# ******************** Execution ended in 00h 00m 07.57s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.33105	training's macroF1: 0.211157	valid_1's multi_logloss: 1.30538	valid_1's macroF1: 0.189068
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 1.38604	training's macroF1: 0.21608	valid_1's multi_logloss: 1.38592	valid_1's macroF1: 0.2258
# ******************** Execution ended in 00h 00m 07.79s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.32596	training's macroF1: 0.210459	valid_1's multi_logloss: 1.32606	valid_1's macroF1: 0.213792
# Early stopping, best iteration is:
# [10]	training's multi_logloss: 1.38496	training's macroF1: 0.205822	valid_1's multi_logloss: 1.3849	valid_1's macroF1: 0.226717
# ******************** Execution ended in 00h 00m 07.56s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.32995	training's macroF1: 0.203563	valid_1's multi_logloss: 1.3165	valid_1's macroF1: 0.227781
# Early stopping, best iteration is:
# [28]	training's multi_logloss: 1.38277	training's macroF1: 0.205752	valid_1's multi_logloss: 1.38184	valid_1's macroF1: 0.241209
# ******************** Execution ended in 00h 00m 08.08s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.3287	training's macroF1: 0.203874	valid_1's multi_logloss: 1.31754	valid_1's macroF1: 0.174555
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 1.38579	training's macroF1: 0.206508	valid_1's multi_logloss: 1.38566	valid_1's macroF1: 0.188562
# ******************** Execution ended in 00h 00m 07.34s ********************
# ######################################## 9 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.53658	training's macroF1: 0.216402	valid_1's multi_logloss: 0.973648	valid_1's macroF1: 0.190129
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 1.36877	training's macroF1: 0.209361	valid_1's multi_logloss: 1.36603	valid_1's macroF1: 0.222652
# ******************** Execution ended in 00h 00m 08.22s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.52579	training's macroF1: 0.194839	valid_1's multi_logloss: 1.02685	valid_1's macroF1: 0.234449
# [1000]	training's multi_logloss: 0.368418	training's macroF1: 0.193827	valid_1's multi_logloss: 1.03347	valid_1's macroF1: 0.243212
# Early stopping, best iteration is:
# [640]	training's multi_logloss: 0.462423	training's macroF1: 0.193681	valid_1's multi_logloss: 1.02425	valid_1's macroF1: 0.241957
# ******************** Execution ended in 00h 00m 18.58s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.539832	training's macroF1: 0.20479	valid_1's multi_logloss: 0.96744	valid_1's macroF1: 0.213168
# Early stopping, best iteration is:
# [6]	training's multi_logloss: 1.33204	training's macroF1: 0.204719	valid_1's multi_logloss: 1.33217	valid_1's macroF1: 0.228761
# ******************** Execution ended in 00h 00m 08.38s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.538772	training's macroF1: 0.213116	valid_1's multi_logloss: 1.03736	valid_1's macroF1: 0.19353
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 1.34955	training's macroF1: 0.207405	valid_1's multi_logloss: 1.35321	valid_1's macroF1: 0.217946
# ******************** Execution ended in 00h 00m 08.34s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.550398	training's macroF1: 0.20745	valid_1's multi_logloss: 0.941894	valid_1's macroF1: 0.218611
# Early stopping, best iteration is:
# [61]	training's multi_logloss: 1.06139	training's macroF1: 0.203429	valid_1's multi_logloss: 1.092	valid_1's macroF1: 0.233532
# ******************** Execution ended in 00h 00m 09.38s ********************
# ######################################## 10 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.25896	training's macroF1: 0.197602	valid_1's multi_logloss: 1.22317	valid_1's macroF1: 0.189854
# Early stopping, best iteration is:
# [115]	training's multi_logloss: 1.34796	training's macroF1: 0.190542	valid_1's multi_logloss: 1.33377	valid_1's macroF1: 0.200349
# ******************** Execution ended in 00h 00m 08.30s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.25449	training's macroF1: 0.202825	valid_1's multi_logloss: 1.22805	valid_1's macroF1: 0.223236
# Early stopping, best iteration is:
# [244]	training's multi_logloss: 1.31023	training's macroF1: 0.205414	valid_1's multi_logloss: 1.28877	valid_1's macroF1: 0.229206
# ******************** Execution ended in 00h 00m 10.59s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.25352	training's macroF1: 0.206273	valid_1's multi_logloss: 1.21506	valid_1's macroF1: 0.165703
# Early stopping, best iteration is:
# [25]	training's multi_logloss: 1.37727	training's macroF1: 0.207762	valid_1's multi_logloss: 1.37388	valid_1's macroF1: 0.171475
# ******************** Execution ended in 00h 00m 08.52s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.26321	training's macroF1: 0.212015	valid_1's multi_logloss: 1.20402	valid_1's macroF1: 0.215656
# Early stopping, best iteration is:
# [270]	training's multi_logloss: 1.3095	training's macroF1: 0.211792	valid_1's multi_logloss: 1.26905	valid_1's macroF1: 0.219442
# ******************** Execution ended in 00h 00m 10.39s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.25877	training's macroF1: 0.217184	valid_1's multi_logloss: 1.23751	valid_1's macroF1: 0.221446
# [1000]	training's multi_logloss: 1.19341	training's macroF1: 0.224277	valid_1's multi_logloss: 1.17568	valid_1's macroF1: 0.217282
# Early stopping, best iteration is:
# [920]	training's multi_logloss: 1.20169	training's macroF1: 0.222041	valid_1's multi_logloss: 1.18264	valid_1's macroF1: 0.22301
# ******************** Execution ended in 00h 00m 19.12s ********************
# ######################################## 11 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13206	training's macroF1: 0.207053	valid_1's multi_logloss: 1.06594	valid_1's macroF1: 0.237161
# Early stopping, best iteration is:
# [14]	training's multi_logloss: 1.36242	training's macroF1: 0.206056	valid_1's multi_logloss: 1.34889	valid_1's macroF1: 0.24389
# ******************** Execution ended in 00h 00m 05.80s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13469	training's macroF1: 0.218254	valid_1's multi_logloss: 1.1043	valid_1's macroF1: 0.199112
# [1000]	training's multi_logloss: 1.07953	training's macroF1: 0.212051	valid_1's multi_logloss: 1.10359	valid_1's macroF1: 0.206755
# Early stopping, best iteration is:
# [577]	training's multi_logloss: 1.12388	training's macroF1: 0.216235	valid_1's multi_logloss: 1.10503	valid_1's macroF1: 0.20907
# ******************** Execution ended in 00h 00m 10.87s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13215	training's macroF1: 0.222685	valid_1's multi_logloss: 1.08754	valid_1's macroF1: 0.231034
# Early stopping, best iteration is:
# [13]	training's multi_logloss: 1.36409	training's macroF1: 0.22038	valid_1's multi_logloss: 1.35494	valid_1's macroF1: 0.25181
# ******************** Execution ended in 00h 00m 05.54s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.12358	training's macroF1: 0.207387	valid_1's multi_logloss: 1.08413	valid_1's macroF1: 0.188383
# Early stopping, best iteration is:
# [186]	training's multi_logloss: 1.20719	training's macroF1: 0.201266	valid_1's multi_logloss: 1.14074	valid_1's macroF1: 0.200749
# ******************** Execution ended in 00h 00m 09.34s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.12546	training's macroF1: 0.203213	valid_1's multi_logloss: 1.12015	valid_1's macroF1: 0.231948
# Early stopping, best iteration is:
# [80]	training's multi_logloss: 1.28207	training's macroF1: 0.206195	valid_1's multi_logloss: 1.24882	valid_1's macroF1: 0.24061
# ******************** Execution ended in 00h 00m 06.55s ********************
# ######################################## 12 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05285	training's macroF1: 0.203757	valid_1's multi_logloss: 1.05712	valid_1's macroF1: 0.1995
# Early stopping, best iteration is:
# [18]	training's multi_logloss: 1.34445	training's macroF1: 0.202994	valid_1's multi_logloss: 1.32563	valid_1's macroF1: 0.216362
# ******************** Execution ended in 00h 00m 06.90s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05222	training's macroF1: 0.207065	valid_1's multi_logloss: 1.08455	valid_1's macroF1: 0.185271
# Early stopping, best iteration is:
# [90]	training's multi_logloss: 1.2305	training's macroF1: 0.211025	valid_1's multi_logloss: 1.19234	valid_1's macroF1: 0.211445
# ******************** Execution ended in 00h 00m 07.63s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04677	training's macroF1: 0.203703	valid_1's multi_logloss: 1.07408	valid_1's macroF1: 0.185712
# Early stopping, best iteration is:
# [13]	training's multi_logloss: 1.35249	training's macroF1: 0.20049	valid_1's multi_logloss: 1.34077	valid_1's macroF1: 0.208605
# ******************** Execution ended in 00h 00m 07.30s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04658	training's macroF1: 0.20736	valid_1's multi_logloss: 1.07198	valid_1's macroF1: 0.217653
# Early stopping, best iteration is:
# [118]	training's multi_logloss: 1.20066	training's macroF1: 0.207527	valid_1's multi_logloss: 1.15588	valid_1's macroF1: 0.225338
# ******************** Execution ended in 00h 00m 07.67s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.06002	training's macroF1: 0.206192	valid_1's multi_logloss: 1.07933	valid_1's macroF1: 0.204729
# Early stopping, best iteration is:
# [26]	training's multi_logloss: 1.32768	training's macroF1: 0.209221	valid_1's multi_logloss: 1.30811	valid_1's macroF1: 0.229382
# ******************** Execution ended in 00h 00m 06.68s ********************
# ######################################## 13 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.756038	training's macroF1: 0.190117	valid_1's multi_logloss: 0.984907	valid_1's macroF1: 0.215293
# [1000]	training's multi_logloss: 0.568378	training's macroF1: 0.189489	valid_1's multi_logloss: 0.956346	valid_1's macroF1: 0.218505
# Early stopping, best iteration is:
# [916]	training's multi_logloss: 0.591901	training's macroF1: 0.190346	valid_1's multi_logloss: 0.959313	valid_1's macroF1: 0.223498
# ******************** Execution ended in 00h 00m 27.74s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.751563	training's macroF1: 0.210617	valid_1's multi_logloss: 1.03134	valid_1's macroF1: 0.206617
# Early stopping, best iteration is:
# [375]	training's multi_logloss: 0.826812	training's macroF1: 0.208865	valid_1's multi_logloss: 1.04032	valid_1's macroF1: 0.213887
# ******************** Execution ended in 00h 00m 17.31s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.752269	training's macroF1: 0.205782	valid_1's multi_logloss: 1.02343	valid_1's macroF1: 0.176274
# Early stopping, best iteration is:
# [79]	training's multi_logloss: 1.16892	training's macroF1: 0.201663	valid_1's multi_logloss: 1.18279	valid_1's macroF1: 0.190659
# ******************** Execution ended in 00h 00m 11.13s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.759443	training's macroF1: 0.202187	valid_1's multi_logloss: 0.989133	valid_1's macroF1: 0.208613
# [1000]	training's multi_logloss: 0.571006	training's macroF1: 0.206483	valid_1's multi_logloss: 0.972122	valid_1's macroF1: 0.215642
# [1500]	training's multi_logloss: 0.464941	training's macroF1: 0.201943	valid_1's multi_logloss: 0.968206	valid_1's macroF1: 0.214881
# Early stopping, best iteration is:
# [1064]	training's multi_logloss: 0.554238	training's macroF1: 0.206201	valid_1's multi_logloss: 0.970323	valid_1's macroF1: 0.220067
# ******************** Execution ended in 00h 00m 29.71s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.763647	training's macroF1: 0.206795	valid_1's multi_logloss: 0.987346	valid_1's macroF1: 0.193321
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 1.36875	training's macroF1: 0.207232	valid_1's multi_logloss: 1.36701	valid_1's macroF1: 0.216059
# ******************** Execution ended in 00h 00m 09.24s ********************
# ######################################## 14 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.27069	training's macroF1: 0.192649	valid_1's multi_logloss: 1.24382	valid_1's macroF1: 0.17578
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.38536	training's macroF1: 0.19688	valid_1's multi_logloss: 1.38503	valid_1's macroF1: 0.210957
# ******************** Execution ended in 00h 00m 06.87s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.27712	training's macroF1: 0.221103	valid_1's multi_logloss: 1.24136	valid_1's macroF1: 0.203393
# Early stopping, best iteration is:
# [32]	training's multi_logloss: 1.37695	training's macroF1: 0.223073	valid_1's multi_logloss: 1.3729	valid_1's macroF1: 0.209183
# ******************** Execution ended in 00h 00m 06.80s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.27182	training's macroF1: 0.191634	valid_1's multi_logloss: 1.22117	valid_1's macroF1: 0.206335
# Early stopping, best iteration is:
# [14]	training's multi_logloss: 1.38197	training's macroF1: 0.189275	valid_1's multi_logloss: 1.37942	valid_1's macroF1: 0.224984
# ******************** Execution ended in 00h 00m 06.67s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.26939	training's macroF1: 0.213655	valid_1's multi_logloss: 1.25149	valid_1's macroF1: 0.186524
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.38595	training's macroF1: 0.206814	valid_1's multi_logloss: 1.38587	valid_1's macroF1: 0.206412
# ******************** Execution ended in 00h 00m 08.63s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.28097	training's macroF1: 0.204659	valid_1's multi_logloss: 1.24821	valid_1's macroF1: 0.226141
# Early stopping, best iteration is:
# [6]	training's multi_logloss: 1.38453	training's macroF1: 0.20426	valid_1's multi_logloss: 1.38381	valid_1's macroF1: 0.236667
# ******************** Execution ended in 00h 00m 07.26s ********************
# ######################################## 15 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.08056	training's macroF1: 0.216943	valid_1's multi_logloss: 1.03652	valid_1's macroF1: 0.193459
# Early stopping, best iteration is:
# [11]	training's multi_logloss: 1.36427	training's macroF1: 0.20726	valid_1's multi_logloss: 1.35379	valid_1's macroF1: 0.204088
# ******************** Execution ended in 00h 00m 07.53s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.07298	training's macroF1: 0.207772	valid_1's multi_logloss: 1.08547	valid_1's macroF1: 0.177333
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 1.37131	training's macroF1: 0.21173	valid_1's multi_logloss: 1.36554	valid_1's macroF1: 0.207557
# ******************** Execution ended in 00h 00m 06.55s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.08696	training's macroF1: 0.213245	valid_1's multi_logloss: 1.0918	valid_1's macroF1: 0.192049
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.38013	training's macroF1: 0.219712	valid_1's multi_logloss: 1.37798	valid_1's macroF1: 0.220025
# ******************** Execution ended in 00h 00m 06.53s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.08445	training's macroF1: 0.209684	valid_1's multi_logloss: 1.0696	valid_1's macroF1: 0.221996
# Early stopping, best iteration is:
# [15]	training's multi_logloss: 1.35706	training's macroF1: 0.204325	valid_1's multi_logloss: 1.34476	valid_1's macroF1: 0.243642
# ******************** Execution ended in 00h 00m 06.51s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.0815	training's macroF1: 0.191182	valid_1's multi_logloss: 1.11972	valid_1's macroF1: 0.176309
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.38405	training's macroF1: 0.201784	valid_1's multi_logloss: 1.38295	valid_1's macroF1: 0.203744
# ******************** Execution ended in 00h 00m 07.22s ********************
# ######################################## 16 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.867304	training's macroF1: 0.202706	valid_1's multi_logloss: 1.00897	valid_1's macroF1: 0.18816
# Early stopping, best iteration is:
# [19]	training's multi_logloss: 1.30308	training's macroF1: 0.208369	valid_1's multi_logloss: 1.28259	valid_1's macroF1: 0.199186
# ******************** Execution ended in 00h 00m 07.18s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.870051	training's macroF1: 0.205631	valid_1's multi_logloss: 1.05676	valid_1's macroF1: 0.19686
# Early stopping, best iteration is:
# [42]	training's multi_logloss: 1.23724	training's macroF1: 0.212184	valid_1's multi_logloss: 1.21515	valid_1's macroF1: 0.208732
# ******************** Execution ended in 00h 00m 08.07s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.865564	training's macroF1: 0.199659	valid_1's multi_logloss: 1.06361	valid_1's macroF1: 0.211885
# Early stopping, best iteration is:
# [19]	training's multi_logloss: 1.30335	training's macroF1: 0.205917	valid_1's multi_logloss: 1.28276	valid_1's macroF1: 0.229601
# ******************** Execution ended in 00h 00m 08.78s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.863696	training's macroF1: 0.201772	valid_1's multi_logloss: 1.01498	valid_1's macroF1: 0.239104
# [1000]	training's multi_logloss: 0.730301	training's macroF1: 0.200441	valid_1's multi_logloss: 1.00936	valid_1's macroF1: 0.226405
# Early stopping, best iteration is:
# [584]	training's multi_logloss: 0.835328	training's macroF1: 0.200042	valid_1's multi_logloss: 1.01188	valid_1's macroF1: 0.249209
# ******************** Execution ended in 00h 00m 17.57s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.870818	training's macroF1: 0.224514	valid_1's multi_logloss: 1.02542	valid_1's macroF1: 0.223882
# Early stopping, best iteration is:
# [149]	training's multi_logloss: 1.0666	training's macroF1: 0.213803	valid_1's multi_logloss: 1.06754	valid_1's macroF1: 0.235285
# ******************** Execution ended in 00h 00m 10.72s ********************
# ######################################## 17 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05212	training's macroF1: 0.19438	valid_1's multi_logloss: 1.09692	valid_1's macroF1: 0.21235
# [1000]	training's multi_logloss: 0.963724	training's macroF1: 0.19175	valid_1's multi_logloss: 1.08911	valid_1's macroF1: 0.220282
# [1500]	training's multi_logloss: 0.903549	training's macroF1: 0.188507	valid_1's multi_logloss: 1.08593	valid_1's macroF1: 0.22061
# Early stopping, best iteration is:
# [1122]	training's multi_logloss: 0.94729	training's macroF1: 0.189257	valid_1's multi_logloss: 1.08668	valid_1's macroF1: 0.226858
# ******************** Execution ended in 00h 00m 23.34s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.03099	training's macroF1: 0.204692	valid_1's multi_logloss: 1.07643	valid_1's macroF1: 0.200463
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.38358	training's macroF1: 0.198625	valid_1's multi_logloss: 1.38256	valid_1's macroF1: 0.213576
# ******************** Execution ended in 00h 00m 07.72s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.051	training's macroF1: 0.219394	valid_1's multi_logloss: 1.0783	valid_1's macroF1: 0.215628
# Early stopping, best iteration is:
# [444]	training's multi_logloss: 1.06504	training's macroF1: 0.218177	valid_1's multi_logloss: 1.08337	valid_1's macroF1: 0.221832
# ******************** Execution ended in 00h 00m 17.85s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04646	training's macroF1: 0.210378	valid_1's multi_logloss: 1.03091	valid_1's macroF1: 0.23207
# Early stopping, best iteration is:
# [46]	training's multi_logloss: 1.29901	training's macroF1: 0.203099	valid_1's multi_logloss: 1.26035	valid_1's macroF1: 0.243949
# ******************** Execution ended in 00h 00m 09.04s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04499	training's macroF1: 0.197353	valid_1's multi_logloss: 1.05081	valid_1's macroF1: 0.2084
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.37937	training's macroF1: 0.210154	valid_1's multi_logloss: 1.37641	valid_1's macroF1: 0.235518
# ******************** Execution ended in 00h 00m 08.03s ********************
# ######################################## 18 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.3599	training's macroF1: 0.215326	valid_1's multi_logloss: 1.35503	valid_1's macroF1: 0.218644
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.38613	training's macroF1: 0.222332	valid_1's multi_logloss: 1.38604	valid_1's macroF1: 0.228941
# ******************** Execution ended in 00h 00m 08.36s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.36166	training's macroF1: 0.207857	valid_1's multi_logloss: 1.34863	valid_1's macroF1: 0.188363
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.38625	training's macroF1: 0.193586	valid_1's multi_logloss: 1.38622	valid_1's macroF1: 0.21341
# ******************** Execution ended in 00h 00m 11.12s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.36061	training's macroF1: 0.214595	valid_1's multi_logloss: 1.34915	valid_1's macroF1: 0.207483
# Early stopping, best iteration is:
# [293]	training's multi_logloss: 1.37065	training's macroF1: 0.209843	valid_1's multi_logloss: 1.36338	valid_1's macroF1: 0.214377
# ******************** Execution ended in 00h 00m 14.20s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# ...
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.16505	training's macroF1: 0.220293	valid_1's multi_logloss: 1.13505	valid_1's macroF1: 0.199729
# Early stopping, best iteration is:
# [16]	training's multi_logloss: 1.37391	training's macroF1: 0.218132	valid_1's multi_logloss: 1.36964	valid_1's macroF1: 0.210769
# ******************** Execution ended in 00h 00m 17.15s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.16547	training's macroF1: 0.209328	valid_1's multi_logloss: 1.15487	valid_1's macroF1: 0.196261
# Early stopping, best iteration is:
# [15]	training's multi_logloss: 1.37455	training's macroF1: 0.203421	valid_1's multi_logloss: 1.37153	valid_1's macroF1: 0.211772
# ******************** Execution ended in 00h 00m 17.46s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.16094	training's macroF1: 0.206905	valid_1's multi_logloss: 1.13965	valid_1's macroF1: 0.213782
# Early stopping, best iteration is:
# [43]	training's multi_logloss: 1.35435	training's macroF1: 0.209297	valid_1's multi_logloss: 1.34432	valid_1's macroF1: 0.225082
# ******************** Execution ended in 00h 00m 15.97s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.15723	training's macroF1: 0.207046	valid_1's multi_logloss: 1.13904	valid_1's macroF1: 0.219867
# [1000]	training's multi_logloss: 1.05958	training's macroF1: 0.204172	valid_1's multi_logloss: 1.07941	valid_1's macroF1: 0.221648
# Early stopping, best iteration is:
# [617]	training's multi_logloss: 1.1286	training's macroF1: 0.206122	valid_1's multi_logloss: 1.11832	valid_1's macroF1: 0.224123
# ******************** Execution ended in 00h 00m 44.60s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.17007	training's macroF1: 0.219792	valid_1's multi_logloss: 1.13118	valid_1's macroF1: 0.231398
# Early stopping, best iteration is:
# [256]	training's multi_logloss: 1.24804	training's macroF1: 0.216435	valid_1's multi_logloss: 1.21033	valid_1's macroF1: 0.237303
# ******************** Execution ended in 00h 00m 30.73s ********************
# ######################################## 46 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11264	training's macroF1: 0.20179	valid_1's multi_logloss: 1.07319	valid_1's macroF1: 0.218603
# Early stopping, best iteration is:
# [102]	training's multi_logloss: 1.25598	training's macroF1: 0.199753	valid_1's multi_logloss: 1.20924	valid_1's macroF1: 0.23372
# ******************** Execution ended in 00h 00m 14.69s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11406	training's macroF1: 0.203621	valid_1's multi_logloss: 1.07903	valid_1's macroF1: 0.216049
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 1.38232	training's macroF1: 0.211775	valid_1's multi_logloss: 1.37952	valid_1's macroF1: 0.229184
# ******************** Execution ended in 00h 00m 15.90s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11089	training's macroF1: 0.199539	valid_1's multi_logloss: 1.08484	valid_1's macroF1: 0.188591
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.38075	training's macroF1: 0.207569	valid_1's multi_logloss: 1.37799	valid_1's macroF1: 0.218589
# ******************** Execution ended in 00h 00m 13.27s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11139	training's macroF1: 0.19567	valid_1's multi_logloss: 1.09863	valid_1's macroF1: 0.218001
# [1000]	training's multi_logloss: 1.04818	training's macroF1: 0.189787	valid_1's multi_logloss: 1.09028	valid_1's macroF1: 0.236903
# Early stopping, best iteration is:
# [994]	training's multi_logloss: 1.04888	training's macroF1: 0.191466	valid_1's multi_logloss: 1.09092	valid_1's macroF1: 0.238715
# ******************** Execution ended in 00h 04m 18.72s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.10953	training's macroF1: 0.207789	valid_1's multi_logloss: 1.09102	valid_1's macroF1: 0.19142
# Early stopping, best iteration is:
# [10]	training's multi_logloss: 1.36805	training's macroF1: 0.200209	valid_1's multi_logloss: 1.36052	valid_1's macroF1: 0.207121
# ******************** Execution ended in 00h 01m 51.55s ********************
# ######################################## 47 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.924135	training's macroF1: 0.204737	valid_1's multi_logloss: 1.07179	valid_1's macroF1: 0.18903
# Early stopping, best iteration is:
# [351]	training's multi_logloss: 0.975721	training's macroF1: 0.204282	valid_1's multi_logloss: 1.07652	valid_1's macroF1: 0.198315
# ******************** Execution ended in 00h 04m 10.45s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.935384	training's macroF1: 0.208927	valid_1's multi_logloss: 0.997934	valid_1's macroF1: 0.209645
# Early stopping, best iteration is:
# [70]	training's multi_logloss: 1.206	training's macroF1: 0.210656	valid_1's multi_logloss: 1.14488	valid_1's macroF1: 0.232278
# ******************** Execution ended in 00h 02m 01.07s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.926706	training's macroF1: 0.203451	valid_1's multi_logloss: 1.09106	valid_1's macroF1: 0.190519
# Early stopping, best iteration is:
# [266]	training's multi_logloss: 1.01518	training's macroF1: 0.208505	valid_1's multi_logloss: 1.09888	valid_1's macroF1: 0.195815
# ******************** Execution ended in 00h 01m 32.91s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.921156	training's macroF1: 0.198227	valid_1's multi_logloss: 1.04103	valid_1's macroF1: 0.203051
# Early stopping, best iteration is:
# [279]	training's multi_logloss: 1.00721	training's macroF1: 0.199428	valid_1's multi_logloss: 1.04989	valid_1's macroF1: 0.209976
# ******************** Execution ended in 00h 01m 02.59s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.927952	training's macroF1: 0.213924	valid_1's multi_logloss: 1.01967	valid_1's macroF1: 0.191226
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 1.37816	training's macroF1: 0.202015	valid_1's multi_logloss: 1.37541	valid_1's macroF1: 0.230401
# ******************** Execution ended in 00h 00m 10.12s ********************
# ######################################## 48 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.941572	training's macroF1: 0.208646	valid_1's multi_logloss: 1.0621	valid_1's macroF1: 0.205748
# Early stopping, best iteration is:
# [277]	training's multi_logloss: 1.0215	training's macroF1: 0.210032	valid_1's multi_logloss: 1.06694	valid_1's macroF1: 0.216287
# ******************** Execution ended in 00h 00m 12.69s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.927125	training's macroF1: 0.198474	valid_1's multi_logloss: 1.05288	valid_1's macroF1: 0.19126
# Early stopping, best iteration is:
# [16]	training's multi_logloss: 1.31723	training's macroF1: 0.195719	valid_1's multi_logloss: 1.29757	valid_1's macroF1: 0.224653
# ******************** Execution ended in 00h 00m 08.91s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.943544	training's macroF1: 0.194829	valid_1's multi_logloss: 1.0331	valid_1's macroF1: 0.220194
# Early stopping, best iteration is:
# [284]	training's multi_logloss: 1.01791	training's macroF1: 0.196448	valid_1's multi_logloss: 1.04214	valid_1's macroF1: 0.229168
# ******************** Execution ended in 00h 00m 15.40s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.922599	training's macroF1: 0.202091	valid_1's multi_logloss: 1.13655	valid_1's macroF1: 0.21208
# Early stopping, best iteration is:
# [20]	training's multi_logloss: 1.29872	training's macroF1: 0.196133	valid_1's multi_logloss: 1.28545	valid_1's macroF1: 0.22262
# ******************** Execution ended in 00h 00m 11.36s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.94156	training's macroF1: 0.199167	valid_1's multi_logloss: 1.04345	valid_1's macroF1: 0.212857
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.37087	training's macroF1: 0.205015	valid_1's multi_logloss: 1.36374	valid_1's macroF1: 0.228585
# ******************** Execution ended in 00h 00m 09.93s ********************
# ######################################## 49 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.995807	training's macroF1: 0.203433	valid_1's multi_logloss: 1.01723	valid_1's macroF1: 0.195956
# Early stopping, best iteration is:
# [16]	training's multi_logloss: 1.33379	training's macroF1: 0.201669	valid_1's multi_logloss: 1.30825	valid_1's macroF1: 0.204439
# ******************** Execution ended in 00h 00m 10.84s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.993469	training's macroF1: 0.213433	valid_1's multi_logloss: 1.03567	valid_1's macroF1: 0.204963
# Early stopping, best iteration is:
# [15]	training's multi_logloss: 1.33993	training's macroF1: 0.21426	valid_1's multi_logloss: 1.31736	valid_1's macroF1: 0.229486
# ******************** Execution ended in 00h 00m 11.47s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.985399	training's macroF1: 0.205034	valid_1's multi_logloss: 1.07775	valid_1's macroF1: 0.177702
# Early stopping, best iteration is:
# [20]	training's multi_logloss: 1.32242	training's macroF1: 0.212831	valid_1's multi_logloss: 1.30117	valid_1's macroF1: 0.211251
# ******************** Execution ended in 00h 00m 08.02s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.980425	training's macroF1: 0.209046	valid_1's multi_logloss: 1.11331	valid_1's macroF1: 0.203083
# Early stopping, best iteration is:
# [17]	training's multi_logloss: 1.33184	training's macroF1: 0.208503	valid_1's multi_logloss: 1.32149	valid_1's macroF1: 0.222517
# ******************** Execution ended in 00h 00m 08.56s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.989768	training's macroF1: 0.1978	valid_1's multi_logloss: 1.08343	valid_1's macroF1: 0.236231
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 1.37212	training's macroF1: 0.199282	valid_1's multi_logloss: 1.36855	valid_1's macroF1: 0.254829
# ******************** Execution ended in 00h 00m 08.96s ********************
# ######################################## 50 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.09793	training's macroF1: 0.201018	valid_1's multi_logloss: 1.05415	valid_1's macroF1: 0.22336
# Early stopping, best iteration is:
# [16]	training's multi_logloss: 1.35025	training's macroF1: 0.208419	valid_1's multi_logloss: 1.33234	valid_1's macroF1: 0.235596
# ******************** Execution ended in 00h 00m 07.28s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.08254	training's macroF1: 0.200174	valid_1's multi_logloss: 1.13272	valid_1's macroF1: 0.213493
# Early stopping, best iteration is:
# [345]	training's multi_logloss: 1.11344	training's macroF1: 0.196651	valid_1's multi_logloss: 1.13906	valid_1's macroF1: 0.217116
# ******************** Execution ended in 00h 00m 11.56s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.09849	training's macroF1: 0.19064	valid_1's multi_logloss: 1.10325	valid_1's macroF1: 0.21965
# Early stopping, best iteration is:
# [58]	training's multi_logloss: 1.28419	training's macroF1: 0.189048	valid_1's multi_logloss: 1.25069	valid_1's macroF1: 0.234459
# ******************** Execution ended in 00h 00m 07.77s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.10183	training's macroF1: 0.224111	valid_1's multi_logloss: 1.07817	valid_1's macroF1: 0.195219
# Early stopping, best iteration is:
# [89]	training's multi_logloss: 1.25225	training's macroF1: 0.215754	valid_1's multi_logloss: 1.19034	valid_1's macroF1: 0.204211
# ******************** Execution ended in 00h 00m 07.72s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.09295	training's macroF1: 0.191269	valid_1's multi_logloss: 1.07521	valid_1's macroF1: 0.223031
# Early stopping, best iteration is:
# [25]	training's multi_logloss: 1.33269	training's macroF1: 0.186125	valid_1's multi_logloss: 1.30487	valid_1's macroF1: 0.240617
# ******************** Execution ended in 00h 00m 07.31s ********************

# %%
shap_sorted_df = total_shap_df.groupby('feature').mean().sort_values('shap_values', ascending=False).reset_index()
feat_imp_sorted_df = total_shap_df.groupby('feature').mean().sort_values('feat_imp', ascending=False).reset_index()
features_top_shap = shap_sorted_df['feature'][:500]
features_top_feat_imp = feat_imp_sorted_df['feature'][:500]
top_features = pd.Series(features_top_shap.tolist() + features_top_feat_imp.tolist())
top_features = top_features.unique()

# %% [markdown]
# # 4. Model development

# %%
new_train = train[top_features].copy()
new_test = test[top_features].copy()

# %%
print('new_train shape:', new_train.shape, 'new_test shape:', new_test.shape)
# Out:
# new_train shape: (2973, 516) new_test shape: (23856, 516)

# %%
new_categorical_feats = [col for col in top_features if col in categorical_feats]

# %%
def LGB_OOF(params, categorical_feats, N_FOLDs, SEED=1989):
    clf = lgb.LGBMClassifier(objective='multiclass',
                             random_state=1989,
                             max_depth=params['max_depth'],
                             learning_rate=params['learning_rate'],
                            #  silent=True,
                             verbose=-1,
                             metric='multi_logloss',
                             n_jobs=-1,
                             n_estimators=10000,
                             class_weight='balanced',
                             colsample_bytree=params['colsample_bytree'],
                             min_split_gain=params['min_split_gain'],
                             bagging_freq=params['bagging_freq'],
                             min_child_weight=params['min_child_weight'],
                             num_leaves=params['num_leaves'],
                             subsample=params['subsample'],
                             reg_alpha=params['reg_alpha'],
                             reg_lambda=params['reg_lambda'],
                             num_class=len(np.unique(y)),
                             bagging_seed=SEED,
                             seed=SEED,
                             )
    
    kfold = 10
    kf = StratifiedKFold(n_splits=kfold, shuffle=True)
    feat_importance_df = pd.DataFrame()
    predicts_result = []

    for i, (train_index, test_index) in enumerate(kf.split(new_train, y)):
        print('='*30, '{} of {} folds'.format(i+1, kfold), '='*30)
        start = time.time()
        X_train, X_val = new_train.iloc[train_index], new_train.iloc[test_index]
        y_train, y_val = y.iloc[train_index], y.iloc[test_index]
        clf.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)], eval_metric=evaluate_macroF1_lgb, categorical_feature=new_categorical_feats, callbacks=[lgb.early_stopping(stopping_rounds=500), lgb.log_evaluation(period=500)])
        shap_values = shap.TreeExplainer(clf.booster_).shap_values(X_train)
        fold_importance_df = pd.DataFrame()
        fold_importance_df['feature'] = X_train.columns
        # fold_importance_df['shap_values'] = abs(np.array(shap_values)[:, :].mean(1).mean(0))
        shap_arr = np.abs(np.array(shap_values))
        if shap_arr.shape[0] == len(X_train):  
            fold_importance_df['shap_values'] = shap_arr.mean(axis=0).mean(axis=-1)
        else:
            fold_importance_df['shap_values'] = shap_arr.mean(axis=1).mean(axis=0)

        fold_importance_df['feat_imp'] = clf.feature_importances_
        feat_importance_df = pd.concat([feat_importance_df, fold_importance_df])
        predicts_result.append(clf.predict(new_test))
        print_execution_time(start)
    return predicts_result, feat_importance_df

# %%
params = {'max_depth': 6,
          'learning_rate': 0.002,
          'colsample_bytree': 0.8,
          'subsample': 0.8,
          'min_split_gain': 0.02,
          'num_leaves': 48,
          'reg_alpha': 0.04,
          'reg_lambda': 0.073,
          'bagging_freq': 2,
          'min_child_weight': 40
          }

N_Folds = 20
SEED = 1989
predicts_result, feat_importance_df = LGB_OOF(params, new_categorical_feats, N_Folds, SEED=1989)
# Out:
# ============================== 1 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13282	training's macroF1: 0.195147	valid_1's multi_logloss: 1.1362	valid_1's macroF1: 0.167843
# Early stopping, best iteration is:
# [54]	training's multi_logloss: 1.34285	training's macroF1: 0.195075	valid_1's multi_logloss: 1.33511	valid_1's macroF1: 0.185285
# ******************** Execution ended in 00h 00m 10.45s ********************
# ============================== 2 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13647	training's macroF1: 0.209315	valid_1's multi_logloss: 1.11497	valid_1's macroF1: 0.197557
# Early stopping, best iteration is:
# [21]	training's multi_logloss: 1.36912	training's macroF1: 0.208458	valid_1's multi_logloss: 1.36364	valid_1's macroF1: 0.209447
# ******************** Execution ended in 00h 00m 07.20s ********************
# ============================== 3 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13868	training's macroF1: 0.215629	valid_1's multi_logloss: 1.12318	valid_1's macroF1: 0.225712
# Early stopping, best iteration is:
# [6]	training's multi_logloss: 1.38143	training's macroF1: 0.211047	valid_1's multi_logloss: 1.38008	valid_1's macroF1: 0.234332
# ******************** Execution ended in 00h 00m 07.46s ********************
# ============================== 4 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13941	training's macroF1: 0.200341	valid_1's multi_logloss: 1.12309	valid_1's macroF1: 0.188081
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 1.38019	training's macroF1: 0.208349	valid_1's multi_logloss: 1.37895	valid_1's macroF1: 0.209227
# ******************** Execution ended in 00h 00m 06.79s ********************
# ============================== 5 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.14277	training's macroF1: 0.200981	valid_1's multi_logloss: 1.11018	valid_1's macroF1: 0.227677
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.38545	training's macroF1: 0.214648	valid_1's multi_logloss: 1.38523	valid_1's macroF1: 0.24019
# ******************** Execution ended in 00h 00m 07.49s ********************
# ============================== 6 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13312	training's macroF1: 0.220075	valid_1's multi_logloss: 1.13931	valid_1's macroF1: 0.226507
# Early stopping, best iteration is:
# [14]	training's multi_logloss: 1.37433	training's macroF1: 0.216709	valid_1's multi_logloss: 1.37194	valid_1's macroF1: 0.242011
# ******************** Execution ended in 00h 00m 06.05s ********************
# ============================== 7 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.1305	training's macroF1: 0.230254	valid_1's multi_logloss: 1.15589	valid_1's macroF1: 0.199376
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.38538	training's macroF1: 0.22692	valid_1's multi_logloss: 1.38524	valid_1's macroF1: 0.229128
# ******************** Execution ended in 00h 00m 06.18s ********************
# ============================== 8 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13825	training's macroF1: 0.211866	valid_1's multi_logloss: 1.12881	valid_1's macroF1: 0.210458
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 1.38214	training's macroF1: 0.226191	valid_1's multi_logloss: 1.38082	valid_1's macroF1: 0.238234
# ******************** Execution ended in 00h 00m 06.26s ********************
# ============================== 9 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13302	training's macroF1: 0.214404	valid_1's multi_logloss: 1.16968	valid_1's macroF1: 0.203782
# Early stopping, best iteration is:
# [21]	training's multi_logloss: 1.36834	training's macroF1: 0.217571	valid_1's multi_logloss: 1.36832	valid_1's macroF1: 0.230069
# ******************** Execution ended in 00h 00m 06.96s ********************
# ============================== 10 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.14302	training's macroF1: 0.225911	valid_1's multi_logloss: 1.12237	valid_1's macroF1: 0.170543
# Early stopping, best iteration is:
# [93]	training's multi_logloss: 1.3194	training's macroF1: 0.221192	valid_1's multi_logloss: 1.3039	valid_1's macroF1: 0.190836
# ******************** Execution ended in 00h 00m 07.72s ********************

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 20))
feat_importance_df_shap = feat_importance_df.groupby('feature').mean().sort_values('shap_values', ascending=False).reset_index()

num_features = 50
sns.barplot(x=feat_importance_df_shap.shap_values[:num_features], y=feat_importance_df_shap.feature[:num_features], ax=ax[0])
ax[0].set_title('Feature importance based on shap values')

feat_importance_df = feat_importance_df.groupby('feature').mean().sort_values('feat_imp', ascending=False).reset_index()

num_features = 50
sns.barplot(x=feat_importance_df.shap_values[:num_features], y=feat_importance_df.feature[:num_features], ax=ax[1])
ax[1].set_title('Feature importance based on feature importance from lgbm')
plt.show()

# %%
submission['Target'] = np.array(predicts_result).mean(axis=0).round().astype(int)
submission.to_csv('submssion_with_new_feature_set.csv', index=False)

# %% [markdown]
# ## Randomized search

# %%
optimized_param = None
lowest_cv = 1000
total_iteration = 100
for i in range(total_iteration):
    print('-' * 20, 'For {} of {} iterations'.format(i+1, total_iteration), '-'*20)
    learning_rate = np.random.rand() * 0.02
    n_folds = 3

    num_class = len(np.unique(y))

    params = {}
    params['application'] = 'multiclass'
    params['metric'] = 'multi_logloss'
    params['num_class'] = num_class
    params['class_weight'] = 'balanced'
    params['num_leaves'] = np.random.randint(24, 48)
    params['max_depth'] = np.random.randint(5, 8)
    params['min_child_weight'] = np.random.randint(5, 50)
    params['min_split_gain'] = np.random.rand() * 0.09
    params['colsample_bytree'] = np.random.rand() * (0.9 - 0.1) + 0.1
    params['subsample'] = np.random.rand() * (1 - 0.8) + 0.8
    params['bagging_freq'] = np.random.randint(1, 5)
    params['bagging_seed'] = np.random.randint(1, 5)
    params['reg_alpha'] = np.random.rand() * 2
    params['reg_lambda'] = np.random.rand() * 2
    params['learning_rate'] = np.random.rand() * 0.02
    params['seed'] = 1989

    d_train = lgb.Dataset(data=new_train, label=y.values-1, categorical_feature=new_categorical_feats, free_raw_data=False)
    cv_results = lgb.cv(params=params, train_set=d_train, num_boost_round=10000, nfold=n_folds, stratified=True, shuffle=True, callbacks=[lgb.early_stopping(stopping_rounds=1), lgb.log_evaluation(1000)])

    min_cv_results = min(cv_results['valid multi_logloss-mean'])

    if min_cv_results < lowest_cv:
        lowest_cv = min_cv_results
        optimized_param = params
# Out:
# -------------------- For 1 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [277]	valid's multi_logloss: 0.831493 + 0.0152886
# -------------------- For 2 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [150]	valid's multi_logloss: 0.825856 + 0.0166358
# -------------------- For 3 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [392]	valid's multi_logloss: 0.831262 + 0.0150826
# -------------------- For 4 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [296]	valid's multi_logloss: 0.830345 + 0.0158741
# -------------------- For 5 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [218]	valid's multi_logloss: 0.826401 + 0.015063
# -------------------- For 6 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.83187 + 0.013431
# Early stopping, best iteration is:
# [1171]	valid's multi_logloss: 0.827867 + 0.0147711
# -------------------- For 7 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [151]	valid's multi_logloss: 0.829597 + 0.0163929
# -------------------- For 8 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [104]	valid's multi_logloss: 0.830922 + 0.0143378
# -------------------- For 9 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [172]	valid's multi_logloss: 0.832401 + 0.0148856
# -------------------- For 10 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [379]	valid's multi_logloss: 0.831198 + 0.0152936
# -------------------- For 11 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.945499 + 0.00248124
# [2000]	valid's multi_logloss: 0.906677 + 0.00519751
# [3000]	valid's multi_logloss: 0.880688 + 0.00740386
# [4000]	valid's multi_logloss: 0.862842 + 0.0090628
# [5000]	valid's multi_logloss: 0.850439 + 0.0103017
# [6000]	valid's multi_logloss: 0.841914 + 0.0113488
# [7000]	valid's multi_logloss: 0.836055 + 0.0123282
# [8000]	valid's multi_logloss: 0.832017 + 0.0133419
# Early stopping, best iteration is:
# [8687]	valid's multi_logloss: 0.830008 + 0.0140363
# -------------------- For 12 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [223]	valid's multi_logloss: 0.829377 + 0.0156426
# -------------------- For 13 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [478]	valid's multi_logloss: 0.831218 + 0.014529
# -------------------- For 14 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.868479 + 0.00932853
# [2000]	valid's multi_logloss: 0.837159 + 0.0134893
# Early stopping, best iteration is:
# [2423]	valid's multi_logloss: 0.832585 + 0.0148943
# -------------------- For 15 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [286]	valid's multi_logloss: 0.827549 + 0.0150739
# -------------------- For 16 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [317]	valid's multi_logloss: 0.831827 + 0.015535
# -------------------- For 17 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [162]	valid's multi_logloss: 0.829031 + 0.0157514
# -------------------- For 18 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [144]	valid's multi_logloss: 0.829582 + 0.0163242
# -------------------- For 19 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [201]	valid's multi_logloss: 0.829515 + 0.0153469
# -------------------- For 20 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [345]	valid's multi_logloss: 0.827333 + 0.0148266
# -------------------- For 21 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.831302 + 0.0140001
# Early stopping, best iteration is:
# [1060]	valid's multi_logloss: 0.82986 + 0.0143841
# -------------------- For 22 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [419]	valid's multi_logloss: 0.830499 + 0.0150949
# -------------------- For 23 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [178]	valid's multi_logloss: 0.829997 + 0.0157032
# -------------------- For 24 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.891531 + 0.00701135
# [2000]	valid's multi_logloss: 0.851671 + 0.0111537
# [3000]	valid's multi_logloss: 0.835822 + 0.0137662
# Early stopping, best iteration is:
# [3455]	valid's multi_logloss: 0.832326 + 0.0147904
# -------------------- For 25 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [293]	valid's multi_logloss: 0.827576 + 0.0168327
# -------------------- For 26 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [156]	valid's multi_logloss: 0.827776 + 0.0163968
# -------------------- For 27 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [151]	valid's multi_logloss: 0.829449 + 0.0146513
# -------------------- For 28 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [293]	valid's multi_logloss: 0.831236 + 0.015075
# -------------------- For 29 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [571]	valid's multi_logloss: 0.830127 + 0.014804
# -------------------- For 30 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [264]	valid's multi_logloss: 0.829027 + 0.0156279
# -------------------- For 31 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.832744 + 0.0146079
# Early stopping, best iteration is:
# [1066]	valid's multi_logloss: 0.831523 + 0.0150384
# -------------------- For 32 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [671]	valid's multi_logloss: 0.829879 + 0.0149099
# -------------------- For 33 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [221]	valid's multi_logloss: 0.832283 + 0.0151748
# -------------------- For 34 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [134]	valid's multi_logloss: 0.831736 + 0.0152794
# -------------------- For 35 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [174]	valid's multi_logloss: 0.83069 + 0.01753
# -------------------- For 36 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [437]	valid's multi_logloss: 0.82929 + 0.0157124
# -------------------- For 37 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [207]	valid's multi_logloss: 0.832977 + 0.0142013
# -------------------- For 38 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.847381 + 0.0114722
# Early stopping, best iteration is:
# [1541]	valid's multi_logloss: 0.832241 + 0.0150126
# -------------------- For 39 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.854801 + 0.0107574
# Early stopping, best iteration is:
# [1949]	valid's multi_logloss: 0.833529 + 0.014448
# -------------------- For 40 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [148]	valid's multi_logloss: 0.831377 + 0.016144
# -------------------- For 41 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [153]	valid's multi_logloss: 0.827857 + 0.016161
# -------------------- For 42 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [221]	valid's multi_logloss: 0.829945 + 0.0156819
# -------------------- For 43 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds

# %%
N_Folds = 20
SEED = 1989
predicts_result, feat_importance_df = LGB_OOF(optimized_param, new_categorical_feats, N_Folds, SEED=1989)

# %%
submission['Target'] = np.array(predicts_result).mean(axis=0).round().astype(int)
submission.to_csv('submission_shap_randomized_search.csv', index=False)
