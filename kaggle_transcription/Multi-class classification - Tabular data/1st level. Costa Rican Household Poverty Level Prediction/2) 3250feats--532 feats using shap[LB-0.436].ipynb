# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale=2.2)
plt.style.use('seaborn-v0_8')

from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.model_selection import StratifiedKFold, train_test_split, ShuffleSplit
from sklearn.metrics import f1_score
import itertools
import lightgbm as lgb
import xgboost as xgb
from xgboost import XGBClassifier
import shap
from tqdm import tqdm
import featuretools as ft
import warnings
warnings.filterwarnings('ignore')
import time
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\woodwork\__init__.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# # 1. Check datasets
#
# ## 1.1 Read dataset

# %%
df_train = pd.read_csv('./input/train.csv')
df_test = pd.read_csv('./input/test.csv')

# %%
print('df_train shape:', df_train.shape, '   ', 'df_test shape: ', df_test.shape)
# Out:
# df_train shape: (9557, 143)     df_test shape:  (23856, 142)

# %%
df_train.head()
# Out:
#              Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  v18q1  \
# 0  ID_279628684  190000.0       0      3       0     1       1     0    NaN
# 1  ID_f29eb3ddd  135000.0       0      4       0     1       1     1    1.0
# 2  ID_68de51c94       NaN       0      8       0     1       1     0    NaN
# 3  ID_d671db89c  180000.0       0      5       0     1       1     1    1.0
# 4  ID_d56d6f5f5  180000.0       0      5       0     1       1     1    1.0
#
#    r4h1  ...  SQBescolari  SQBage  SQBhogar_total  SQBedjefe  SQBhogar_nin  \
# 0     0  ...          100    1849               1        100             0
# 1     0  ...          144    4489               1        144             0
# 2     0  ...          121    8464               1          0             0
# 3     0  ...           81     289              16        121             4
# 4     0  ...          121    1369              16        121             4
#
#    SQBovercrowding  SQBdependency  SQBmeaned  agesq  Target
# 0         1.000000            0.0      100.0   1849       4
# 1         1.000000           64.0      144.0   4489       4
# 2         0.250000           64.0      121.0   8464       4
# 3         1.777778            1.0      121.0    289       4
# 4         1.777778            1.0      121.0   1369       4
#
# [5 rows x 143 columns]

# %%
df_test.head()
# Out:
#              Id      v2a1  hacdor  rooms  hacapo  v14a  refrig  v18q  v18q1  \
# 0  ID_2f6873615       NaN       0      5       0     1       1     0    NaN
# 1  ID_1c78846d2       NaN       0      5       0     1       1     0    NaN
# 2  ID_e5442cf6a       NaN       0      5       0     1       1     0    NaN
# 3  ID_a8db26a79       NaN       0     14       0     1       1     1    1.0
# 4  ID_a62966799  175000.0       0      4       0     1       1     1    1.0
#
#    r4h1  ...  age  SQBescolari  SQBage  SQBhogar_total  SQBedjefe  \
# 0     1  ...    4            0      16               9          0
# 1     1  ...   41          256    1681               9          0
# 2     1  ...   41          289    1681               9          0
# 3     0  ...   59          256    3481               1        256
# 4     0  ...   18          121     324               1          0
#
#    SQBhogar_nin  SQBovercrowding  SQBdependency  SQBmeaned  agesq
# 0             1             2.25           0.25     272.25     16
# 1             1             2.25           0.25     272.25   1681
# 2             1             2.25           0.25     272.25   1681
# 3             0             1.00           0.00     256.00   3481
# 4             1             0.25          64.00        NaN    324
#
# [5 rows x 142 columns]

# %% [markdown]
# ## 1.2 Make description df

# %%
description = [
    ('v2a1', 'Monthly rent payment'),
    ('hacdor', ' =1 Overcrowding by bedrooms'),
    ('rooms', ' number of all rooms in the house'),
    ('hacapo', ' =1 Overcrowding by rooms'),
    ('v14a', ' =1 has toilet in the household'),
    ('refrig', ' =1 if the household has refrigerator'),
    ('v18q', ' owns a tablet'),
    ('v18q1', ' number of tablets household owns'),
    ('r4h1', ' Males younger than 12 years of age'),
    ('r4h2', ' Males 12 years of age and older'),
    ('r4h3', ' Total males in the household'),
    ('r4m1', ' Females younger than 12 years of age'),
    ('r4m2', ' Females 12 years of age and older'),
    ('r4m3', ' Total females in the household'),
    ('r4t1', ' persons younger than 12 years of age'),
    ('r4t2', ' persons 12 years of age and older'),
    ('r4t3', ' Total persons in the household'),
    ('tamhog', ' size of the household'),
    ('tamviv', ' number of persons living in the household'),
    ('escolari', ' years of schooling'),
    ('rez_esc', ' Years behind in school'),
    ('hhsize', ' household size'),
    ('paredblolad', ' =1 if predominant material on the outside wall is block or brick'),
    ('paredzocalo', ' =1 if predominant material on the outside wall is socket (wood, zinc or absbesto'),
    ('paredpreb', ' =1 if predominant material on the outside wall is prefabricated or cement'),
    ('pareddes', ' =1 if predominant material on the outside wall is waste material'),
    ('paredmad', ' =1 if predominant material on the outside wall is wood'),
    ('paredzinc', ' =1 if predominant material on the outside wall is zinc'),
    ('paredfibras', ' =1 if predominant material on the outside wall is natural fibers'),
    ('paredother', ' =1 if predominant material on the outside wall is other'),
    ('pisomoscer', ' =1 if predominant material on the floor is mosaic ceramic terrazo'),
    ('pisocemento', ' =1 if predominant material on the floor is cement'),
    ('pisoother', ' =1 if predominant material on the floor is other'),
    ('pisonatur', ' =1 if predominant material on the floor is natural material'),
    ('pisonotiene', ' =1 if no floor at the household'),
    ('pisomadera', ' =1 if predominant material on the floor is wood'),
    ('techozinc', ' =1 if predominant material on the roof is metal foil or zinc'),
    ('techoentrepiso', ' =1 if predominant material on the roof is fiber cement, mezzanine '),
    ('techocane', ' =1 if predominant material on the roof is natural fibers'),
    ('techootro', ' =1 if predominant material on the roof is other'),
    ('cielorazo', ' =1 if the hosue has ceiling'),
    ('abastaguadentro', ' =1 if water provision inside the dwelling'),
    ('abastaguafuera', ' =1 if water provision outside the dwelling'),
    ('abastaguano', ' =1 if no water provision'),
    ('public', ' =1 electricy from CNFL, ICE, ESPH/JASEC'),
    ('planpri', ' =1 electricity from private plant'),
    ('noelec', ' =1 no electricity in the dwelling'),
    ('coopele', ' =1 electricity from cooperative'),
    ('sanitario1', ' =1 no toilet in the dwelling'),
    ('sanitario2', ' =1 toilet connected to sewer or cesspool'),
    ('sanitario3', ' =1 toilet connected to septic tank'),
    ('sanitario5', ' =1 toilet connected to black hole or letrine'),
    ('sanitario6', ' =1 toilet connected to other system'),
    ('energcocinar1', ' =1 no main source of energy used for cooking (no kitchen)'),
    ('energcocinar2', ' =1 main source of energy used for cooking electricity'),
    ('energcocinar3', ' =1 main source of energy used for cooking gas'),
    ('energcocinar4', ' =1 main source of energy used for cooking wood charcoal'),
    ('elimbasu1', ' =1 if rubbish disposal mainly by tanker truck'),
    ('elimbasu2', ' =1 if rubbish disposal mainly by botan hollow or buried'),
    ('elimbasu3', ' =1 if rubbish disposal mainly by burning'),
    ('elimbasu4', ' =1 if rubbish disposal mainly by throwing in an unoccupied space'),
    ('elimbasu5', ' =1 if rubbish disposal mainly by throwing in river, creek or sea'),
    ('elimbasu6', ' =1 if rubbish disposal mainly other'),
    ('epared1', ' =1 if walls are bad'),
    ('epared2', ' =1 if walls are regular'),
    ('epared3', ' =1 if walls are good'),
    ('etecho1', ' =1 if roof are bad'),
    ('etecho2', ' =1 if roof are regular'),
    ('etecho3', ' =1 if roof are good'),
    ('eviv1', ' =1 if floor are bad'),
    ('eviv2', ' =1 if floor are regular'),
    ('eviv3', ' =1 if floor are good'),
    ('dis', ' =1 if disable person'),
    ('male', ' =1 if male'),
    ('female', ' =1 if female'),
    ('estadocivil1', ' =1 if less than 10 years old'),
    ('estadocivil2', ' =1 if free or coupled union'),
    ('estadocivil3', ' =1 if married'),
    ('estadocivil4', ' =1 if divorced'),
    ('estadocivil5', ' =1 if separated'),
    ('estadocivil6', ' =1 if widow/er'),
    ('estadocivil7', ' =1 if single'),
    ('parentesco1', ' =1 if household head'),
    ('parentesco2', ' =1 if spouse/partner'),
    ('parentesco3', ' =1 if son/daughter'),
    ('parentesco4', ' =1 if stepson/daughter'),
    ('parentesco5', ' =1 if son/daughter in law'),
    ('parentesco6', ' =1 if grandson/daughter'),
    ('parentesco7', ' =1 if mother/father'),
    ('parentesco8', ' =1 if father/mother in law'),
    ('parentesco9', ' =1 if brother/sister'),
    ('parentesco10', ' =1 if brother/sister in law'),
    ('parentesco11', ' =1 if other family member'),
    ('parentesco12', ' =1 if other non family member'),
    ('idhogar', ' Household level identifier'),
    ('hogar_nin', ' Number of children 0 to 19 in household'),
    ('hogar_adul', ' Number of adults in household'),
    ('hogar_mayor', ' # of individuals 65+ in the household'),
    ('hogar_total', ' # of total individuals in the household'),
    ('dependency', ' Dependency rate'),
    ('edjefe', ' years of education of male head of household'),
    ('edjefa', ' years of education of female head of household'),
    ('meaneduc', ' average years of education for adults (18+)'),
    ('instlevel1', ' =1 no level of education'),
    ('instlevel2', ' =1 incomplete primary'),
    ('instlevel3', ' =1 complete primary'),
    ('instlevel4', ' =1 incomplete academic secondary level'),
    ('instlevel5', ' =1 complete academic secondary level'),
    ('instlevel6', ' =1 incomplete technical secondary level'),
    ('instlevel7', ' =1 complete technical secondary level'),
    ('instlevel8', ' =1 undergraduate and higher education'),
    ('instlevel9', ' =1 postgraduate higher education'),
    ('bedrooms', ' number of bedrooms'),
    ('overcrowding', ' # persons per room'),
    ('tipovivi1', ' =1 own and fully paid house'),
    ('tipovivi2', ' =1 own, paying in installments'),
    ('tipovivi3', ' =1 rented'),
    ('tipovivi4', ' =1 precarious'),
    ('tipovivi5', ' =1 other(assigned)'),
    ('computer', ' =1 if the household has notebook or desktop computer, borrowed'),
    ('television', ' =1 if the household has TV'),
    ('mobilephone', ' =1 if mobile phone'),
    ('qmobilephone', ' # of mobile phones'),
    ('lugar1', ' =1 region Central'),
    ('lugar2', ' =1 region Chorotega'),
    ('lugar3', ' =1 region PacÃƒÂ­fico central'),
    ('lugar4', ' =1 region Brunca'),
    ('lugar5', ' =1 region Huetar AtlÃƒÂ¡ntica'),
    ('lugar6', ' =1 region Huetar Norte'),
    ('area1', ' =1 zona urbana'),
    ('area2', ' =2 zona rural'),
    ('age', ' Age in years'),
    ('SQBescolari', ' escolari squared'),
    ('SQBage', ' age squared'),
    ('SQBhogar_total', ' hogar_total squared'),
    ('SQBedjefe', ' edjefe squared'),
    ('SQBhogar_nin', ' hogar_nin squared'),
    ('SQBovercrowding', ' overcrowding squared'),
    ('SQBdependency', ' dependency squared'),
    ('SQBmeaned', ' meaned squared'),
    ('agesq', ' Age sqaured'),
]

description = pd.DataFrame(description, columns=['varname', 'description'])

# %%
description
# Out:
#              varname                        description
# 0               v2a1               Monthly rent payment
# 1             hacdor        =1 Overcrowding by bedrooms
# 2              rooms   number of all rooms in the house
# 3             hacapo           =1 Overcrowding by rooms
# 4               v14a     =1 has toilet in the household
# ..               ...                                ...
# 136     SQBhogar_nin                  hogar_nin squared
# 137  SQBovercrowding               overcrowding squared
# 138    SQBdependency                 dependency squared
# 139        SQBmeaned                     meaned squared
# 140            agesq                        Age sqaured
#
# [141 rows x 2 columns]

# %% [markdown]
# ## 1.3 Check null data

# %%
total = df_train.isnull().sum().sort_values(ascending=False)
percent = 100 * (df_train.isnull().sum() / df_train.isnull().count()).sort_values(ascending=False)
missing_df = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_df.head(20)
# Out:
#            Total    Percent
# rez_esc     7928  82.954902
# v18q1       7342  76.823271
# v2a1        6860  71.779847
# meaneduc       5   0.052318
# SQBmeaned      5   0.052318
# rooms          0   0.000000
# Id             0   0.000000
# refrig         0   0.000000
# v18q           0   0.000000
# r4h1           0   0.000000
# r4h2           0   0.000000
# r4h3           0   0.000000
# hacapo         0   0.000000
# v14a           0   0.000000
# hacdor         0   0.000000
# r4m3           0   0.000000
# r4m2           0   0.000000
# r4m1           0   0.000000
# r4t1           0   0.000000
# tamhog         0   0.000000

# %% [markdown]
# ## 1.4 Fill missing values
#
# * Below cell is from this kernel. https://www.kaggle.com/skooch/lgbm-w-random-split-2

# %%
# df_train.loc[(df_train['edjefa'] == 'yes') & (df_train['parentesco1'] == 1), 'edjefa'] = df_train.loc[(df_train['edjefa'] == 'yes') & (df_train['parentesco1'] == 1), 'escolari']
# df_train.loc[(df_train['edjefe'] == 'yes') & (df_train['parentesco1'] == 1), 'edjefe'] = df_train.loc[(df_train['edjefe'] == 'yes') & (df_train['parentesco1'] == 1), 'escolari']

# df_test.loc[(df_test['edjefa'] == 'yes') & (df_test['parentesco1'] == 1), 'edjefa'] = df_test.loc[(df_test['edjefa'] == 'yes') & (df_test['parentesco1'] == 1), 'escolari']
# df_test.loc[(df_test['edjefe'] == 'yes') & (df_test['parentesco1'] == 1), 'edjefe'] = df_test.loc[(df_test['edjefe'] == 'yes') & (df_test['parentesco1'] == 1), 'escolari']

# df_train.loc[df_train['edjefa'] == 'yes', 'edjefa'] = 4
# df_train.loc[df_train['edjefe'] == 'yes', 'edjefe'] = 4

# df_test.loc[df_test['edjefa'] == 'yes', 'edjefa'] = 4
# df_test.loc[df_test['edjefe'] == 'yes', 'edjefe'] = 4

# df_train['edjef'] = np.max(df_train[['edjefa', 'edjefe']], axis=1)
# df_test['edjef'] = np.max(df_test[['edjefa', 'edjefe']], axis=1)

# df_train.loc[(df_train.v14a == 1) & (df_train.sanitario1 == 1) & (df_train.abastaguano == 0), 'v14a'] = 0
# df_train.loc[(df_train.v14a == 1) & (df_train.sanitario1 == 1) & (df_train.abastaguano == 0), 'sanitario1'] = 0

# df_test.loc[(df_test.v14a == 1) & (df_test.sanitario1 == 1) & (df_test.abastaguano == 0), 'v14a'] = 0
# df_test.loc[(df_test.v14a == 1) & (df_test.sanitario1 == 1) & (df_test.abastaguano == 0), 'sanitario1'] = 0

# %%
df_train.loc[(df_train['edjefa'] == 'yes') & (df_train['parentesco1'] == 1), 'edjefa'] = df_train.loc[(df_train['edjefa'] == 'yes') & (df_train['parentesco1'] == 1), 'escolari']
df_train.loc[(df_train['edjefe'] == 'yes') & (df_train['parentesco1'] == 1), 'edjefe'] = df_train.loc[(df_train['edjefe'] == 'yes') & (df_train['parentesco1'] == 1), 'escolari']

df_test.loc[(df_test['edjefa'] == 'yes') & (df_test['parentesco1'] == 1), 'edjefa'] = df_test.loc[(df_test['edjefa'] == 'yes') & (df_test['parentesco1'] == 1), 'escolari']
df_test.loc[(df_test['edjefe'] == 'yes') & (df_test['parentesco1'] == 1), 'edjefe'] = df_test.loc[(df_test['edjefe'] == 'yes') & (df_test['parentesco1'] == 1), 'escolari']

df_train.loc[df_train['edjefa'] == 'yes', 'edjefa'] = 4
df_train.loc[df_train['edjefe'] == 'yes', 'edjefe'] = 4

df_test.loc[df_test['edjefa'] == 'yes', 'edjefa'] = 4
df_test.loc[df_test['edjefe'] == 'yes', 'edjefe'] = 4

df_train['edjef'] = df_train[['edjefa', 'edjefe']].replace('no', 0).astype(float).max(axis=1)
df_test['edjef'] = df_test[['edjefa', 'edjefe']].replace('no', 0).astype(float).max(axis=1)

df_train.loc[(df_train.v14a == 1) & (df_train.sanitario1 == 1) & (df_train.abastaguano == 0), 'v14a'] = 0
df_train.loc[(df_train.v14a == 1) & (df_train.sanitario1 == 1) & (df_train.abastaguano == 0), 'sanitario1'] = 0

df_test.loc[(df_test.v14a == 1) & (df_test.sanitario1 == 1) & (df_test.abastaguano == 0), 'v14a'] = 0
df_test.loc[(df_test.v14a == 1) & (df_test.sanitario1 == 1) & (df_test.abastaguano == 0), 'sanitario1'] = 0

# %% [markdown]
# ### rez_esc, SQBmeaned
#
# * rez_esc : Years behind in school -> filled with 0
# * SQBmeaned : square of the mean years of education of adults (>=18) in the household agesq, Age squared -> same with rez_esc -> filled with 0

# %%
df_train['rez_esc'].fillna(0, inplace=True)
df_test['rez_esc'].fillna(0, inplace=True)

# %%
df_train['SQBmeaned'].fillna(0, inplace=True)
df_test['SQBmeaned'].fillna(0, inplace=True)

# %% [markdown]
# ### meaneduc
#
# * meaneduc: average years of education for adults (18+) -> filled with 0

# %%
df_train['meaneduc'].fillna(0, inplace=True)
df_test['meaneduc'].fillna(0, inplace=True)

# %% [markdown]
# ### v18q1
#
# * v18q1: number of tablets household owns -> if v18q(Do you own a tablet?) == 1, there are some values. If not, only NaN values in v18q1. See below 3 cells.

# %%
df_train['v18q'].value_counts()
# Out:
# v18q
# 0    7342
# 1    2215
# Name: count, dtype: int64

# %% [markdown]
# * v18q1: number of tablets household owns -> if v18q == 1, there are some values. If not, only NaN values there. See below two cells.

# %%
df_train.loc[df_train['v18q'] == 1, 'v18q1'].value_counts()
# Out:
# v18q1
# 1.0    1586
# 2.0     444
# 3.0     129
# 4.0      37
# 5.0      13
# 6.0       6
# Name: count, dtype: int64

# %%
df_train.loc[df_train['v18q'] == 0, 'v18q1'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df_train['v18q1'].fillna(0, inplace=True)
df_test['v18q1'].fillna(0, inplace=True)

# %% [markdown]
# * v2a1: number of tablets household owns -> if tipovivi3(rented?) == 1, there are some values. If not, there are also some values.
# * NaN value could be replaced by 0.

# %%
df_train['tipovivi3'].value_counts()
# Out:
# tipovivi3
# 0    7821
# 1    1736
# Name: count, dtype: int64

# %%
sns.kdeplot(df_train.loc[df_train['tipovivi3'] == 1, 'v2a1'], label='Monthly rent payment of household(rented=1)')
sns.kdeplot(df_train.loc[df_train['tipovivi3'] == 0, 'v2a1'], label='Monthly rent payment of household(rented=0)')
plt.xscale('log')
plt.show()

# %%
df_train['v2a1'].fillna(0, inplace=True)
df_test['v2a1'].fillna(0, inplace=True)

# %%
total = df_train.isnull().sum().sort_values(ascending=False)
percent = 100 * (df_train.isnull().sum() / df_train.isnull().count()).sort_values(ascending=False)
missing_df = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_df.head(20)
# Out:
#         Total  Percent
# Id          0      0.0
# v2a1        0      0.0
# hacdor      0      0.0
# rooms       0      0.0
# hacapo      0      0.0
# v14a        0      0.0
# refrig      0      0.0
# v18q        0      0.0
# v18q1       0      0.0
# r4h1        0      0.0
# r4h2        0      0.0
# r4h3        0      0.0
# r4m1        0      0.0
# r4m2        0      0.0
# r4m3        0      0.0
# r4t1        0      0.0
# r4t2        0      0.0
# r4t3        0      0.0
# tamhog      0      0.0
# tamviv      0      0.0

# %%
total = df_test.isnull().sum().sort_values(ascending=False)
percent = 100 * (df_test.isnull().sum() / df_test.isnull().count()).sort_values(ascending=False)
missing_df = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

missing_df.head(20)
# Out:
#         Total  Percent
# Id          0      0.0
# v2a1        0      0.0
# hacdor      0      0.0
# rooms       0      0.0
# hacapo      0      0.0
# v14a        0      0.0
# refrig      0      0.0
# v18q        0      0.0
# v18q1       0      0.0
# r4h1        0      0.0
# r4h2        0      0.0
# r4h3        0      0.0
# r4m1        0      0.0
# r4m2        0      0.0
# r4m3        0      0.0
# r4t1        0      0.0
# r4t2        0      0.0
# r4t3        0      0.0
# tamhog      0      0.0
# tamviv      0      0.0

# %% [markdown]
# **For now, there are no NaN values.**
#
# # 2. Feature engineering
#
# ## 2.1 Object features

# %%
features_object = [col for col in df_train.columns if df_train[col].dtype=='object']

# %%
features_object
# Out:
# ['Id', 'idhogar', 'dependency', 'edjefe', 'edjefa']

# %% [markdown]
# ### dependency

# %%
df_train['dependency'] = np.sqrt(df_train['SQBdependency'])
df_test['dependency'] = np.sqrt(df_test['SQBdependency'])

# %% [markdown]
# ### edjefe
#
# * edjefe, years of education of male head of household, based on the interaction of escolari (years of education), head of household and gender, yes=1 and no=0
# * replace yes -> 1 and no -> 0

# %%
def replace_edjefe(x):
    if x == 'yes':
        return 1
    elif x == 'no':
        return 0
    else:
        return x

df_train['edjefe'] = df_train['edjefe'].apply(replace_edjefe).astype(float)
df_test['edjefe'] = df_test['edjefe'].apply(replace_edjefe).astype(float)

# %% [markdown]
# ### edjefa
#
# * edjefa, years of education of female head of household, based on the interaction of escolari (years of education), head of household and gender, yes=1 and no=0
# * replace yes -> 1 and no -> 0

# %%
def replace_edjefa(x):
    if x == 'yes':
        return 1
    elif x == 'no':
        return 0
    else:
        return x

df_train['edjefa'] = df_train['edjefa'].apply(replace_edjefa).astype(float)
df_test['edjefa'] = df_test['edjefa'].apply(replace_edjefa).astype(float)

# %%
df_train['edjef'] = np.max(df_train[['edjefa', 'edjefe']], axis=1)
df_test['edjef'] = np.max(df_test[['edjefa', 'edjefe']], axis=1)

# %% [markdown]
# ### roof and electricity
#
# * I referred to https://www.kaggle.com/mineshjethva/exploratory-data-analysis-lightgbm. Thanks!

# %%
df_train['roof_waste_material'] = np.nan
df_test['roof_waste_material'] = np.nan
df_train['electricity_other'] = np.nan
df_test['electricity_other'] = np.nan

def fill_roof_exception(x):
    if (x['techozinc'] == 0) and (x['techoentrepiso'] == 0) and (x['techocane'] == 0) and (x['techootro'] == 0):
        return 1
    else:
        return 0

def fill_no_electricity(x):
    if (x['public'] == 0) and (x['planpri'] == 0) and (x['noelec'] == 0) and (x['coopele'] == 0):
        return 1
    else:
        return 0

df_train['roof_waste_material'] = df_train.apply(lambda x: fill_roof_exception(x), axis=1)
df_test['roof_waste_material'] = df_test.apply(lambda x: fill_roof_exception(x), axis=1)
df_train['electricity_other'] = df_train.apply(lambda x: fill_no_electricity(x), axis=1)
df_test['electricity_other'] = df_test.apply(lambda x: fill_no_electricity(x), axis=1)

# %% [markdown]
# ## 2.2 Extract cat features
#
# * According to data scription, there are many binary category features.

# %%
binary_cat_features = [col for col in df_train.columns if df_train[col].value_counts().shape[0] == 2]

# %% [markdown]
# ## 2.3 Make new features using continuous feature

# %%
continuous_features = [col for col in df_train.columns if col not in binary_cat_features]
continuous_features = [col for col in continuous_features if col not in features_object]
continuous_features = [col for col in continuous_features if col not in ['Id', 'Target', 'idhogar']]

# %%
print('There are {} continuous features'.format(len(continuous_features)))
for col in continuous_features:
    print('{}: {}'.format(col, description.loc[description['varname'] == col, 'description'].values))
# Out:
# There are 37 continuous features
# v2a1: ['Monthly rent payment']
# rooms: [' number of all rooms in the house']
# v18q1: [' number of tablets household owns']
# r4h1: [' Males younger than 12 years of age']
# r4h2: [' Males 12 years of age and older']
# r4h3: [' Total males in the household']
# r4m1: [' Females younger than 12 years of age']
# r4m2: [' Females 12 years of age and older']
# r4m3: [' Total females in the household']
# r4t1: [' persons younger than 12 years of age']
# r4t2: [' persons 12 years of age and older']
# r4t3: [' Total persons in the household']
# tamhog: [' size of the household']
# tamviv: [' number of persons living in the household']
# escolari: [' years of schooling']
# rez_esc: [' Years behind in school']
# hhsize: [' household size']
# elimbasu5: [' =1 if rubbish disposal mainly by throwing in river, creek or sea']
# hogar_nin: [' Number of children 0 to 19 in household']
# hogar_adul: [' Number of adults in household']
# hogar_mayor: [' # of individuals 65+ in the household']
# hogar_total: [' # of total individuals in the household']
# meaneduc: [' average years of education for adults (18+)']
# bedrooms: [' number of bedrooms']
# overcrowding: [' # persons per room']
# qmobilephone: [' # of mobile phones']
# age: [' Age in years']
# SQBescolari: [' escolari squared']
# SQBage: [' age squared']
# SQBhogar_total: [' hogar_total squared']
# SQBedjefe: [' edjefe squared']
# SQBhogar_nin: [' hogar_nin squared']
# SQBovercrowding: [' overcrowding squared']
# SQBdependency: [' dependency squared']
# SQBmeaned: [' meaned squared']
# agesq: [' Age sqaured']
# edjef: []

# %% [markdown]
# * hhsize: household size
# * tamhog: size of the household
#
# What is different?
#
# * As you can see, the meaning of two features are same but the exact number are different. Are they different?
# * I don't know. For now, I decided to drop one feature 'tamhog'

# %%
df_train['edjef'].value_counts()
# Out:
# edjef
# 6.0     2792
# 11.0    1150
# 9.0      723
# 8.0      474
# 15.0     473
# 3.0      459
# 0.0      435
# 7.0      413
# 4.0      400
# 5.0      398
# 14.0     328
# 17.0     278
# 2.0      278
# 16.0     247
# 10.0     207
# 12.0     185
# 13.0     155
# 1.0       65
# 21.0      48
# 18.0      22
# 19.0      18
# 20.0       9
# Name: count, dtype: int64

# %%
df_train.drop('tamhog', axis=1, inplace=True)
df_test.drop('tamhog', axis=1, inplace=True)

# %% [markdown]
# ### Squared features
#
# * There are many squared features. Actually, tree models like lightgbm don't need them. But at this kernel, I want to use lightgbm as feature filter model and set entity-ebedding as classifier. So let's keep them.
#
# ### Family features
#
# * hogar_nin, hogar_adul, hogar_mayor, hogar_total, r4h1, r4h2, r4h3, r4m1, r4m2, r4m3, r4t1, r4t2, r4t3, tamhog, tamviv, rez_esc, escolari
# * Family size features (subtract, ratio)

# %%
df_train['adult'] = df_train['hogar_adul'] - df_train['hogar_mayor']
df_train['dependency_count'] = df_train['hogar_nin'] + df_train['hogar_mayor']
df_train['dependency'] = df_train['dependency_count'] / df_train['adult']
df_train['child_percent'] = df_train['hogar_nin'] / df_train['hogar_total']
df_train['elder_percent'] = df_train['hogar_mayor'] / df_train['hogar_total']
df_train['adult_percent'] = df_train['hogar_adul'] / df_train['hogar_total']
df_train['males_younger_12_years_percent'] = df_train['r4h1'] / df_train['hogar_total']
df_train['males_older_12_years_percent'] = df_train['r4h2'] / df_train['hogar_total']
df_train['males_percent'] = df_train['r4h3'] / df_train['hogar_total']
df_train['females_younger_12_years_percent'] = df_train['r4m1'] / df_train['hogar_total']
df_train['females_older_12_years_percent'] = df_train['r4m2'] / df_train['hogar_total']
df_train['females_percent'] = df_train['r4m3'] / df_train['hogar_total']
df_train['persons_younger_12_years_percent'] = df_train['r4t1'] / df_train['hogar_total']
df_train['persons_older_12_years_percent'] = df_train['r4t2'] / df_train['hogar_total']
df_train['persons_percent'] = df_train['r4t3'] / df_train['hogar_total']

# %%
df_test['adult'] = df_test['hogar_adul'] - df_test['hogar_mayor']
df_test['dependency_count'] = df_test['hogar_nin'] + df_test['hogar_mayor']
df_test['dependency'] = df_test['dependency_count'] / df_test['adult']
df_test['child_percent'] = df_test['hogar_nin'] / df_test['hogar_total']
df_test['elder_percent'] = df_test['hogar_mayor'] / df_test['hogar_total']
df_test['adult_percent'] = df_test['hogar_adul'] / df_test['hogar_total']
df_test['males_younger_12_years_percent'] = df_test['r4h1'] / df_test['hogar_total']
df_test['males_older_12_years_percent'] = df_test['r4h2'] / df_test['hogar_total']
df_test['males_percent'] = df_test['r4h3'] / df_test['hogar_total']
df_test['females_younger_12_years_percent'] = df_test['r4m1'] / df_test['hogar_total']
df_test['females_older_12_years_percent'] = df_test['r4m2'] / df_test['hogar_total']
df_test['females_percent'] = df_test['r4m3'] / df_test['hogar_total']
df_test['persons_younger_12_years_percent'] = df_test['r4t1'] / df_test['hogar_total']
df_test['persons_older_12_years_percent'] = df_test['r4t2'] / df_test['hogar_total']
df_test['persons_percent'] = df_test['r4t3'] / df_test['hogar_total']

# %%
df_train['males_younger_12_years_in_household_size'] = df_train['r4h1'] / df_train['hhsize']
df_train['males_older_12_years_in_household_size'] = df_train['r4h2'] / df_train['hhsize']
df_train['males_in_household_size'] = df_train['r4h3'] / df_train['hhsize']
df_train['females_younger_12_years_in_household_size'] = df_train['r4m1'] / df_train['hhsize']
df_train['females_older_12_years_in_household_size'] = df_train['r4m2'] / df_train['hhsize']
df_train['females_in_household_size'] = df_train['r4m3'] / df_train['hogar_total']
df_train['persons_younger_12_years_in_household_size'] = df_train['r4t1'] / df_train['hhsize']
df_train['persons_older_12_years_in_household_size'] = df_train['r4t2'] / df_train['hhsize']
df_train['persons_in_household_size'] = df_train['r4t3'] / df_train['hhsize']

# %%
df_test['males_younger_12_years_in_household_size'] = df_test['r4h1'] / df_test['hhsize']
df_test['males_older_12_years_in_household_size'] = df_test['r4h2'] / df_test['hhsize']
df_test['males_in_household_size'] = df_test['r4h3'] / df_test['hhsize']
df_test['females_younger_12_years_in_household_size'] = df_test['r4m1'] / df_test['hhsize']
df_test['females_older_12_years_in_household_size'] = df_test['r4m2'] / df_test['hhsize']
df_test['females_in_household_size'] = df_test['r4m3'] / df_test['hogar_total']
df_test['persons_younger_12_years_in_household_size'] = df_test['r4t1'] / df_test['hhsize']
df_test['persons_older_12_years_in_household_size'] = df_test['r4t2'] / df_test['hhsize']
df_test['persons_in_household_size'] = df_test['r4t3'] / df_test['hhsize']

# %%
df_train['overcrowding_room_and_bedroom'] = (df_train['hacdor'] + df_train['hacapo']) / 2
df_test['overcrowding_room_and_bedroom'] = (df_test['hacdor'] + df_test['hacapo']) / 2

# %%
df_train['escolari_age'] = df_train['escolari'] / df_train['age']
df_test['escolari_age'] = df_test['escolari'] / df_test['age']

df_train['age_12_19'] = df_train['hogar_nin'] - df_train['r4t1']
df_test['age_12_19'] = df_test['hogar_nin'] - df_test['r4t1']

# %%
df_train['phones-per-capita'] = df_train['qmobilephone'] / df_train['tamviv']
df_train['tablets-per-capita'] = df_train['v18q1'] / df_train['tamviv']
df_train['rooms-per-capita'] = df_train['rooms'] / df_train['tamviv']
df_train['rent-per-capita'] = df_train['v2a1'] / df_train['tamviv']

# %%
df_test['phones-per-capita'] = df_test['qmobilephone'] / df_test['tamviv']
df_test['tablets-per-capita'] = df_test['v18q1'] / df_test['tamviv']
df_test['rooms-per-capita'] = df_test['rooms'] / df_test['tamviv']
df_test['rent-per-capita'] = df_test['v2a1'] / df_test['tamviv']

# %% [markdown]
# * You can see that "Total persons in the household" != "# of total individuals in the household".
# * Somewhat weird. But for now I will keep it.

# %%
(df_train['hogar_total'] == df_train['r4t3']).sum()
# Out:
# np.int64(9509)

# %% [markdown]
# ### Rent per family features
#
# * I will reduce the number of features using shap, so let's generate many features!! Hope catch some fortune features :)

# %%
family_size_features = ['adult', 'hogar_adul', 'hogar_mayor', 'hogar_nin', 'hogar_total', 'r4h1', 'r4h2', 'r4h3', 'r4m1', 'r4m2', 'r4m3', 'r4t1', 'r4t2', 'r4t3', 'hhsize']
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('v2a1', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['v2a1'] / df_train[col]
    df_test[new_col_name] = df_test['v2a1'] / df_test[col]

# %% [markdown]
# * Ratio feature can have infinite values. So let them be filled with 0.

# %%
for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)

    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %% [markdown]
# ### Room per family features

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('rooms', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['bedrooms'] / df_train[col]
    df_test[new_col_name] = df_test['bedrooms'] / df_test[col]

for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)

    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 205) (23856, 204)

# %% [markdown]
# ### Tabulet per family features

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('v18q1', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['v18q1'] / df_train[col]
    df_test[new_col_name] = df_test['v18q1'] / df_test[col]

for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)

    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %% [markdown]
# ### phone per family features

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('qmobilephone', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['qmobilephone'] / df_train[col]
    df_test[new_col_name] = df_test['qmobilephone'] / df_test[col]

for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)
    
    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %% [markdown]
# ### rez_esc(Years behind in school) per family features

# %%
new_feats = []
for col in family_size_features:
    new_col_name = 'new_{}_per_{}'.format('rez_esc', col)
    new_feats.append(new_col_name)
    df_train[new_col_name] = df_train['rez_esc'] / df_train[col]
    df_test[new_col_name] = df_train['rez_esc'] / df_test[col]

for col in new_feats:
    df_train[col].replace([np.inf], np.nan, inplace=True)
    df_train[col].fillna(0, inplace=True)

    df_test[col].replace([np.inf], np.nan, inplace=True)
    df_test[col].fillna(0, inplace=True)

# %%
df_train['rez_esc_age'] = df_train['rez_esc'] / df_train['age']
df_train['rez_esc_escolari'] = df_train['rez_esc'] / df_train['escolari']

df_test['rez_esc_age'] = df_test['rez_esc'] / df_test['age']
df_test['rez_esc_escolari'] = df_test['rez_esc'] / df_test['escolari']

# %% [markdown]
# ### Rich features
#
# * I think the more richer, the larger number of phhones and tabulet

# %%
df_train['tabulet_x_qmobilephone'] = df_train['v18q1'] * df_train['qmobilephone']
df_test['tabulet_x_qmobilephone'] = df_test['v18q1'] * df_test['qmobilephone']

# %% [markdown]
# * wall, roof, floor may be key factor.
# * Let's multiply each of them. Because they are binary cat features, so multification of each features generates new categorical features.

# %%
for col1 in ['epared1', 'epared2', 'epared3']:
    for col2 in ['etecho1', 'etecho2', 'etecho3']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

for col1 in ['epared1', 'epared2', 'epared3']:
    for col2 in ['eviv1', 'eviv2', 'eviv3']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

for col1 in ['etecho1', 'etecho2', 'etecho3']:
    for col2 in ['eviv1', 'eviv2', 'eviv3']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %% [markdown]
# * combination using three features

# %%
for col1 in ['epared1', 'epared2', 'epared3']:
    for col2 in ['etecho1', 'etecho2', 'etecho3']:
        for col3 in ['eviv1', 'eviv2', 'eviv3']:
            new_col_name = 'new_{}_x_{}_x_{}'.format(col1, col2, col3)
            df_train[new_col_name] = df_train[col1] * df_train[col2] * df_train[col3]
            df_test[new_col_name] = df_test[col1] * df_test[col2] * df_test[col3]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 307) (23856, 306)

# %% [markdown]
# * I want to mix electricity and energy features -> energy features

# %%
for col1 in ['public', 'planpri', 'noelec', 'coopele']:
    for col2 in ['energcocinar1', 'energcocinar2', 'energcocinar3', 'energcocinar4']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %% [markdown]
# * I want to mix toilet and rubbish disposal features -> other_infra features

# %%
for col1 in ['sanitario1', 'sanitario2', 'sanitario3', 'sanitario5', 'sanitario6']:
    for col2 in ['elimbasu1', 'elimbasu2', 'elimbasu3', 'elimbasu4', 'elimbasu5', 'elimbasu6']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %% [markdown]
# * I want to mix toilet and water provision features -> water features

# %%
for col1 in ['abastaguadentro', 'abastaguafuera', 'abastaguano']:
    for col2 in ['sanitario1', 'sanitario2', 'sanitario3', 'sanitario5', 'sanitario6']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 368) (23856, 367)

# %% [markdown]
# * I want mix education and area features -> education_zone_features

# %%
for col1 in ['area1', 'area2']:
    for col2 in ['instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %% [markdown]
# * Mix region and education

# %%
for col1 in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
    for col2 in ['instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 440) (23856, 439)

# %% [markdown]
# * Multiply television / mobilephone / computer / tabulet / refrigerator -> electronics features

# %%
df_train['electronics'] = df_train['computer'] * df_train['mobilephone'] * df_train['television'] * df_train['v18q'] * df_train['refrig']
df_test['electronics'] = df_test['computer'] * df_test['mobilephone'] * df_test['television'] * df_test['v18q'] * df_test['refrig']

df_train['no_appliances'] = df_train['refrig'] + df_train['computer'] + df_train['television'] + df_train['mobilephone']
df_test['no_appliances'] = df_test['refrig'] + df_test['computer'] + df_test['television'] + df_test['mobilephone']

# %% [markdown]
# * Mix wall material of roof, floor, wall

# %%
for col1 in ['paredblolad', 'paredzocalo', 'paredpreb', 'pareddes', 'paredmad', 'paredzinc', 'paredfibras', 'paredother']:
    for col2 in ['pisomoscer', 'pisocemento', 'pisoother', 'pisonatur', 'pisonotiene', 'pisomadera']:
        new_col_name = 'new_{}_x_{}'.format(col, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

for col1 in ['pisomoscer', 'pisocemento', 'pisoother', 'pisonatur', 'pisonotiene', 'pisomadera']:
    for col2 in ['techozinc', 'techoentrepiso', 'techocane', 'techootro']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]

for col1 in ['paredblolad', 'paredzocalo', 'paredpreb', 'pareddes', 'paredmad', 'paredzinc', 'paredfibras', 'paredother']:
    for col2 in ['techozinc', 'techoentrepiso', 'techocane', 'techootro']:
        new_col_name = 'new_{}_x_{}'.format(col1, col2)
        df_train[new_col_name] = df_train[col1] * df_train[col2]
        df_test[new_col_name] = df_test[col1] * df_test[col2]
    
for col1 in ['paredblolad', 'paredzocalo', 'paredpreb', 'pareddes', 'paredmad', 'paredzinc', 'paredfibras', 'paredother']:
    for col2 in ['pisomoscer', 'pisocemento', 'pisoother', 'pisonatur', 'pisonotiene', 'pisomadera']:
        for col3 in ['techozinc', 'techoentrepiso', 'techocane', 'techootro']:
            new_col_name = 'new_{}_x_{}_x_{}'.format(col1, col2, col3)
            df_train[new_col_name] = df_train[col1] * df_train[col2] * df_train[col3]
            df_test[new_col_name] = df_test[col1] * df_test[col2] * df_test[col3]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (9557, 696) (23856, 695)

# %% [markdown]
# * Wow! Without any aggregation features, we have 446 features for now. Actually mixing the materials of walls make thousands of features. I don't want to do that because of computational costs!
#
# ### Remove feature with only one value

# %%
cols_with_only_one_value = []
for col in df_train.columns:
    if col == 'Target':
        continue
    if df_train[col].value_counts().shape[0] == 1 or df_test[col].value_counts().shape[0] == 1:
        print(col)
        cols_with_only_one_value.append(col)
# Out:
# elimbasu5
# new_planpri_x_energcocinar1
# new_planpri_x_energcocinar2
# new_planpri_x_energcocinar3
# new_planpri_x_energcocinar4
# new_noelec_x_energcocinar2
# new_sanitario1_x_elimbasu4
# new_sanitario1_x_elimbasu5
# new_sanitario1_x_elimbasu6
# new_sanitario2_x_elimbasu4
# new_sanitario2_x_elimbasu5
# new_sanitario2_x_elimbasu6
# new_sanitario3_x_elimbasu5
# new_sanitario5_x_elimbasu4
# new_sanitario5_x_elimbasu5
# new_sanitario5_x_elimbasu6
# new_sanitario6_x_elimbasu2
# new_sanitario6_x_elimbasu4
# new_sanitario6_x_elimbasu5
# new_sanitario6_x_elimbasu6
# new_abastaguafuera_x_sanitario6
# new_abastaguano_x_sanitario2
# new_abastaguano_x_sanitario6
# new_new_rez_esc_per_hhsize_x_pisoother
# new_new_rez_esc_per_hhsize_x_pisonatur
# new_new_rez_esc_per_hhsize_x_pisonotiene
# new_new_rez_esc_per_hhsize_x_pisomadera
# new_pisocemento_x_techocane
# new_pisocemento_x_techootro
# new_pisoother_x_techoentrepiso
# new_pisoother_x_techocane
# new_pisoother_x_techootro
# new_pisonatur_x_techozinc
# new_pisonatur_x_techoentrepiso
# new_pisonatur_x_techocane
# new_pisonatur_x_techootro
# new_pisonotiene_x_techoentrepiso
# new_pisonotiene_x_techocane
# new_pisonotiene_x_techootro
# new_pisomadera_x_techocane
# new_pisomadera_x_techootro
# new_paredzocalo_x_techoentrepiso
# new_paredzocalo_x_techocane
# new_paredzocalo_x_techootro
# new_paredpreb_x_techootro
# new_pareddes_x_techoentrepiso
# new_pareddes_x_techocane
# new_pareddes_x_techootro
# new_paredmad_x_techocane
# new_paredmad_x_techootro
# new_paredzinc_x_techoentrepiso
# new_paredzinc_x_techocane
# new_paredzinc_x_techootro
# new_paredfibras_x_techoentrepiso
# new_paredfibras_x_techootro
# new_paredother_x_techoentrepiso
# new_paredother_x_techocane
# new_paredother_x_techootro
# new_paredblolad_x_pisocemento_x_techocane
# new_paredblolad_x_pisocemento_x_techootro
# new_paredblolad_x_pisoother_x_techoentrepiso
# new_paredblolad_x_pisoother_x_techocane
# new_paredblolad_x_pisoother_x_techootro
# new_paredblolad_x_pisonatur_x_techozinc
# new_paredblolad_x_pisonatur_x_techoentrepiso
# new_paredblolad_x_pisonatur_x_techocane
# new_paredblolad_x_pisonatur_x_techootro
# new_paredblolad_x_pisonotiene_x_techozinc
# new_paredblolad_x_pisonotiene_x_techoentrepiso
# new_paredblolad_x_pisonotiene_x_techocane
# new_paredblolad_x_pisonotiene_x_techootro
# new_paredblolad_x_pisomadera_x_techocane
# new_paredblolad_x_pisomadera_x_techootro
# new_paredzocalo_x_pisomoscer_x_techoentrepiso
# new_paredzocalo_x_pisomoscer_x_techocane
# new_paredzocalo_x_pisomoscer_x_techootro
# new_paredzocalo_x_pisocemento_x_techoentrepiso
# new_paredzocalo_x_pisocemento_x_techocane
# new_paredzocalo_x_pisocemento_x_techootro
# new_paredzocalo_x_pisoother_x_techozinc
# new_paredzocalo_x_pisoother_x_techoentrepiso
# new_paredzocalo_x_pisoother_x_techocane
# new_paredzocalo_x_pisoother_x_techootro
# new_paredzocalo_x_pisonatur_x_techozinc
# new_paredzocalo_x_pisonatur_x_techoentrepiso
# new_paredzocalo_x_pisonatur_x_techocane
# new_paredzocalo_x_pisonatur_x_techootro
# new_paredzocalo_x_pisonotiene_x_techoentrepiso
# new_paredzocalo_x_pisonotiene_x_techocane
# new_paredzocalo_x_pisonotiene_x_techootro
# new_paredzocalo_x_pisomadera_x_techoentrepiso
# new_paredzocalo_x_pisomadera_x_techocane
# new_paredzocalo_x_pisomadera_x_techootro
# new_paredpreb_x_pisomoscer_x_techootro
# new_paredpreb_x_pisocemento_x_techoentrepiso
# new_paredpreb_x_pisocemento_x_techocane
# new_paredpreb_x_pisocemento_x_techootro
# new_paredpreb_x_pisoother_x_techoentrepiso
# new_paredpreb_x_pisoother_x_techocane
# new_paredpreb_x_pisoother_x_techootro
# new_paredpreb_x_pisonatur_x_techozinc
# new_paredpreb_x_pisonatur_x_techoentrepiso
# new_paredpreb_x_pisonatur_x_techocane
# new_paredpreb_x_pisonatur_x_techootro
# new_paredpreb_x_pisonotiene_x_techoentrepiso
# new_paredpreb_x_pisonotiene_x_techocane
# new_paredpreb_x_pisonotiene_x_techootro
# new_paredpreb_x_pisomadera_x_techoentrepiso
# new_paredpreb_x_pisomadera_x_techocane
# new_paredpreb_x_pisomadera_x_techootro
# new_pareddes_x_pisomoscer_x_techozinc
# new_pareddes_x_pisomoscer_x_techoentrepiso
# new_pareddes_x_pisomoscer_x_techocane
# new_pareddes_x_pisomoscer_x_techootro
# new_pareddes_x_pisocemento_x_techoentrepiso
# new_pareddes_x_pisocemento_x_techocane
# new_pareddes_x_pisocemento_x_techootro
# new_pareddes_x_pisoother_x_techozinc
# new_pareddes_x_pisoother_x_techoentrepiso
# new_pareddes_x_pisoother_x_techocane
# new_pareddes_x_pisoother_x_techootro
# new_pareddes_x_pisonatur_x_techozinc
# new_pareddes_x_pisonatur_x_techoentrepiso
# new_pareddes_x_pisonatur_x_techocane
# new_pareddes_x_pisonatur_x_techootro
# new_pareddes_x_pisonotiene_x_techoentrepiso
# new_pareddes_x_pisonotiene_x_techocane
# new_pareddes_x_pisonotiene_x_techootro
# new_pareddes_x_pisomadera_x_techozinc
# new_pareddes_x_pisomadera_x_techoentrepiso
# new_pareddes_x_pisomadera_x_techocane
# new_pareddes_x_pisomadera_x_techootro
# new_paredmad_x_pisomoscer_x_techocane
# new_paredmad_x_pisomoscer_x_techootro
# new_paredmad_x_pisocemento_x_techocane
# new_paredmad_x_pisocemento_x_techootro
# new_paredmad_x_pisoother_x_techozinc
# new_paredmad_x_pisoother_x_techoentrepiso
# new_paredmad_x_pisoother_x_techocane
# new_paredmad_x_pisoother_x_techootro
# new_paredmad_x_pisonatur_x_techozinc
# new_paredmad_x_pisonatur_x_techoentrepiso
# new_paredmad_x_pisonatur_x_techocane
# new_paredmad_x_pisonatur_x_techootro
# new_paredmad_x_pisonotiene_x_techoentrepiso
# new_paredmad_x_pisonotiene_x_techocane
# new_paredmad_x_pisonotiene_x_techootro
# new_paredmad_x_pisomadera_x_techocane
# new_paredmad_x_pisomadera_x_techootro
# new_paredzinc_x_pisomoscer_x_techoentrepiso
# new_paredzinc_x_pisomoscer_x_techocane
# new_paredzinc_x_pisomoscer_x_techootro
# new_paredzinc_x_pisocemento_x_techoentrepiso
# new_paredzinc_x_pisocemento_x_techocane
# new_paredzinc_x_pisocemento_x_techootro
# new_paredzinc_x_pisoother_x_techozinc
# new_paredzinc_x_pisoother_x_techoentrepiso
# new_paredzinc_x_pisoother_x_techocane
# new_paredzinc_x_pisoother_x_techootro
# new_paredzinc_x_pisonatur_x_techozinc
# new_paredzinc_x_pisonatur_x_techoentrepiso
# new_paredzinc_x_pisonatur_x_techocane
# new_paredzinc_x_pisonatur_x_techootro
# new_paredzinc_x_pisonotiene_x_techoentrepiso
# new_paredzinc_x_pisonotiene_x_techocane
# new_paredzinc_x_pisonotiene_x_techootro
# new_paredzinc_x_pisomadera_x_techoentrepiso
# new_paredzinc_x_pisomadera_x_techocane
# new_paredzinc_x_pisomadera_x_techootro
# new_paredfibras_x_pisomoscer_x_techoentrepiso
# new_paredfibras_x_pisomoscer_x_techocane
# new_paredfibras_x_pisomoscer_x_techootro
# new_paredfibras_x_pisocemento_x_techoentrepiso
# new_paredfibras_x_pisocemento_x_techocane
# new_paredfibras_x_pisocemento_x_techootro
# new_paredfibras_x_pisoother_x_techozinc
# new_paredfibras_x_pisoother_x_techoentrepiso
# new_paredfibras_x_pisoother_x_techocane
# new_paredfibras_x_pisoother_x_techootro
# new_paredfibras_x_pisonatur_x_techozinc
# new_paredfibras_x_pisonatur_x_techoentrepiso
# new_paredfibras_x_pisonatur_x_techocane
# new_paredfibras_x_pisonatur_x_techootro
# new_paredfibras_x_pisonotiene_x_techozinc
# new_paredfibras_x_pisonotiene_x_techoentrepiso
# new_paredfibras_x_pisonotiene_x_techocane
# new_paredfibras_x_pisonotiene_x_techootro
# new_paredfibras_x_pisomadera_x_techozinc
# new_paredfibras_x_pisomadera_x_techoentrepiso
# new_paredfibras_x_pisomadera_x_techocane
# new_paredfibras_x_pisomadera_x_techootro
# new_paredother_x_pisomoscer_x_techoentrepiso
# new_paredother_x_pisomoscer_x_techocane
# new_paredother_x_pisomoscer_x_techootro
# new_paredother_x_pisocemento_x_techoentrepiso
# new_paredother_x_pisocemento_x_techocane
# new_paredother_x_pisocemento_x_techootro
# new_paredother_x_pisoother_x_techozinc
# new_paredother_x_pisoother_x_techoentrepiso
# new_paredother_x_pisoother_x_techocane
# new_paredother_x_pisoother_x_techootro
# new_paredother_x_pisonatur_x_techozinc
# new_paredother_x_pisonatur_x_techoentrepiso
# new_paredother_x_pisonatur_x_techocane
# new_paredother_x_pisonatur_x_techootro
# new_paredother_x_pisonotiene_x_techozinc
# new_paredother_x_pisonotiene_x_techoentrepiso
# new_paredother_x_pisonotiene_x_techocane
# new_paredother_x_pisonotiene_x_techootro
# new_paredother_x_pisomadera_x_techozinc
# new_paredother_x_pisomadera_x_techoentrepiso
# new_paredother_x_pisomadera_x_techocane
# new_paredother_x_pisomadera_x_techootro

# %% [markdown]
# * Let's remove them!

# %%
df_train.drop(cols_with_only_one_value, axis=1, inplace=True)
df_test.drop(cols_with_only_one_value, axis=1, inplace=True)

# %% [markdown]
# ### Check whether both train and test have same features

# %%
cols_train = np.array(sorted([col for col in df_train.columns if col != 'Target']))
cols_test = np.array(sorted(df_test.columns))

# %%
(cols_train == cols_test).sum() == len(cols_train)
# Out:
# np.True_

# %% [markdown]
# * Good, Let's move!
#
# ## 2.4 aggregation features
#
# * In this competition, each samples are member of specific household(idhogar). So let's aggregate based on 'idhogar' values.
#
# ### Aggregation for family features

# %%
def max_min(x):
    return x.max() - x.min()

# %%
agg_train = pd.DataFrame()
agg_test = pd.DataFrame()

for item in tqdm(family_size_features):
    for i, function in enumerate(['mean', 'std', 'min', 'max', 'sum', 'count', max_min]):
        group_train = df_train[item].groupby(df_train['idhogar']).agg(function)
        group_test = df_test[item].groupby(df_test['idhogar']).agg(function)

        if i == 6:
            new_col = item + '_new_' + 'max_min'
        else:
            new_col = item + '_new_' + function
        agg_train[new_col] = group_train
        agg_test[new_col] = group_test

print('new aggregate train set has {} rows, and {} features'.format(agg_train.shape[0], agg_train.shape[1]))
print('new aggregate test set has {} rows, and {} features'.format(agg_test.shape[0], agg_test.shape[1]))
# Out:
# 100%|██████████| 15/15 [00:05<00:00,  2.82it/s]
# new aggregate train set has 2988 rows, and 105 features
# new aggregate test set has 7352 rows, and 105 features

# %%
aggr_list = ['rez_esc', 'dis', 'male', 'female', 'estadocivil1', 'estadocivil2', 'estadocivil3', 'estadocivil4', 'estadocivil5', 'estadocivil6', 'estadocivil7', 'parentesco2', 'parentesco3', 'parentesco4', 'parentesco5', 'parentesco6', 'parentesco7', 'parentesco8', 'parentesco9', 'parentesco10', 'parentesco11', 'parentesco12', 'instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9', 'epared1', 'epared2', 'epared3', 'etecho1', 'etecho2', 'etecho3', 'eviv1', 'eviv2', 'eviv3', 'refrig', 'television', 'mobilephone', 'area1', 'area2', 'v18q', 'edjef']

for item in tqdm(aggr_list):
    for function in ['count', 'sum']:
        group_train = df_train[item].groupby(df_train['idhogar']).agg(function)
        group_test = df_test[item].groupby(df_test['idhogar']).agg(function)
        new_col = item + '_new1_' + function
        agg_train[new_col] = group_train
        agg_test[new_col] = group_test
print('new aggregate train set has {} rows, and {} features'.format(agg_train.shape[0], agg_train.shape[1]))
print('new aggregate test set has {} rows, and {} features'.format(agg_test.shape[0], agg_test.shape[1]))
# Out:
# 100%|██████████| 47/47 [00:00<00:00, 66.10it/s]
# new aggregate train set has 2988 rows, and 199 features
# new aggregate test set has 7352 rows, and 199 features

# %%
aggr_list = ['escolari', 'age', 'escolari_age', 'dependency', 'bedrooms', 'overcrowding', 'rooms', 'qmobilephone', 'v18q1']

for item in tqdm(aggr_list):
    for function in ['mean', 'std', 'min', 'max', 'sum', 'count', max_min]:
        group_train = df_train[item].groupby(df_train['idhogar']).agg(function)
        group_test = df_test[item].groupby(df_test['idhogar']).agg(function)
        if i == 6:
            new_col = item + '_new2_' + 'max_min'
        else:
            new_col = item + '_new2_' + function
        agg_train[new_col] = group_train
        agg_test[new_col] = group_test

print('new aggregate train set has {} rows, and {} features'.format(agg_train.shape[0], agg_train.shape[1]))
print('new aggregate test set has {} rows, and {} features'.format(agg_test.shape[0], agg_test.shape[1]))
# Out:
# 100%|██████████| 9/9 [00:03<00:00,  2.86it/s]
# new aggregate train set has 2988 rows, and 208 features
# new aggregate test set has 7352 rows, and 208 features

# %%
agg_test = agg_test.reset_index()
agg_train = agg_train.reset_index()

train_agg = pd.merge(df_train, agg_train, on='idhogar')
test = pd.merge(df_test, agg_test, on='idhogar')

train_agg.fillna(value=0, inplace=True)
test.fillna(value=0, inplace=True)

print('train shape:', train_agg.shape, 'test shape:', test.shape)
# Out:
# train shape: (9557, 691) test shape: (23856, 690)

# %%
aggr_list = ['rez_esc', 'dis', 'male', 'female', 'estadocivil1', 'estadocivil2', 'estadocivil3', 'estadocivil4', 'estadocivil5', 'estadocivil6', 'estadocivil7', 'parentesco2', 'parentesco3', 'parentesco4', 'parentesco5', 'parentesco6', 'parentesco7', 'parentesco8', 'parentesco9', 'parentesco10', 'parentesco11', 'parentesco12', 'instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9', 'epared1', 'epared2', 'epared3', 'etecho1', 'etecho2', 'etecho3', 'eviv1', 'eviv2', 'eviv3', 'refrig', 'television', 'mobilephone', 'area1', 'area2', 'v18q', 'edjef']

for lugar in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
    group_train = df_train[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_train.columns = [lugar, 'idhogar'] + ['new3_{}_idhogar_{}'.format(lugar, col) for col in group_train][2:]

    group_test = df_test[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_test.columns = [lugar, 'idhogar'] + ['new3_{}_idhogar_{}'.format(lugar, col) for col in group_test][2:]

    train_agg = pd.merge(train_agg, group_train, on=[lugar, 'idhogar'])
    test = pd.merge(test, group_test, on=[lugar, 'idhogar'])

print('train shape:', train_agg.shape, 'test shape:', test.shape)
# Out:
# train shape: (9557, 973) test shape: (23856, 972)

# %%
aggr_list = ['rez_esc', 'dis', 'male', 'female', 'estadocivil1', 'estadocivil2', 'estadocivil3', 'estadocivil4', 'estadocivil5', 'estadocivil6', 'estadocivil7', 'parentesco2', 'parentesco3', 'parentesco4', 'parentesco5', 'parentesco6', 'parentesco7', 'parentesco8', 'parentesco9', 'parentesco10', 'parentesco11', 'parentesco12', 'instlevel1', 'instlevel2', 'instlevel3', 'instlevel4', 'instlevel5', 'instlevel6', 'instlevel7', 'instlevel8', 'instlevel9', 'epared1', 'epared2', 'epared3', 'etecho1', 'etecho2', 'etecho3', 'eviv1', 'eviv2', 'eviv3', 'refrig', 'television', 'mobilephone', 'area1', 'area2', 'v18q', 'edjef']

for lugar in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
    group_train = df_train[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_train.columns = [lugar, 'idhogar'] + ['new4_{}_idhogar_{}'.format(lugar, col) for col in group_train][2:]

    group_test = df_test[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).sum().reset_index()
    group_test.columns = [lugar, 'idhogar'] + ['new4_{}_idhogar_{}'.format(lugar, col) for col in group_test][2:]

    train_agg = pd.merge(train_agg, group_train, on=[lugar, 'idhogar'])
    test = pd.merge(test, group_test, on=[lugar, 'idhogar'])

print('train shape:', train_agg.shape, 'test shape:', test.shape)
# Out:
# train shape: (9557, 1255) test shape: (23856, 1254)

# %%
cols_nums = ['age', 'meaneduc', 'dependency', 'hogar_nin', 'hogar_adul', 'hogar_mayor', 'hogar_total', 'bedrooms', 'overcrowding']

for function in tqdm(['mean', 'std', 'min', 'max', 'sum', 'count', max_min]):
    for lugar in ['lugar1', 'lugar2', 'lugar3', 'lugar4', 'lugar5', 'lugar6']:
        group_train = df_train[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).agg(function).reset_index()
        group_train.columns = [lugar, 'idhogar'] + ['new5_{}_idhogar_{}_{}'.format(lugar, col, function) for col in group_train][2:]

        group_test = df_test[[lugar, 'idhogar'] + aggr_list].groupby([lugar, 'idhogar']).agg(function).reset_index()
        group_test.columns = [lugar, 'idhogar'] + ['new5_{}_idhogar_{}_{}'.format(lugar, col, function) for col in group_test][2:]

        train_agg = pd.merge(train_agg, group_train, on=[lugar, 'idhogar'])
        test = pd.merge(test, group_test, on=[lugar, 'idhogar'])
    
print('train shape:', train_agg.shape, 'test shape:', test.shape)
# Out:
# 100%|██████████| 7/7 [01:57<00:00, 16.79s/it]
# train shape: (9557, 3229) test shape: (23856, 3228)

# %% [markdown]
# * According to data descriptions, ONLY the heads of household are used in scoring.
# * All household members are included in test + the sample submission, but only heads of households are scored.

# %%
train = train_agg.query('parentesco1==1')

# %%
train['dependency'].replace(np.inf, 0, inplace=True)
test['dependency'].replace(np.inf, 0, inplace=True)

# %%
submission = test[['Id']]

train.drop(columns=['idhogar', 'Id', 'agesq', 'hogar_adul', 'SQBescolari', 'SQBage', 'SQBhogar_total', 'SQBedjefe', 'SQBhogar_nin', 'SQBovercrowding', 'SQBdependency', 'SQBmeaned'], inplace=True)
test.drop(columns=['idhogar', 'Id', 'agesq', 'hogar_adul', 'SQBescolari', 'SQBage', 'SQBhogar_total', 'SQBedjefe', 'SQBhogar_nin', 'SQBovercrowding', 'SQBdependency', 'SQBmeaned'], inplace=True)

correlation = train.corr()
correlation = correlation['Target'].sort_values(ascending=False)

# %%
print('final_data size', train.shape, test.shape)
# Out:
# final_data size (2973, 3217) (23856, 3216)

# %%
print(f'The most 20 positive feature: \n{correlation.head(40)}')
# Out:
# The most 20 positive feature:
# Target                                1.000000
# new5_lugar6_idhogar_edjef_max         0.334254
# new5_lugar4_idhogar_edjef_max         0.334254
# new5_lugar2_idhogar_edjef_max         0.334254
# new5_lugar3_idhogar_edjef_max         0.334254
# new5_lugar1_idhogar_edjef_max         0.334254
# new5_lugar5_idhogar_edjef_max         0.334254
# new5_lugar1_idhogar_edjef_mean        0.333873
# new5_lugar2_idhogar_edjef_mean        0.333873
# new5_lugar6_idhogar_edjef_mean        0.333873
# new5_lugar4_idhogar_edjef_mean        0.333873
# new5_lugar5_idhogar_edjef_mean        0.333873
# new5_lugar3_idhogar_edjef_mean        0.333873
# edjef                                 0.333791
# new5_lugar6_idhogar_edjef_min         0.333791
# new5_lugar4_idhogar_edjef_min         0.333791
# new5_lugar5_idhogar_edjef_min         0.333791
# new5_lugar3_idhogar_edjef_min         0.333791
# new5_lugar1_idhogar_edjef_min         0.333791
# new5_lugar2_idhogar_edjef_min         0.333791
# escolari                              0.333791
# meaneduc                              0.331489
# new5_lugar6_idhogar_instlevel8_max    0.317815
# new5_lugar1_idhogar_instlevel8_max    0.317815
# new5_lugar3_idhogar_instlevel8_max    0.317815
# new5_lugar5_idhogar_instlevel8_max    0.317815
# new5_lugar2_idhogar_instlevel8_max    0.317815
# new5_lugar4_idhogar_instlevel8_max    0.317815
# phones-per-capita                     0.299026
# new5_lugar1_idhogar_instlevel8_std    0.298251
# new5_lugar2_idhogar_instlevel8_std    0.298251
# new5_lugar6_idhogar_instlevel8_std    0.298251
# new5_lugar5_idhogar_instlevel8_std    0.298251
# new5_lugar4_idhogar_instlevel8_std    0.298251
# new5_lugar3_idhogar_instlevel8_std    0.298251
# new_epared3_x_eviv3                   0.298196
# cielorazo                             0.295249
# new4_lugar3_idhogar_instlevel8        0.294277
# new4_lugar6_idhogar_instlevel8        0.294277
# new5_lugar3_idhogar_instlevel8_sum    0.294277
# Name: Target, dtype: float64

# %%
print(f'The most 20 negative feature: \n{correlation.tail(20)}')
# Out:
# The most 20 negative feature:
# new5_lugar5_idhogar_television_<function max_min at 0x0000019FAD158540>    NaN
# new5_lugar5_idhogar_mobilephone_<function max_min at 0x0000019FAD158540>   NaN
# new5_lugar5_idhogar_area1_<function max_min at 0x0000019FAD158540>         NaN
# new5_lugar5_idhogar_area2_<function max_min at 0x0000019FAD158540>         NaN
# new5_lugar5_idhogar_v18q_<function max_min at 0x0000019FAD158540>          NaN
# new5_lugar6_idhogar_epared1_<function max_min at 0x0000019FAD158540>       NaN
# new5_lugar6_idhogar_epared2_<function max_min at 0x0000019FAD158540>       NaN
# new5_lugar6_idhogar_epared3_<function max_min at 0x0000019FAD158540>       NaN
# new5_lugar6_idhogar_etecho1_<function max_min at 0x0000019FAD158540>       NaN
# new5_lugar6_idhogar_etecho2_<function max_min at 0x0000019FAD158540>       NaN
# new5_lugar6_idhogar_etecho3_<function max_min at 0x0000019FAD158540>       NaN
# new5_lugar6_idhogar_eviv1_<function max_min at 0x0000019FAD158540>         NaN
# new5_lugar6_idhogar_eviv2_<function max_min at 0x0000019FAD158540>         NaN
# new5_lugar6_idhogar_eviv3_<function max_min at 0x0000019FAD158540>         NaN
# new5_lugar6_idhogar_refrig_<function max_min at 0x0000019FAD158540>        NaN
# new5_lugar6_idhogar_television_<function max_min at 0x0000019FAD158540>    NaN
# new5_lugar6_idhogar_mobilephone_<function max_min at 0x0000019FAD158540>   NaN
# new5_lugar6_idhogar_area1_<function max_min at 0x0000019FAD158540>         NaN
# new5_lugar6_idhogar_area2_<function max_min at 0x0000019FAD158540>         NaN
# new5_lugar6_idhogar_v18q_<function max_min at 0x0000019FAD158540>          NaN
# Name: Target, dtype: float64

# %% [markdown]
# # 4. Feature selection using shap

# %%
binary_cat_features = [col for col in train.columns if train[col].value_counts().shape[0] == 2]
object_features = ['edjefe', 'edjefa']

categorical_feats = binary_cat_features + object_features

# %%
def evaluate_macroF1_lgb(truth, predictions):
    pred_labels = predictions.reshape(len(np.unique(truth)), -1).argmax(axis=0)
    f1 = f1_score(truth, pred_labels, average='macro')
    return ('macroF1', f1, True)

# %%
y = train['Target']
train.drop(columns=['Target'], inplace=True)

# %%
def print_execution_time(start):
    end = time.time()
    hours, rem = divmod(end-start, 3600)
    minutes, seconds = divmod(rem, 60)
    print('*' * 20, 'Execution ended in {:0>2}h {:0>2}m {:05.2f}s'.format(int(hours), int(minutes), seconds), '*'*20)

# %%
def extract_good_features_using_shap_LGB(params, SEED):
    clf = lgb.LGBMClassifier(objective='multiclass',
                             random_state=1989,
                             max_depth=params['max_depth'],
                             learning_rate=params['learning_rate'],
                            #  silent=True,
                             verbose=-1,
                             metric='multi_logloss',
                             n_jobs=-1,
                             n_estimators=10000,
                             class_weight='balanced',
                             colsample_bytree=params['colsample_bytree'],
                             min_split_gain=params['min_split_gain'],
                             bagging_freq=params['bagging_freq'],
                             min_child_weight=params['min_child_weight'],
                             num_leaves=params['num_leaves'],
                             subsample=params['subsample'],
                             reg_alpha=params['reg_alpha'],
                             reg_lambda=params['reg_lambda'],
                             num_class=len(np.unique(y)),
                             bagging_seed=SEED,
                             seed=SEED,
                             )
    
    kfold = 5
    kf = StratifiedKFold(n_splits=kfold, shuffle=True)
    feat_importance_df = pd.DataFrame()

    for i, (train_index, test_index) in enumerate(kf.split(train, y)):
        print('=' * 30, '{} of {} folds'.format(i+1, kfold), '='*30)
        start = time.time()
        X_train, X_val = train.iloc[train_index], train.iloc[test_index]
        y_train, y_val = y.iloc[train_index], y.iloc[test_index]
        clf.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)], eval_metric=evaluate_macroF1_lgb, categorical_feature=categorical_feats,
                callbacks=[lgb.early_stopping(stopping_rounds=500), lgb.log_evaluation(period=500)])
        shap_values = shap.TreeExplainer(clf.booster_).shap_values(X_train)
        fold_importance_df = pd.DataFrame()
        fold_importance_df['feature'] = X_train.columns
        # fold_importance_df['shap_values'] = abs(np.array(shap_values)[:, :].mean(1).mean(0))
        shap_arr = np.abs(np.array(shap_values))
        if shap_arr.shape[0] == len(X_train):  
            fold_importance_df['shap_values'] = shap_arr.mean(axis=0).mean(axis=-1)
        else:  
            fold_importance_df['shap_values'] = shap_arr.mean(axis=1).mean(axis=0)

        fold_importance_df['feat_imp'] = clf.feature_importances_
        feat_importance_df = pd.concat([feat_importance_df, fold_importance_df])
        print_execution_time(start)
    
    feat_importance_df_shap = feat_importance_df.groupby('feature').mean().sort_values('shap_values', ascending=False).reset_index()
    
    return feat_importance_df_shap

# %%
total_shap_df = pd.DataFrame()
NUM_ITERATIONS = 50
for SEED in range(NUM_ITERATIONS):
    print('#' * 40, '{} of {} iterations'.format(SEED+1, NUM_ITERATIONS), '#'*40)
    params = {'max_depth': np.random.choice([5, 6, 7, 8, 10, 12, -1]),
              'learning_rate': np.random.rand() * 0.02,
              'colsample_bytree': np.random.rand() * (1 - 0.5) + 0.5,
              'subsample': np.random.rand() * (1 - 0.5) + 0.5,
              'min_split_gain': np.random.rand() * 0.2,
              'num_leaves': np.random.choice([32, 48, 64]),
              'reg_alpha': np.random.rand() * 2,
              'reg_lambda': np.random.rand() * 2,
              'bagging_freq': np.random.randint(4) + 1,
              'min_child_weight': np.random.randint(100) + 20
            }
    temp_shap_df = extract_good_features_using_shap_LGB(params, SEED)
    total_shap_df = pd.concat([total_shap_df, temp_shap_df])
# Out:
# ######################################## 1 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04637	training's macroF1: 0.199161	valid_1's multi_logloss: 1.10294	valid_1's macroF1: 0.226578
# Early stopping, best iteration is:
# [494]	training's multi_logloss: 1.04855	training's macroF1: 0.198328	valid_1's multi_logloss: 1.10408	valid_1's macroF1: 0.228697
# ******************** Execution ended in 00h 00m 19.29s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04634	training's macroF1: 0.208787	valid_1's multi_logloss: 1.09341	valid_1's macroF1: 0.216406
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 1.38086	training's macroF1: 0.207725	valid_1's multi_logloss: 1.38034	valid_1's macroF1: 0.230169
# ******************** Execution ended in 00h 00m 09.96s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05191	training's macroF1: 0.20633	valid_1's multi_logloss: 1.07851	valid_1's macroF1: 0.185206
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 1.38083	training's macroF1: 0.202867	valid_1's multi_logloss: 1.3799	valid_1's macroF1: 0.197737
# ******************** Execution ended in 00h 00m 08.82s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.03484	training's macroF1: 0.201168	valid_1's multi_logloss: 1.10858	valid_1's macroF1: 0.19439
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 1.38346	training's macroF1: 0.207947	valid_1's multi_logloss: 1.38318	valid_1's macroF1: 0.203301
# ******************** Execution ended in 00h 00m 09.72s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05728	training's macroF1: 0.192131	valid_1's multi_logloss: 1.0664	valid_1's macroF1: 0.218329
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.38492	training's macroF1: 0.188175	valid_1's multi_logloss: 1.38468	valid_1's macroF1: 0.231367
# ******************** Execution ended in 00h 00m 09.92s ********************
# ######################################## 2 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04834	training's macroF1: 0.216439	valid_1's multi_logloss: 1.06795	valid_1's macroF1: 0.217226
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.38371	training's macroF1: 0.206016	valid_1's multi_logloss: 1.38284	valid_1's macroF1: 0.221444
# ******************** Execution ended in 00h 00m 08.80s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05452	training's macroF1: 0.211572	valid_1's multi_logloss: 1.06274	valid_1's macroF1: 0.19174
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 1.37418	training's macroF1: 0.215525	valid_1's multi_logloss: 1.36949	valid_1's macroF1: 0.213966
# ******************** Execution ended in 00h 00m 09.30s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.03303	training's macroF1: 0.204471	valid_1's multi_logloss: 1.10195	valid_1's macroF1: 0.185095
# Early stopping, best iteration is:
# [345]	training's multi_logloss: 1.0761	training's macroF1: 0.208938	valid_1's multi_logloss: 1.10882	valid_1's macroF1: 0.193666
# ******************** Execution ended in 00h 00m 29.14s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05717	training's macroF1: 0.208003	valid_1's multi_logloss: 1.03	valid_1's macroF1: 0.200807
# Early stopping, best iteration is:
# [377]	training's multi_logloss: 1.08875	training's macroF1: 0.208979	valid_1's multi_logloss: 1.03841	valid_1's macroF1: 0.209742
# ******************** Execution ended in 00h 00m 50.67s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04217	training's macroF1: 0.197817	valid_1's multi_logloss: 1.08829	valid_1's macroF1: 0.17879
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 1.37604	training's macroF1: 0.20487	valid_1's multi_logloss: 1.37267	valid_1's macroF1: 0.214391
# ******************** Execution ended in 00h 00m 28.89s ********************
# ######################################## 3 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.958599	training's macroF1: 0.20158	valid_1's multi_logloss: 1.10102	valid_1's macroF1: 0.196898
# Early stopping, best iteration is:
# [260]	training's multi_logloss: 1.0379	training's macroF1: 0.207863	valid_1's multi_logloss: 1.10263	valid_1's macroF1: 0.209118
# ******************** Execution ended in 00h 01m 07.54s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.973718	training's macroF1: 0.208268	valid_1's multi_logloss: 1.03234	valid_1's macroF1: 0.182452
# Early stopping, best iteration is:
# [6]	training's multi_logloss: 1.35685	training's macroF1: 0.214189	valid_1's multi_logloss: 1.34268	valid_1's macroF1: 0.21747
# ******************** Execution ended in 00h 00m 52.80s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.966433	training's macroF1: 0.20483	valid_1's multi_logloss: 1.02994	valid_1's macroF1: 0.219589
# Early stopping, best iteration is:
# [23]	training's multi_logloss: 1.29543	training's macroF1: 0.207979	valid_1's multi_logloss: 1.25735	valid_1's macroF1: 0.228818
# ******************** Execution ended in 00h 00m 42.42s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.960707	training's macroF1: 0.217407	valid_1's multi_logloss: 1.05801	valid_1's macroF1: 0.189286
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.37109	training's macroF1: 0.211692	valid_1's multi_logloss: 1.36169	valid_1's macroF1: 0.216129
# ******************** Execution ended in 00h 00m 59.32s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.961886	training's macroF1: 0.19796	valid_1's multi_logloss: 1.10458	valid_1's macroF1: 0.193185
# Early stopping, best iteration is:
# [478]	training's multi_logloss: 0.967591	training's macroF1: 0.196623	valid_1's multi_logloss: 1.10382	valid_1's macroF1: 0.20714
# ******************** Execution ended in 00h 00m 52.49s ********************
# ######################################## 4 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.87983	training's macroF1: 0.199415	valid_1's multi_logloss: 1.03464	valid_1's macroF1: 0.213934
# Early stopping, best iteration is:
# [12]	training's multi_logloss: 1.34134	training's macroF1: 0.199559	valid_1's multi_logloss: 1.33238	valid_1's macroF1: 0.215531
# ******************** Execution ended in 00h 01m 39.65s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.879875	training's macroF1: 0.218479	valid_1's multi_logloss: 1.03278	valid_1's macroF1: 0.17786
# Early stopping, best iteration is:
# [12]	training's multi_logloss: 1.34369	training's macroF1: 0.208523	valid_1's multi_logloss: 1.33827	valid_1's macroF1: 0.19577
# ******************** Execution ended in 00h 00m 51.49s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.875307	training's macroF1: 0.210157	valid_1's multi_logloss: 1.02813	valid_1's macroF1: 0.174105
# Early stopping, best iteration is:
# [412]	training's multi_logloss: 0.91143	training's macroF1: 0.209598	valid_1's multi_logloss: 1.03145	valid_1's macroF1: 0.176605
# ******************** Execution ended in 00h 01m 00.76s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.888159	training's macroF1: 0.204262	valid_1's multi_logloss: 1.02326	valid_1's macroF1: 0.197193
# Early stopping, best iteration is:
# [14]	training's multi_logloss: 1.33756	training's macroF1: 0.197764	valid_1's multi_logloss: 1.32253	valid_1's macroF1: 0.203591
# ******************** Execution ended in 00h 00m 21.61s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.874748	training's macroF1: 0.199715	valid_1's multi_logloss: 1.03203	valid_1's macroF1: 0.208173
# [1000]	training's multi_logloss: 0.732221	training's macroF1: 0.199069	valid_1's multi_logloss: 1.0283	valid_1's macroF1: 0.214043
# Early stopping, best iteration is:
# [642]	training's multi_logloss: 0.825548	training's macroF1: 0.200383	valid_1's multi_logloss: 1.02606	valid_1's macroF1: 0.210265
# ******************** Execution ended in 00h 00m 32.76s ********************
# ######################################## 5 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.21833	training's macroF1: 0.207182	valid_1's multi_logloss: 1.16312	valid_1's macroF1: 0.208856
# Early stopping, best iteration is:
# [55]	training's multi_logloss: 1.35876	training's macroF1: 0.222576	valid_1's multi_logloss: 1.34641	valid_1's macroF1: 0.221724
# ******************** Execution ended in 00h 00m 24.45s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.21948	training's macroF1: 0.20864	valid_1's multi_logloss: 1.17114	valid_1's macroF1: 0.221122
# Early stopping, best iteration is:
# [19]	training's multi_logloss: 1.3761	training's macroF1: 0.211386	valid_1's multi_logloss: 1.37185	valid_1's macroF1: 0.226123
# ******************** Execution ended in 00h 00m 30.46s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.20707	training's macroF1: 0.195725	valid_1's multi_logloss: 1.1946	valid_1's macroF1: 0.206378
# Early stopping, best iteration is:
# [248]	training's multi_logloss: 1.27297	training's macroF1: 0.198576	valid_1's multi_logloss: 1.25578	valid_1's macroF1: 0.220118
# ******************** Execution ended in 00h 00m 36.18s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.21799	training's macroF1: 0.196654	valid_1's multi_logloss: 1.14842	valid_1's macroF1: 0.190788
# Early stopping, best iteration is:
# [72]	training's multi_logloss: 1.34956	training's macroF1: 0.202155	valid_1's multi_logloss: 1.33246	valid_1's macroF1: 0.201547
# ******************** Execution ended in 00h 00m 25.25s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.21327	training's macroF1: 0.197725	valid_1's multi_logloss: 1.16388	valid_1's macroF1: 0.211566
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.38574	training's macroF1: 0.196761	valid_1's multi_logloss: 1.38546	valid_1's macroF1: 0.250504
# ******************** Execution ended in 00h 00m 23.64s ********************
# ######################################## 6 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05994	training's macroF1: 0.212846	valid_1's multi_logloss: 1.05552	valid_1's macroF1: 0.202084
# Early stopping, best iteration is:
# [10]	training's multi_logloss: 1.36655	training's macroF1: 0.210548	valid_1's multi_logloss: 1.35579	valid_1's macroF1: 0.223101
# ******************** Execution ended in 00h 00m 23.77s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.07822	training's macroF1: 0.19418	valid_1's multi_logloss: 1.05418	valid_1's macroF1: 0.19478
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 1.3771	training's macroF1: 0.194528	valid_1's multi_logloss: 1.37267	valid_1's macroF1: 0.20325
# ******************** Execution ended in 00h 00m 23.43s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.06467	training's macroF1: 0.203056	valid_1's multi_logloss: 1.08061	valid_1's macroF1: 0.229503
# [1000]	training's multi_logloss: 0.980187	training's macroF1: 0.207489	valid_1's multi_logloss: 1.07859	valid_1's macroF1: 0.216412
# Early stopping, best iteration is:
# [504]	training's multi_logloss: 1.06384	training's macroF1: 0.202951	valid_1's multi_logloss: 1.08031	valid_1's macroF1: 0.230544
# ******************** Execution ended in 00h 00m 44.59s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.07385	training's macroF1: 0.197514	valid_1's multi_logloss: 1.06721	valid_1's macroF1: 0.213503
# Early stopping, best iteration is:
# [132]	training's multi_logloss: 1.22112	training's macroF1: 0.206424	valid_1's multi_logloss: 1.17616	valid_1's macroF1: 0.230319
# ******************** Execution ended in 00h 00m 34.46s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.06619	training's macroF1: 0.204478	valid_1's multi_logloss: 1.1	valid_1's macroF1: 0.202059
# Early stopping, best iteration is:
# [54]	training's multi_logloss: 1.29854	training's macroF1: 0.207374	valid_1's multi_logloss: 1.27479	valid_1's macroF1: 0.213848
# ******************** Execution ended in 00h 00m 25.95s ********************
# ######################################## 7 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04335	training's macroF1: 0.207693	valid_1's multi_logloss: 1.07966	valid_1's macroF1: 0.224873
# [1000]	training's multi_logloss: 0.918281	training's macroF1: 0.206125	valid_1's multi_logloss: 1.05051	valid_1's macroF1: 0.231971
# [1500]	training's multi_logloss: 0.838251	training's macroF1: 0.206596	valid_1's multi_logloss: 1.04762	valid_1's macroF1: 0.233363
# Early stopping, best iteration is:
# [1254]	training's multi_logloss: 0.874723	training's macroF1: 0.20504	valid_1's multi_logloss: 1.04904	valid_1's macroF1: 0.236853
# ******************** Execution ended in 00h 01m 43.40s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.0496	training's macroF1: 0.213752	valid_1's multi_logloss: 1.08462	valid_1's macroF1: 0.208001
# Early stopping, best iteration is:
# [10]	training's multi_logloss: 1.37212	training's macroF1: 0.216655	valid_1's multi_logloss: 1.36872	valid_1's macroF1: 0.218259
# ******************** Execution ended in 00h 00m 33.64s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.0523	training's macroF1: 0.211138	valid_1's multi_logloss: 1.07494	valid_1's macroF1: 0.190354
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.38205	training's macroF1: 0.200543	valid_1's multi_logloss: 1.38118	valid_1's macroF1: 0.219599
# ******************** Execution ended in 00h 00m 50.21s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05268	training's macroF1: 0.204651	valid_1's multi_logloss: 1.03854	valid_1's macroF1: 0.20529
# Early stopping, best iteration is:
# [26]	training's multi_logloss: 1.34945	training's macroF1: 0.206103	valid_1's multi_logloss: 1.33844	valid_1's macroF1: 0.209426
# ******************** Execution ended in 00h 02m 46.19s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05209	training's macroF1: 0.211999	valid_1's multi_logloss: 1.08446	valid_1's macroF1: 0.184703
# Early stopping, best iteration is:
# [40]	training's multi_logloss: 1.33379	training's macroF1: 0.200743	valid_1's multi_logloss: 1.32476	valid_1's macroF1: 0.200305
# ******************** Execution ended in 00h 00m 32.21s ********************
# ######################################## 8 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.935716	training's macroF1: 0.203274	valid_1's multi_logloss: 1.027	valid_1's macroF1: 0.19282
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.38228	training's macroF1: 0.196027	valid_1's multi_logloss: 1.38099	valid_1's macroF1: 0.210924
# ******************** Execution ended in 00h 00m 25.30s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.934658	training's macroF1: 0.208147	valid_1's multi_logloss: 0.996626	valid_1's macroF1: 0.18766
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 1.36046	training's macroF1: 0.201873	valid_1's multi_logloss: 1.34883	valid_1's macroF1: 0.204946
# ******************** Execution ended in 00h 00m 12.91s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.934033	training's macroF1: 0.202848	valid_1's multi_logloss: 1.0716	valid_1's macroF1: 0.202998
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.37469	training's macroF1: 0.205429	valid_1's multi_logloss: 1.37058	valid_1's macroF1: 0.234583
# ******************** Execution ended in 00h 00m 16.72s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.941972	training's macroF1: 0.216498	valid_1's multi_logloss: 1.05947	valid_1's macroF1: 0.209675
# [1000]	training's multi_logloss: 0.825014	training's macroF1: 0.21549	valid_1's multi_logloss: 1.04945	valid_1's macroF1: 0.22929
# [1500]	training's multi_logloss: 0.748597	training's macroF1: 0.214144	valid_1's multi_logloss: 1.04543	valid_1's macroF1: 0.227891
# Early stopping, best iteration is:
# [1213]	training's multi_logloss: 0.789045	training's macroF1: 0.216859	valid_1's multi_logloss: 1.04699	valid_1's macroF1: 0.234058
# ******************** Execution ended in 00h 00m 50.34s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.950422	training's macroF1: 0.201737	valid_1's multi_logloss: 1.05993	valid_1's macroF1: 0.203588
# Early stopping, best iteration is:
# [310]	training's multi_logloss: 1.01874	training's macroF1: 0.203499	valid_1's multi_logloss: 1.07566	valid_1's macroF1: 0.211975
# ******************** Execution ended in 00h 00m 27.55s ********************
# ######################################## 9 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.821878	training's macroF1: 0.200469	valid_1's multi_logloss: 1.03372	valid_1's macroF1: 0.201321
# Early stopping, best iteration is:
# [205]	training's multi_logloss: 1.01239	training's macroF1: 0.204274	valid_1's multi_logloss: 1.07418	valid_1's macroF1: 0.215562
# ******************** Execution ended in 00h 00m 12.19s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.821364	training's macroF1: 0.206704	valid_1's multi_logloss: 1.01402	valid_1's macroF1: 0.189283
# Early stopping, best iteration is:
# [123]	training's multi_logloss: 1.10805	training's macroF1: 0.211738	valid_1's multi_logloss: 1.11104	valid_1's macroF1: 0.20594
# ******************** Execution ended in 00h 00m 10.66s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.826882	training's macroF1: 0.203235	valid_1's multi_logloss: 1.02602	valid_1's macroF1: 0.18737
# Early stopping, best iteration is:
# [94]	training's multi_logloss: 1.15697	training's macroF1: 0.199859	valid_1's multi_logloss: 1.16466	valid_1's macroF1: 0.21267
# ******************** Execution ended in 00h 00m 10.38s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.821142	training's macroF1: 0.196767	valid_1's multi_logloss: 0.98829	valid_1's macroF1: 0.193927
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 1.37188	training's macroF1: 0.197683	valid_1's multi_logloss: 1.36902	valid_1's macroF1: 0.202028
# ******************** Execution ended in 00h 00m 08.53s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.826307	training's macroF1: 0.221685	valid_1's multi_logloss: 1.02685	valid_1's macroF1: 0.222318
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 1.37919	training's macroF1: 0.20292	valid_1's multi_logloss: 1.37806	valid_1's macroF1: 0.231492
# ******************** Execution ended in 00h 00m 08.65s ********************
# ######################################## 10 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.03158	training's macroF1: 0.203381	valid_1's multi_logloss: 1.08151	valid_1's macroF1: 0.202337
# Early stopping, best iteration is:
# [9]	training's multi_logloss: 1.36049	training's macroF1: 0.20487	valid_1's multi_logloss: 1.35211	valid_1's macroF1: 0.208431
# ******************** Execution ended in 00h 00m 06.81s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.0493	training's macroF1: 0.212745	valid_1's multi_logloss: 1.07333	valid_1's macroF1: 0.182909
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 1.36824	training's macroF1: 0.205518	valid_1's multi_logloss: 1.36175	valid_1's macroF1: 0.206171
# ******************** Execution ended in 00h 00m 06.74s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.03959	training's macroF1: 0.214724	valid_1's multi_logloss: 1.09302	valid_1's macroF1: 0.204425
# Early stopping, best iteration is:
# [30]	training's multi_logloss: 1.31342	training's macroF1: 0.208848	valid_1's multi_logloss: 1.28769	valid_1's macroF1: 0.209597
# ******************** Execution ended in 00h 00m 07.25s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.0557	training's macroF1: 0.197466	valid_1's multi_logloss: 1.05155	valid_1's macroF1: 0.193292
# Early stopping, best iteration is:
# [102]	training's multi_logloss: 1.22025	training's macroF1: 0.197754	valid_1's multi_logloss: 1.15699	valid_1's macroF1: 0.205906
# ******************** Execution ended in 00h 00m 08.17s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05387	training's macroF1: 0.20978	valid_1's multi_logloss: 1.08194	valid_1's macroF1: 0.218403
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 1.36818	training's macroF1: 0.207029	valid_1's multi_logloss: 1.36104	valid_1's macroF1: 0.227805
# ******************** Execution ended in 00h 00m 06.91s ********************
# ######################################## 11 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.00445	training's macroF1: 0.214013	valid_1's multi_logloss: 1.05935	valid_1's macroF1: 0.224533
# Early stopping, best iteration is:
# [63]	training's multi_logloss: 1.23943	training's macroF1: 0.205652	valid_1's multi_logloss: 1.19393	valid_1's macroF1: 0.228156
# ******************** Execution ended in 00h 00m 07.05s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.00901	training's macroF1: 0.200178	valid_1's multi_logloss: 1.05512	valid_1's macroF1: 0.17392
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 1.36347	training's macroF1: 0.206669	valid_1's multi_logloss: 1.35129	valid_1's macroF1: 0.183221
# ******************** Execution ended in 00h 00m 07.16s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.00197	training's macroF1: 0.214666	valid_1's multi_logloss: 1.11629	valid_1's macroF1: 0.203901
# Early stopping, best iteration is:
# [42]	training's multi_logloss: 1.27756	training's macroF1: 0.227806	valid_1's multi_logloss: 1.26684	valid_1's macroF1: 0.218049
# ******************** Execution ended in 00h 00m 07.38s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.0189	training's macroF1: 0.198428	valid_1's multi_logloss: 1.04552	valid_1's macroF1: 0.206005
# Early stopping, best iteration is:
# [21]	training's multi_logloss: 1.32624	training's macroF1: 0.19464	valid_1's multi_logloss: 1.29534	valid_1's macroF1: 0.236151
# ******************** Execution ended in 00h 00m 07.00s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.00179	training's macroF1: 0.204208	valid_1's multi_logloss: 1.05861	valid_1's macroF1: 0.215729
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 1.36457	training's macroF1: 0.209408	valid_1's multi_logloss: 1.35276	valid_1's macroF1: 0.232656
# ******************** Execution ended in 00h 00m 06.55s ********************
# ######################################## 12 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.00242	training's macroF1: 0.212772	valid_1's multi_logloss: 1.04132	valid_1's macroF1: 0.190679
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 1.37013	training's macroF1: 0.221623	valid_1's multi_logloss: 1.36233	valid_1's macroF1: 0.21298
# ******************** Execution ended in 00h 00m 08.24s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.994208	training's macroF1: 0.206849	valid_1's multi_logloss: 1.04838	valid_1's macroF1: 0.192343
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.38202	training's macroF1: 0.191444	valid_1's multi_logloss: 1.38078	valid_1's macroF1: 0.223309
# ******************** Execution ended in 00h 00m 08.37s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.993272	training's macroF1: 0.203729	valid_1's multi_logloss: 1.08378	valid_1's macroF1: 0.187045
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 1.36896	training's macroF1: 0.196893	valid_1's multi_logloss: 1.36333	valid_1's macroF1: 0.212897
# ******************** Execution ended in 00h 00m 08.20s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.993289	training's macroF1: 0.19948	valid_1's multi_logloss: 1.06496	valid_1's macroF1: 0.213041
# Early stopping, best iteration is:
# [336]	training's multi_logloss: 1.03951	training's macroF1: 0.199432	valid_1's multi_logloss: 1.06812	valid_1's macroF1: 0.229101
# ******************** Execution ended in 00h 00m 13.40s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.99878	training's macroF1: 0.1917	valid_1's multi_logloss: 1.0962	valid_1's macroF1: 0.206321
# [1000]	training's multi_logloss: 0.905108	training's macroF1: 0.194837	valid_1's multi_logloss: 1.09429	valid_1's macroF1: 0.205698
# Early stopping, best iteration is:
# [618]	training's multi_logloss: 0.972088	training's macroF1: 0.193923	valid_1's multi_logloss: 1.09538	valid_1's macroF1: 0.220301
# ******************** Execution ended in 00h 00m 17.40s ********************
# ######################################## 13 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.20543	training's macroF1: 0.215101	valid_1's multi_logloss: 1.13849	valid_1's macroF1: 0.207008
# Early stopping, best iteration is:
# [131]	training's multi_logloss: 1.3148	training's macroF1: 0.212396	valid_1's multi_logloss: 1.28421	valid_1's macroF1: 0.212127
# ******************** Execution ended in 00h 00m 07.59s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.20628	training's macroF1: 0.203199	valid_1's multi_logloss: 1.15858	valid_1's macroF1: 0.191656
# Early stopping, best iteration is:
# [103]	training's multi_logloss: 1.32736	training's macroF1: 0.202775	valid_1's multi_logloss: 1.3027	valid_1's macroF1: 0.212747
# ******************** Execution ended in 00h 00m 07.43s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.21103	training's macroF1: 0.216254	valid_1's multi_logloss: 1.16274	valid_1's macroF1: 0.19247
# Early stopping, best iteration is:
# [29]	training's multi_logloss: 1.36718	training's macroF1: 0.204312	valid_1's multi_logloss: 1.35979	valid_1's macroF1: 0.218543
# ******************** Execution ended in 00h 00m 06.70s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.20961	training's macroF1: 0.19313	valid_1's multi_logloss: 1.15206	valid_1's macroF1: 0.172053
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 1.38495	training's macroF1: 0.193452	valid_1's multi_logloss: 1.38416	valid_1's macroF1: 0.191454
# ******************** Execution ended in 00h 00m 06.17s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.20433	training's macroF1: 0.203142	valid_1's multi_logloss: 1.15662	valid_1's macroF1: 0.169218
# Early stopping, best iteration is:
# [10]	training's multi_logloss: 1.37944	training's macroF1: 0.214502	valid_1's multi_logloss: 1.37619	valid_1's macroF1: 0.186293
# ******************** Execution ended in 00h 00m 06.31s ********************
# ######################################## 14 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.1085	training's macroF1: 0.228738	valid_1's multi_logloss: 1.09957	valid_1's macroF1: 0.19481
# Early stopping, best iteration is:
# [109]	training's multi_logloss: 1.25095	training's macroF1: 0.223427	valid_1's multi_logloss: 1.21568	valid_1's macroF1: 0.21388
# ******************** Execution ended in 00h 00m 07.28s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.12612	training's macroF1: 0.207364	valid_1's multi_logloss: 1.07366	valid_1's macroF1: 0.2135
# Early stopping, best iteration is:
# [45]	training's multi_logloss: 1.32022	training's macroF1: 0.208522	valid_1's multi_logloss: 1.28609	valid_1's macroF1: 0.220041
# ******************** Execution ended in 00h 00m 06.74s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.12075	training's macroF1: 0.203135	valid_1's multi_logloss: 1.08102	valid_1's macroF1: 0.193831
# Early stopping, best iteration is:
# [20]	training's multi_logloss: 1.35151	training's macroF1: 0.195358	valid_1's multi_logloss: 1.33349	valid_1's macroF1: 0.207566
# ******************** Execution ended in 00h 00m 06.39s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11742	training's macroF1: 0.212138	valid_1's multi_logloss: 1.10564	valid_1's macroF1: 0.214417
# Early stopping, best iteration is:
# [19]	training's multi_logloss: 1.35238	training's macroF1: 0.204744	valid_1's multi_logloss: 1.33984	valid_1's macroF1: 0.23829
# ******************** Execution ended in 00h 00m 06.20s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.12058	training's macroF1: 0.199303	valid_1's multi_logloss: 1.0968	valid_1's macroF1: 0.20824
# Early stopping, best iteration is:
# [51]	training's multi_logloss: 1.30992	training's macroF1: 0.201577	valid_1's multi_logloss: 1.28498	valid_1's macroF1: 0.220032
# ******************** Execution ended in 00h 00m 06.82s ********************
# ######################################## 15 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.03584	training's macroF1: 0.208672	valid_1's multi_logloss: 1.05784	valid_1's macroF1: 0.204739
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 1.37966	training's macroF1: 0.204743	valid_1's multi_logloss: 1.37608	valid_1's macroF1: 0.207898
# ******************** Execution ended in 00h 00m 08.60s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.02764	training's macroF1: 0.221073	valid_1's multi_logloss: 1.11446	valid_1's macroF1: 0.218601
# Early stopping, best iteration is:
# [9]	training's multi_logloss: 1.35696	training's macroF1: 0.217669	valid_1's multi_logloss: 1.34801	valid_1's macroF1: 0.226974
# ******************** Execution ended in 00h 00m 08.83s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.02397	training's macroF1: 0.212508	valid_1's multi_logloss: 1.08775	valid_1's macroF1: 0.189886
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.3826	training's macroF1: 0.207986	valid_1's multi_logloss: 1.38166	valid_1's macroF1: 0.22073
# ******************** Execution ended in 00h 00m 08.65s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.03713	training's macroF1: 0.19594	valid_1's multi_logloss: 1.06058	valid_1's macroF1: 0.205216
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.37531	training's macroF1: 0.197267	valid_1's multi_logloss: 1.37226	valid_1's macroF1: 0.2327
# ******************** Execution ended in 00h 00m 08.46s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04373	training's macroF1: 0.195291	valid_1's multi_logloss: 1.06074	valid_1's macroF1: 0.180197
# Early stopping, best iteration is:
# [26]	training's multi_logloss: 1.31294	training's macroF1: 0.200617	valid_1's multi_logloss: 1.27633	valid_1's macroF1: 0.213389
# ******************** Execution ended in 00h 00m 08.84s ********************
# ######################################## 16 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.832868	training's macroF1: 0.220553	valid_1's multi_logloss: 1.01351	valid_1's macroF1: 0.192832
# Early stopping, best iteration is:
# [40]	training's multi_logloss: 1.25857	training's macroF1: 0.216488	valid_1's multi_logloss: 1.24711	valid_1's macroF1: 0.218608
# ******************** Execution ended in 00h 00m 11.46s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.835797	training's macroF1: 0.205624	valid_1's multi_logloss: 0.996588	valid_1's macroF1: 0.231842
# Early stopping, best iteration is:
# [172]	training's multi_logloss: 1.04309	training's macroF1: 0.205462	valid_1's multi_logloss: 1.07311	valid_1's macroF1: 0.244879
# ******************** Execution ended in 00h 00m 13.40s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.829322	training's macroF1: 0.207526	valid_1's multi_logloss: 1.04071	valid_1's macroF1: 0.192801
# Early stopping, best iteration is:
# [203]	training's multi_logloss: 1.00988	training's macroF1: 0.214878	valid_1's multi_logloss: 1.07995	valid_1's macroF1: 0.203192
# ******************** Execution ended in 00h 00m 21.71s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.825951	training's macroF1: 0.212908	valid_1's multi_logloss: 1.00258	valid_1's macroF1: 0.187847
# Early stopping, best iteration is:
# [236]	training's multi_logloss: 0.982542	training's macroF1: 0.21194	valid_1's multi_logloss: 1.03586	valid_1's macroF1: 0.208732
# ******************** Execution ended in 00h 00m 23.08s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.826727	training's macroF1: 0.198454	valid_1's multi_logloss: 1.06972	valid_1's macroF1: 0.228264
# Early stopping, best iteration is:
# [126]	training's multi_logloss: 1.09782	training's macroF1: 0.197386	valid_1's multi_logloss: 1.15185	valid_1's macroF1: 0.233487
# ******************** Execution ended in 00h 00m 40.30s ********************
# ######################################## 17 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04022	training's macroF1: 0.212005	valid_1's multi_logloss: 1.12575	valid_1's macroF1: 0.209177
# Early stopping, best iteration is:
# [8]	training's multi_logloss: 1.36391	training's macroF1: 0.216977	valid_1's multi_logloss: 1.35762	valid_1's macroF1: 0.216414
# ******************** Execution ended in 00h 00m 12.27s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05342	training's macroF1: 0.19877	valid_1's multi_logloss: 1.02198	valid_1's macroF1: 0.196923
# Early stopping, best iteration is:
# [38]	training's multi_logloss: 1.30103	training's macroF1: 0.210731	valid_1's multi_logloss: 1.2565	valid_1's macroF1: 0.223095
# ******************** Execution ended in 00h 00m 10.99s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.04585	training's macroF1: 0.19684	valid_1's multi_logloss: 1.05753	valid_1's macroF1: 0.190497
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.37768	training's macroF1: 0.198838	valid_1's multi_logloss: 1.37342	valid_1's macroF1: 0.202683
# ******************** Execution ended in 00h 00m 09.80s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.05451	training's macroF1: 0.211897	valid_1's multi_logloss: 1.07694	valid_1's macroF1: 0.23728
# Early stopping, best iteration is:
# [377]	training's multi_logloss: 1.08279	training's macroF1: 0.21489	valid_1's multi_logloss: 1.083	valid_1's macroF1: 0.245156
# ******************** Execution ended in 00h 00m 41.93s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.0599	training's macroF1: 0.198086	valid_1's multi_logloss: 1.06888	valid_1's macroF1: 0.213942
# Early stopping, best iteration is:
# [301]	training's multi_logloss: 1.10969	training's macroF1: 0.199103	valid_1's multi_logloss: 1.08183	valid_1's macroF1: 0.227741
# ******************** Execution ended in 00h 00m 55.84s ********************
# ######################################## 18 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.17299	training's macroF1: 0.20754	valid_1's multi_logloss: 1.11342	valid_1's macroF1: 0.194519
# Early stopping, best iteration is:
# [12]	training's multi_logloss: 1.37349	training's macroF1: 0.19674	valid_1's multi_logloss: 1.3679	valid_1's macroF1: 0.214297
# ******************** Execution ended in 00h 00m 34.90s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.16753	training's macroF1: 0.212497	valid_1's multi_logloss: 1.1427	valid_1's macroF1: 0.186592
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 1.37838	training's macroF1: 0.207358	valid_1's multi_logloss: 1.37637	valid_1's macroF1: 0.195438
# ******************** Execution ended in 00h 00m 20.51s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.16492	training's macroF1: 0.208523	valid_1's multi_logloss: 1.12758	valid_1's macroF1: 0.193407
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 1.38431	training's macroF1: 0.205535	valid_1's multi_logloss: 1.38329	valid_1's macroF1: 0.199412
# ******************** Execution ended in 00h 00m 20.15s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.16707	training's macroF1: 0.181958	valid_1's multi_logloss: 1.10277	valid_1's macroF1: 0.219361
# Early stopping, best iteration is:
# [438]	training's multi_logloss: 1.17891	training's macroF1: 0.182877	valid_1's multi_logloss: 1.11307	valid_1's macroF1: 0.232026
# ******************** Execution ended in 00h 00m 36.20s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# ...
# [500]	training's multi_logloss: 1.14143	training's macroF1: 0.208456	valid_1's multi_logloss: 1.09908	valid_1's macroF1: 0.200114
# Early stopping, best iteration is:
# [269]	training's multi_logloss: 1.21377	training's macroF1: 0.210929	valid_1's multi_logloss: 1.16873	valid_1's macroF1: 0.205169
# ******************** Execution ended in 00h 00m 18.55s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.12924	training's macroF1: 0.197644	valid_1's multi_logloss: 1.10456	valid_1's macroF1: 0.208202
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 1.38397	training's macroF1: 0.196096	valid_1's multi_logloss: 1.38334	valid_1's macroF1: 0.232803
# ******************** Execution ended in 00h 00m 08.55s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.11527	training's macroF1: 0.213855	valid_1's multi_logloss: 1.131	valid_1's macroF1: 0.187619
# Early stopping, best iteration is:
# [28]	training's multi_logloss: 1.35461	training's macroF1: 0.210269	valid_1's multi_logloss: 1.34724	valid_1's macroF1: 0.21638
# ******************** Execution ended in 00h 00m 08.99s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.12902	training's macroF1: 0.209168	valid_1's multi_logloss: 1.11627	valid_1's macroF1: 0.202974
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 1.38066	training's macroF1: 0.202422	valid_1's multi_logloss: 1.37892	valid_1's macroF1: 0.218044
# ******************** Execution ended in 00h 00m 09.62s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.12809	training's macroF1: 0.19882	valid_1's multi_logloss: 1.12215	valid_1's macroF1: 0.216453
# [1000]	training's multi_logloss: 1.03962	training's macroF1: 0.199564	valid_1's multi_logloss: 1.08067	valid_1's macroF1: 0.20441
# Early stopping, best iteration is:
# [615]	training's multi_logloss: 1.10178	training's macroF1: 0.200583	valid_1's multi_logloss: 1.10687	valid_1's macroF1: 0.222585
# ******************** Execution ended in 00h 00m 21.40s ********************
# ######################################## 46 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.675478	training's macroF1: 0.183596	valid_1's multi_logloss: 1.03321	valid_1's macroF1: 0.196924
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.36195	training's macroF1: 0.198282	valid_1's multi_logloss: 1.35544	valid_1's macroF1: 0.209893
# ******************** Execution ended in 00h 00m 24.54s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.676527	training's macroF1: 0.213908	valid_1's multi_logloss: 0.978116	valid_1's macroF1: 0.197591
# Early stopping, best iteration is:
# [16]	training's multi_logloss: 1.27953	training's macroF1: 0.208698	valid_1's multi_logloss: 1.25156	valid_1's macroF1: 0.226218
# ******************** Execution ended in 00h 00m 10.28s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.679618	training's macroF1: 0.198947	valid_1's multi_logloss: 1.01257	valid_1's macroF1: 0.213717
# Early stopping, best iteration is:
# [18]	training's multi_logloss: 1.26504	training's macroF1: 0.200113	valid_1's multi_logloss: 1.25057	valid_1's macroF1: 0.243864
# ******************** Execution ended in 00h 00m 11.70s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.672822	training's macroF1: 0.194774	valid_1's multi_logloss: 1.04487	valid_1's macroF1: 0.196563
# Early stopping, best iteration is:
# [24]	training's multi_logloss: 1.23614	training's macroF1: 0.199868	valid_1's multi_logloss: 1.24393	valid_1's macroF1: 0.212497
# ******************** Execution ended in 00h 00m 09.95s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.675304	training's macroF1: 0.208549	valid_1's multi_logloss: 1.01618	valid_1's macroF1: 0.200674
# Early stopping, best iteration is:
# [356]	training's multi_logloss: 0.753565	training's macroF1: 0.206875	valid_1's multi_logloss: 1.01928	valid_1's macroF1: 0.211232
# ******************** Execution ended in 00h 00m 16.58s ********************
# ######################################## 47 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.809276	training's macroF1: 0.203087	valid_1's multi_logloss: 1.08197	valid_1's macroF1: 0.195022
# Early stopping, best iteration is:
# [18]	training's multi_logloss: 1.29866	training's macroF1: 0.209031	valid_1's multi_logloss: 1.2937	valid_1's macroF1: 0.223093
# ******************** Execution ended in 00h 00m 09.59s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.817714	training's macroF1: 0.203611	valid_1's multi_logloss: 1.0392	valid_1's macroF1: 0.174791
# Early stopping, best iteration is:
# [4]	training's multi_logloss: 1.36543	training's macroF1: 0.203375	valid_1's multi_logloss: 1.36017	valid_1's macroF1: 0.189956
# ******************** Execution ended in 00h 00m 09.33s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.823424	training's macroF1: 0.195666	valid_1's multi_logloss: 1.03152	valid_1's macroF1: 0.21404
# [1000]	training's multi_logloss: 0.668772	training's macroF1: 0.197371	valid_1's multi_logloss: 1.02539	valid_1's macroF1: 0.216446
# Early stopping, best iteration is:
# [721]	training's multi_logloss: 0.743845	training's macroF1: 0.197544	valid_1's multi_logloss: 1.02788	valid_1's macroF1: 0.226649
# ******************** Execution ended in 00h 00m 24.66s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.827483	training's macroF1: 0.215426	valid_1's multi_logloss: 1.00459	valid_1's macroF1: 0.182856
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 1.35947	training's macroF1: 0.222361	valid_1's multi_logloss: 1.35355	valid_1's macroF1: 0.204525
# ******************** Execution ended in 00h 00m 09.68s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.821867	training's macroF1: 0.204857	valid_1's multi_logloss: 0.975536	valid_1's macroF1: 0.204083
# Early stopping, best iteration is:
# [89]	training's multi_logloss: 1.12527	training's macroF1: 0.213291	valid_1's multi_logloss: 1.09725	valid_1's macroF1: 0.220598
# ******************** Execution ended in 00h 00m 11.77s ********************
# ######################################## 48 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.24704	training's macroF1: 0.20423	valid_1's multi_logloss: 1.1725	valid_1's macroF1: 0.193624
# [1000]	training's multi_logloss: 1.19936	training's macroF1: 0.204522	valid_1's multi_logloss: 1.12193	valid_1's macroF1: 0.194241
# Early stopping, best iteration is:
# [943]	training's multi_logloss: 1.20316	training's macroF1: 0.206328	valid_1's multi_logloss: 1.1249	valid_1's macroF1: 0.199379
# ******************** Execution ended in 00h 00m 14.84s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.23468	training's macroF1: 0.223101	valid_1's multi_logloss: 1.19282	valid_1's macroF1: 0.220344
# Early stopping, best iteration is:
# [33]	training's multi_logloss: 1.36707	training's macroF1: 0.21139	valid_1's multi_logloss: 1.35944	valid_1's macroF1: 0.229181
# ******************** Execution ended in 00h 00m 06.15s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.24473	training's macroF1: 0.206623	valid_1's multi_logloss: 1.17489	valid_1's macroF1: 0.207957
# Early stopping, best iteration is:
# [22]	training's multi_logloss: 1.37515	training's macroF1: 0.200105	valid_1's multi_logloss: 1.36771	valid_1's macroF1: 0.236631
# ******************** Execution ended in 00h 00m 06.33s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.23225	training's macroF1: 0.215183	valid_1's multi_logloss: 1.18876	valid_1's macroF1: 0.235774
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 1.38206	training's macroF1: 0.223463	valid_1's multi_logloss: 1.37994	valid_1's macroF1: 0.248391
# ******************** Execution ended in 00h 00m 05.83s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.23874	training's macroF1: 0.22114	valid_1's multi_logloss: 1.16765	valid_1's macroF1: 0.222702
# Early stopping, best iteration is:
# [228]	training's multi_logloss: 1.29293	training's macroF1: 0.220225	valid_1's multi_logloss: 1.24496	valid_1's macroF1: 0.235052
# ******************** Execution ended in 00h 00m 07.40s ********************
# ######################################## 49 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.33177	training's macroF1: 0.196214	valid_1's multi_logloss: 1.31092	valid_1's macroF1: 0.218737
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.38617	training's macroF1: 0.206915	valid_1's multi_logloss: 1.38614	valid_1's macroF1: 0.233845
# ******************** Execution ended in 00h 00m 08.09s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.33244	training's macroF1: 0.204694	valid_1's multi_logloss: 1.30928	valid_1's macroF1: 0.203101
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 1.38542	training's macroF1: 0.20065	valid_1's multi_logloss: 1.38507	valid_1's macroF1: 0.210781
# ******************** Execution ended in 00h 00m 08.83s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.33201	training's macroF1: 0.197243	valid_1's multi_logloss: 1.31255	valid_1's macroF1: 0.199457
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 1.38563	training's macroF1: 0.192509	valid_1's multi_logloss: 1.38535	valid_1's macroF1: 0.203543
# ******************** Execution ended in 00h 00m 08.59s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.33361	training's macroF1: 0.20515	valid_1's multi_logloss: 1.29816	valid_1's macroF1: 0.218933
# Early stopping, best iteration is:
# [101]	training's multi_logloss: 1.37382	training's macroF1: 0.205227	valid_1's multi_logloss: 1.36502	valid_1's macroF1: 0.223069
# ******************** Execution ended in 00h 00m 10.15s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.33032	training's macroF1: 0.200833	valid_1's multi_logloss: 1.31445	valid_1's macroF1: 0.199607
# Early stopping, best iteration is:
# [37]	training's multi_logloss: 1.38125	training's macroF1: 0.204	valid_1's multi_logloss: 1.38004	valid_1's macroF1: 0.202547
# ******************** Execution ended in 00h 00m 10.05s ********************
# ######################################## 50 of 50 iterations ########################################
# ============================== 1 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.17766	training's macroF1: 0.209985	valid_1's multi_logloss: 1.12693	valid_1's macroF1: 0.241341
# Early stopping, best iteration is:
# [43]	training's multi_logloss: 1.35099	training's macroF1: 0.204656	valid_1's multi_logloss: 1.3365	valid_1's macroF1: 0.257194
# ******************** Execution ended in 00h 00m 09.05s ********************
# ============================== 2 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.19529	training's macroF1: 0.213101	valid_1's multi_logloss: 1.11917	valid_1's macroF1: 0.228585
# Early stopping, best iteration is:
# [15]	training's multi_logloss: 1.37477	training's macroF1: 0.206681	valid_1's multi_logloss: 1.36766	valid_1's macroF1: 0.239625
# ******************** Execution ended in 00h 00m 08.18s ********************
# ============================== 3 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.18448	training's macroF1: 0.219351	valid_1's multi_logloss: 1.11696	valid_1's macroF1: 0.192316
# Early stopping, best iteration is:
# [63]	training's multi_logloss: 1.33883	training's macroF1: 0.211174	valid_1's multi_logloss: 1.31402	valid_1's macroF1: 0.214458
# ******************** Execution ended in 00h 00m 09.39s ********************
# ============================== 4 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.18785	training's macroF1: 0.200393	valid_1's multi_logloss: 1.12666	valid_1's macroF1: 0.192945
# Early stopping, best iteration is:
# [174]	training's multi_logloss: 1.28003	training's macroF1: 0.201451	valid_1's multi_logloss: 1.2326	valid_1's macroF1: 0.205772
# ******************** Execution ended in 00h 00m 10.80s ********************
# ============================== 5 of 5 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.17924	training's macroF1: 0.215515	valid_1's multi_logloss: 1.16766	valid_1's macroF1: 0.200957
# Early stopping, best iteration is:
# [85]	training's multi_logloss: 1.32213	training's macroF1: 0.208673	valid_1's multi_logloss: 1.30957	valid_1's macroF1: 0.221801
# ******************** Execution ended in 00h 00m 09.26s ********************

# %%
shap_sorted_df = total_shap_df.groupby('feature').mean().sort_values('shap_values', ascending=False).reset_index()
feat_imp_sorted_df = total_shap_df.groupby('feature').mean().sort_values('feat_imp', ascending=False).reset_index()
features_top_shap = shap_sorted_df['feature'][:500]
features_top_feat_imp = feat_imp_sorted_df['feature'][:500]
top_features = pd.Series(features_top_shap.tolist() + features_top_feat_imp.tolist())
top_features = top_features.unique()

# %% [markdown]
# # 4. Model development

# %%
new_train = train[top_features].copy()
new_test = test[top_features].copy()

# %%
print('new_train shape:', new_train.shape, 'new_test shape:', new_test.shape)
# Out:
# new_train shape: (2973, 511) new_test shape: (23856, 511)

# %%
new_categorical_feats = [col for col in top_features if col in categorical_feats]

# %%
def LGB_OOF(params, categorical_feats, N_FOLDs, SEED=1989):
    clf = lgb.LGBMClassifier(objective='multiclass',
                             random_state=1989,
                             max_depth=params['max_depth'],
                             learning_rate=params['learning_rate'],
                            #  silent=True,
                             verbose=-1,
                             metric='multi_logloss',
                             n_jobs=-1,
                             n_estimators=10000,
                             class_weight='balanced',
                             colsample_bytree=params['colsample_bytree'],
                             min_split_gain=params['min_split_gain'],
                             bagging_freq=params['bagging_freq'],
                             min_child_weight=params['min_child_weight'],
                             num_leaves=params['num_leaves'],
                             subsample=params['subsample'],
                             reg_alpha=params['reg_alpha'],
                             reg_lambda=params['reg_lambda'],
                             num_class=len(np.unique(y)),
                             bagging_seed=SEED,
                             seed=SEED,
                             )
    
    kfold = 10
    kf = StratifiedKFold(n_splits=kfold, shuffle=True)
    feat_importance_df = pd.DataFrame()
    predicts_result = []

    for i, (train_index, test_index) in enumerate(kf.split(new_train, y)):
        print('='*30, '{} of {} folds'.format(i+1, kfold), '='*30)
        start = time.time()
        X_train, X_val = new_train.iloc[train_index], new_train.iloc[test_index]
        y_train, y_val = y.iloc[train_index], y.iloc[test_index]
        clf.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)], eval_metric=evaluate_macroF1_lgb, categorical_feature=new_categorical_feats, callbacks=[lgb.early_stopping(stopping_rounds=500), lgb.log_evaluation(period=500)])
        shap_values = shap.TreeExplainer(clf.booster_).shap_values(X_train)
        fold_importance_df = pd.DataFrame()
        fold_importance_df['feature'] = X_train.columns
        # fold_importance_df['shap_values'] = abs(np.array(shap_values)[:, :].mean(1).mean(0))
        shap_arr = np.abs(np.array(shap_values))
        if shap_arr.shape[0] == len(X_train):  
            fold_importance_df['shap_values'] = shap_arr.mean(axis=0).mean(axis=-1)
        else:
            fold_importance_df['shap_values'] = shap_arr.mean(axis=1).mean(axis=0)

        fold_importance_df['feat_imp'] = clf.feature_importances_
        feat_importance_df = pd.concat([feat_importance_df, fold_importance_df])
        predicts_result.append(clf.predict(new_test))
        print_execution_time(start)
    return predicts_result, feat_importance_df

# %%
params = {'max_depth': 6,
          'learning_rate': 0.002,
          'colsample_bytree': 0.8,
          'subsample': 0.8,
          'min_split_gain': 0.02,
          'num_leaves': 48,
          'reg_alpha': 0.04,
          'reg_lambda': 0.073,
          'bagging_freq': 2,
          'min_child_weight': 40
          }

N_Folds = 20
SEED = 1989
predicts_result, feat_importance_df = LGB_OOF(params, new_categorical_feats, N_Folds, SEED=1989)
# Out:
# ============================== 1 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13486	training's macroF1: 0.202919	valid_1's multi_logloss: 1.13334	valid_1's macroF1: 0.199615
# Early stopping, best iteration is:
# [2]	training's multi_logloss: 1.38464	training's macroF1: 0.197867	valid_1's multi_logloss: 1.38448	valid_1's macroF1: 0.234066
# ******************** Execution ended in 00h 00m 05.39s ********************
# ============================== 2 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13703	training's macroF1: 0.202155	valid_1's multi_logloss: 1.13086	valid_1's macroF1: 0.218303
# Early stopping, best iteration is:
# [243]	training's multi_logloss: 1.23399	training's macroF1: 0.199138	valid_1's multi_logloss: 1.21736	valid_1's macroF1: 0.227462
# ******************** Execution ended in 00h 00m 09.23s ********************
# ============================== 3 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13672	training's macroF1: 0.196991	valid_1's multi_logloss: 1.14483	valid_1's macroF1: 0.183321
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.38375	training's macroF1: 0.204338	valid_1's multi_logloss: 1.38339	valid_1's macroF1: 0.192581
# ******************** Execution ended in 00h 00m 05.31s ********************
# ============================== 4 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13731	training's macroF1: 0.221424	valid_1's multi_logloss: 1.12158	valid_1's macroF1: 0.233796
# Early stopping, best iteration is:
# [163]	training's multi_logloss: 1.2757	training's macroF1: 0.219876	valid_1's multi_logloss: 1.25634	valid_1's macroF1: 0.248756
# ******************** Execution ended in 00h 00m 07.13s ********************
# ============================== 5 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.14069	training's macroF1: 0.211475	valid_1's multi_logloss: 1.09108	valid_1's macroF1: 0.210034
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.38551	training's macroF1: 0.210401	valid_1's multi_logloss: 1.38515	valid_1's macroF1: 0.230281
# ******************** Execution ended in 00h 00m 04.90s ********************
# ============================== 6 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13989	training's macroF1: 0.21154	valid_1's multi_logloss: 1.09848	valid_1's macroF1: 0.172472
# Early stopping, best iteration is:
# [8]	training's multi_logloss: 1.37961	training's macroF1: 0.209516	valid_1's multi_logloss: 1.37686	valid_1's macroF1: 0.204851
# ******************** Execution ended in 00h 00m 05.59s ********************
# ============================== 7 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13734	training's macroF1: 0.224197	valid_1's multi_logloss: 1.15739	valid_1's macroF1: 0.184694
# Early stopping, best iteration is:
# [5]	training's multi_logloss: 1.38212	training's macroF1: 0.220829	valid_1's multi_logloss: 1.38156	valid_1's macroF1: 0.212387
# ******************** Execution ended in 00h 00m 05.47s ********************
# ============================== 8 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13998	training's macroF1: 0.20993	valid_1's multi_logloss: 1.1273	valid_1's macroF1: 0.153521
# Early stopping, best iteration is:
# [49]	training's multi_logloss: 1.34881	training's macroF1: 0.222533	valid_1's multi_logloss: 1.3394	valid_1's macroF1: 0.175468
# ******************** Execution ended in 00h 00m 05.80s ********************
# ============================== 9 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13686	training's macroF1: 0.221193	valid_1's multi_logloss: 1.13691	valid_1's macroF1: 0.224849
# Early stopping, best iteration is:
# [30]	training's multi_logloss: 1.3614	training's macroF1: 0.212815	valid_1's multi_logloss: 1.35736	valid_1's macroF1: 0.243964
# ******************** Execution ended in 00h 00m 05.37s ********************
# ============================== 10 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 1.13299	training's macroF1: 0.206189	valid_1's multi_logloss: 1.14609	valid_1's macroF1: 0.184709
# Early stopping, best iteration is:
# [13]	training's multi_logloss: 1.37514	training's macroF1: 0.206388	valid_1's multi_logloss: 1.37373	valid_1's macroF1: 0.197411
# ******************** Execution ended in 00h 00m 04.95s ********************

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 20))
feat_importance_df_shap = feat_importance_df.groupby('feature').mean().sort_values('shap_values', ascending=False).reset_index()

num_features = 50
sns.barplot(x=feat_importance_df_shap.shap_values[:num_features], y=feat_importance_df_shap.feature[:num_features], ax=ax[0])
ax[0].set_title('Feature importance based on shap values')

feat_importance_df = feat_importance_df.groupby('feature').mean().sort_values('feat_imp', ascending=False).reset_index()

num_features = 50
sns.barplot(x=feat_importance_df.shap_values[:num_features], y=feat_importance_df.feature[:num_features], ax=ax[1])
ax[1].set_title('Feature importance based on feature importance from lgbm')
plt.show()

# %%
submission['Target'] = np.array(predicts_result).mean(axis=0).round().astype(int)
submission.to_csv('submssion_with_new_feature_set.csv', index=False)

# %% [markdown]
# ## Randomized search

# %%
optimized_param = None
lowest_cv = 1000
total_iteration = 100
for i in range(total_iteration):
    print('-' * 20, 'For {} of {} iterations'.format(i+1, total_iteration), '-'*20)
    learning_rate = np.random.rand() * 0.02
    n_folds = 3

    num_class = len(np.unique(y))

    params = {}
    params['application'] = 'multiclass'
    params['metric'] = 'multi_logloss'
    params['num_class'] = num_class
    params['class_weight'] = 'balanced'
    params['num_leaves'] = np.random.randint(24, 48)
    params['max_depth'] = np.random.randint(5, 8)
    params['min_child_weight'] = np.random.randint(5, 50)
    params['min_split_gain'] = np.random.rand() * 0.09
    params['colsample_bytree'] = np.random.rand() * (0.9 - 0.1) + 0.1
    params['subsample'] = np.random.rand() * (1 - 0.8) + 0.8
    params['bagging_freq'] = np.random.randint(1, 5)
    params['bagging_seed'] = np.random.randint(1, 5)
    params['reg_alpha'] = np.random.rand() * 2
    params['reg_lambda'] = np.random.rand() * 2
    params['learning_rate'] = np.random.rand() * 0.02
    params['seed'] = 1989

    d_train = lgb.Dataset(data=new_train, label=y.values-1, categorical_feature=new_categorical_feats, free_raw_data=False)
    cv_results = lgb.cv(params=params, train_set=d_train, num_boost_round=10000, nfold=n_folds, stratified=True, shuffle=True, callbacks=[lgb.early_stopping(stopping_rounds=1), lgb.log_evaluation(1000)])

    min_cv_results = min(cv_results['valid multi_logloss-mean'])

    if min_cv_results < lowest_cv:
        lowest_cv = min_cv_results
        optimized_param = params
# Out:
# -------------------- For 1 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [243]	valid's multi_logloss: 0.833239 + 0.0137738
# -------------------- For 2 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.866412 + 0.00929626
# [2000]	valid's multi_logloss: 0.837712 + 0.0129595
# Early stopping, best iteration is:
# [2321]	valid's multi_logloss: 0.834434 + 0.0138662
# -------------------- For 3 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [208]	valid's multi_logloss: 0.827492 + 0.0154879
# -------------------- For 4 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.838671 + 0.0135747
# Early stopping, best iteration is:
# [1300]	valid's multi_logloss: 0.832523 + 0.0151152
# -------------------- For 5 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [185]	valid's multi_logloss: 0.829224 + 0.0149745
# -------------------- For 6 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [169]	valid's multi_logloss: 0.829281 + 0.0160783
# -------------------- For 7 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [241]	valid's multi_logloss: 0.829513 + 0.0172493
# -------------------- For 8 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [737]	valid's multi_logloss: 0.834015 + 0.0138708
# -------------------- For 9 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [281]	valid's multi_logloss: 0.830743 + 0.0143387
# -------------------- For 10 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [560]	valid's multi_logloss: 0.83197 + 0.0153572
# -------------------- For 11 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [113]	valid's multi_logloss: 0.831815 + 0.0137982
# -------------------- For 12 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.972209 + 0.00169853
# [2000]	valid's multi_logloss: 0.945654 + 0.00334164
# [3000]	valid's multi_logloss: 0.924896 + 0.00491473
# [4000]	valid's multi_logloss: 0.908362 + 0.00626809
# [5000]	valid's multi_logloss: 0.895027 + 0.00739939
# [6000]	valid's multi_logloss: 0.884048 + 0.00836472
# [7000]	valid's multi_logloss: 0.874911 + 0.0090856
# [8000]	valid's multi_logloss: 0.867304 + 0.00972799
# [9000]	valid's multi_logloss: 0.860906 + 0.0103552
# [10000]	valid's multi_logloss: 0.855565 + 0.0108748
# Did not meet early stopping. Best iteration is:
# [10000]	valid's multi_logloss: 0.855565 + 0.0108748
# -------------------- For 13 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.931817 + 0.00359018
# [2000]	valid's multi_logloss: 0.890189 + 0.00698882
# [3000]	valid's multi_logloss: 0.865529 + 0.00882123
# [4000]	valid's multi_logloss: 0.850035 + 0.0102117
# [5000]	valid's multi_logloss: 0.840185 + 0.0115767
# [6000]	valid's multi_logloss: 0.833982 + 0.0129858
# [7000]	valid's multi_logloss: 0.829971 + 0.0143469
# Early stopping, best iteration is:
# [7100]	valid's multi_logloss: 0.829659 + 0.0144815
# -------------------- For 14 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [732]	valid's multi_logloss: 0.830413 + 0.0156259
# -------------------- For 15 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [896]	valid's multi_logloss: 0.833387 + 0.014972
# -------------------- For 16 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [270]	valid's multi_logloss: 0.825464 + 0.0164656
# -------------------- For 17 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [210]	valid's multi_logloss: 0.826898 + 0.0166528
# -------------------- For 18 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [224]	valid's multi_logloss: 0.832677 + 0.0133813
# -------------------- For 19 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [179]	valid's multi_logloss: 0.827557 + 0.0156477
# -------------------- For 20 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [124]	valid's multi_logloss: 0.828328 + 0.0166345
# -------------------- For 21 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [193]	valid's multi_logloss: 0.831713 + 0.016265
# -------------------- For 22 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [160]	valid's multi_logloss: 0.829416 + 0.0153344
# -------------------- For 23 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [501]	valid's multi_logloss: 0.829878 + 0.0157715
# -------------------- For 24 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.851543 + 0.0102636
# Early stopping, best iteration is:
# [1838]	valid's multi_logloss: 0.829105 + 0.0148033
# -------------------- For 25 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [144]	valid's multi_logloss: 0.82955 + 0.0152281
# -------------------- For 26 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [637]	valid's multi_logloss: 0.826672 + 0.0148877
# -------------------- For 27 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [270]	valid's multi_logloss: 0.831717 + 0.0163318
# -------------------- For 28 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [664]	valid's multi_logloss: 0.827307 + 0.0146389
# -------------------- For 29 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [132]	valid's multi_logloss: 0.828302 + 0.014291
# -------------------- For 30 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.833836 + 0.0127774
# Early stopping, best iteration is:
# [1242]	valid's multi_logloss: 0.828643 + 0.0145054
# -------------------- For 31 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [186]	valid's multi_logloss: 0.833291 + 0.0145795
# -------------------- For 32 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [493]	valid's multi_logloss: 0.833206 + 0.0141165
# -------------------- For 33 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [370]	valid's multi_logloss: 0.827956 + 0.014161
# -------------------- For 34 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [230]	valid's multi_logloss: 0.828749 + 0.0149606
# -------------------- For 35 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [314]	valid's multi_logloss: 0.829308 + 0.0137838
# -------------------- For 36 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [290]	valid's multi_logloss: 0.835078 + 0.0140023
# -------------------- For 37 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [311]	valid's multi_logloss: 0.825939 + 0.016465
# -------------------- For 38 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [456]	valid's multi_logloss: 0.830569 + 0.0150841
# -------------------- For 39 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [202]	valid's multi_logloss: 0.833103 + 0.0149347
# -------------------- For 40 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [203]	valid's multi_logloss: 0.833561 + 0.0142415
# -------------------- For 41 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [206]	valid's multi_logloss: 0.831414 + 0.0136408
# -------------------- For 42 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [197]	valid's multi_logloss: 0.827458 + 0.0148697
# -------------------- For 43 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.876793 + 0.00752224
# [2000]	valid's multi_logloss: 0.840127 + 0.012959
# Early stopping, best iteration is:
# [2691]	valid's multi_logloss: 0.831272 + 0.0153769
# -------------------- For 44 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [157]	valid's multi_logloss: 0.829591 + 0.0158937
# -------------------- For 45 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.84021 + 0.01295
# Early stopping, best iteration is:
# [1228]	valid's multi_logloss: 0.834803 + 0.0143067
# -------------------- For 46 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [282]	valid's multi_logloss: 0.828942 + 0.0158187
# -------------------- For 47 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [205]	valid's multi_logloss: 0.828764 + 0.014933
# -------------------- For 48 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [829]	valid's multi_logloss: 0.829283 + 0.0143913
# -------------------- For 49 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.853582 + 0.0111921
# Early stopping, best iteration is:
# [1774]	valid's multi_logloss: 0.833525 + 0.0147155
# -------------------- For 50 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [750]	valid's multi_logloss: 0.831132 + 0.0148098
# -------------------- For 51 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [181]	valid's multi_logloss: 0.828702 + 0.0148609
# -------------------- For 52 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [444]	valid's multi_logloss: 0.834999 + 0.0149407
# -------------------- For 53 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [246]	valid's multi_logloss: 0.833035 + 0.0126586
# -------------------- For 54 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [157]	valid's multi_logloss: 0.831895 + 0.0136312
# -------------------- For 55 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [157]	valid's multi_logloss: 0.835607 + 0.0136866
# -------------------- For 56 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.838781 + 0.0123937
# Early stopping, best iteration is:
# [1371]	valid's multi_logloss: 0.830853 + 0.0146172
# -------------------- For 57 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [802]	valid's multi_logloss: 0.82808 + 0.0159959
# -------------------- For 58 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [135]	valid's multi_logloss: 0.82986 + 0.015381
# -------------------- For 59 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [123]	valid's multi_logloss: 0.830839 + 0.0149608
# -------------------- For 60 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [563]	valid's multi_logloss: 0.831197 + 0.0142384
# -------------------- For 61 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [324]	valid's multi_logloss: 0.833784 + 0.0146674
# -------------------- For 62 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.931453 + 0.00343639
# [2000]	valid's multi_logloss: 0.890442 + 0.00694576
# [3000]	valid's multi_logloss: 0.865964 + 0.00925482
# [4000]	valid's multi_logloss: 0.850959 + 0.010979
# [5000]	valid's multi_logloss: 0.841599 + 0.0123849
# [6000]	valid's multi_logloss: 0.835744 + 0.0135176
# Early stopping, best iteration is:
# [6720]	valid's multi_logloss: 0.832851 + 0.0143232
# -------------------- For 63 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [181]	valid's multi_logloss: 0.8295 + 0.0142044
# -------------------- For 64 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.874417 + 0.00844256
# [2000]	valid's multi_logloss: 0.839396 + 0.0126717
# Early stopping, best iteration is:
# [2879]	valid's multi_logloss: 0.83037 + 0.0152611
# -------------------- For 65 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [193]	valid's multi_logloss: 0.829641 + 0.0161142
# -------------------- For 66 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [142]	valid's multi_logloss: 0.830106 + 0.0164511
# -------------------- For 67 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [508]	valid's multi_logloss: 0.829732 + 0.0146576
# -------------------- For 68 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [279]	valid's multi_logloss: 0.826604 + 0.0160758
# -------------------- For 69 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [357]	valid's multi_logloss: 0.832145 + 0.0141402
# -------------------- For 70 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [183]	valid's multi_logloss: 0.828165 + 0.0150928
# -------------------- For 71 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [149]	valid's multi_logloss: 0.83029 + 0.016668
# -------------------- For 72 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [648]	valid's multi_logloss: 0.83191 + 0.0152267
# -------------------- For 73 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [462]	valid's multi_logloss: 0.825201 + 0.0153781
# -------------------- For 74 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.964636 + 0.0014344
# [2000]	valid's multi_logloss: 0.933195 + 0.00292298
# [3000]	valid's multi_logloss: 0.909208 + 0.00445069
# [4000]	valid's multi_logloss: 0.890717 + 0.00595511
# [5000]	valid's multi_logloss: 0.876374 + 0.00729666
# [6000]	valid's multi_logloss: 0.865078 + 0.00852849
# [7000]	valid's multi_logloss: 0.856171 + 0.00963446
# [8000]	valid's multi_logloss: 0.849074 + 0.0105689
# [9000]	valid's multi_logloss: 0.843413 + 0.0114508
# [10000]	valid's multi_logloss: 0.838893 + 0.0122195
# Did not meet early stopping. Best iteration is:
# [10000]	valid's multi_logloss: 0.838893 + 0.0122195
# -------------------- For 75 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [463]	valid's multi_logloss: 0.827677 + 0.0143281
# -------------------- For 76 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [137]	valid's multi_logloss: 0.831396 + 0.0170392
# -------------------- For 77 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [142]	valid's multi_logloss: 0.830857 + 0.0162647
# -------------------- For 78 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [333]	valid's multi_logloss: 0.830909 + 0.0143902
# -------------------- For 79 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [182]	valid's multi_logloss: 0.82963 + 0.0155376
# -------------------- For 80 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [227]	valid's multi_logloss: 0.827738 + 0.0145442
# -------------------- For 81 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [277]	valid's multi_logloss: 0.828768 + 0.0171432
# -------------------- For 82 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [330]	valid's multi_logloss: 0.831583 + 0.0163015
# -------------------- For 83 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [153]	valid's multi_logloss: 0.828904 + 0.0154063
# -------------------- For 84 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [202]	valid's multi_logloss: 0.827196 + 0.0151391
# -------------------- For 85 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [120]	valid's multi_logloss: 0.827458 + 0.015718
# -------------------- For 86 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [158]	valid's multi_logloss: 0.824979 + 0.0168759
# -------------------- For 87 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [184]	valid's multi_logloss: 0.831562 + 0.0162126
# -------------------- For 88 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.831368 + 0.014803
# Early stopping, best iteration is:
# [1040]	valid's multi_logloss: 0.830747 + 0.0149988
# -------------------- For 89 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [364]	valid's multi_logloss: 0.828593 + 0.0148897
# -------------------- For 90 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [326]	valid's multi_logloss: 0.829034 + 0.0157239
# -------------------- For 91 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [137]	valid's multi_logloss: 0.829889 + 0.0156621
# -------------------- For 92 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [227]	valid's multi_logloss: 0.827974 + 0.0144556
# -------------------- For 93 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [153]	valid's multi_logloss: 0.830708 + 0.01643
# -------------------- For 94 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [220]	valid's multi_logloss: 0.828865 + 0.0148667
# -------------------- For 95 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [731]	valid's multi_logloss: 0.829615 + 0.0150243
# -------------------- For 96 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [163]	valid's multi_logloss: 0.830998 + 0.0162255
# -------------------- For 97 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [459]	valid's multi_logloss: 0.830131 + 0.0153127
# -------------------- For 98 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [557]	valid's multi_logloss: 0.827378 + 0.0167411
# -------------------- For 99 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# [1000]	valid's multi_logloss: 0.829853 + 0.0143895
# Early stopping, best iteration is:
# [1029]	valid's multi_logloss: 0.829303 + 0.0145216
# -------------------- For 100 of 100 iterations --------------------
# Training until validation scores don't improve for 1 rounds
# Early stopping, best iteration is:
# [197]	valid's multi_logloss: 0.82633 + 0.0146261

# %%
N_Folds = 20
SEED = 1989
predicts_result, feat_importance_df = LGB_OOF(optimized_param, new_categorical_feats, N_Folds, SEED=1989)
# Out:
# ============================== 1 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.535995	training's macroF1: 0.202429	valid_1's multi_logloss: 1.021	valid_1's macroF1: 0.2513
# Early stopping, best iteration is:
# [199]	training's multi_logloss: 0.78767	training's macroF1: 0.201371	valid_1's multi_logloss: 1.03615	valid_1's macroF1: 0.264345
# ******************** Execution ended in 00h 00m 07.62s ********************
# ============================== 2 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.54052	training's macroF1: 0.215937	valid_1's multi_logloss: 1.00786	valid_1's macroF1: 0.217703
# Early stopping, best iteration is:
# [117]	training's multi_logloss: 0.919267	training's macroF1: 0.211964	valid_1's multi_logloss: 1.06083	valid_1's macroF1: 0.230973
# ******************** Execution ended in 00h 00m 07.09s ********************
# ============================== 3 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.53946	training's macroF1: 0.200175	valid_1's multi_logloss: 0.968053	valid_1's macroF1: 0.215083
# Early stopping, best iteration is:
# [238]	training's multi_logloss: 0.744057	training's macroF1: 0.194491	valid_1's multi_logloss: 0.988928	valid_1's macroF1: 0.241476
# ******************** Execution ended in 00h 00m 09.25s ********************
# ============================== 4 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.541433	training's macroF1: 0.21735	valid_1's multi_logloss: 0.97779	valid_1's macroF1: 0.205094
# [1000]	training's multi_logloss: 0.362382	training's macroF1: 0.214483	valid_1's multi_logloss: 0.973	valid_1's macroF1: 0.232511
# Early stopping, best iteration is:
# [768]	training's multi_logloss: 0.425337	training's macroF1: 0.217085	valid_1's multi_logloss: 0.966236	valid_1's macroF1: 0.223122
# ******************** Execution ended in 00h 00m 20.48s ********************
# ============================== 5 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.54363	training's macroF1: 0.217443	valid_1's multi_logloss: 0.949619	valid_1's macroF1: 0.178524
# Early stopping, best iteration is:
# [3]	training's multi_logloss: 1.35937	training's macroF1: 0.218305	valid_1's multi_logloss: 1.35605	valid_1's macroF1: 0.219626
# ******************** Execution ended in 00h 00m 07.52s ********************
# ============================== 6 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.537555	training's macroF1: 0.209134	valid_1's multi_logloss: 0.981109	valid_1's macroF1: 0.246718
# Early stopping, best iteration is:
# [1]	training's multi_logloss: 1.3773	training's macroF1: 0.216066	valid_1's multi_logloss: 1.3755	valid_1's macroF1: 0.258386
# ******************** Execution ended in 00h 00m 05.67s ********************
# ============================== 7 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.538282	training's macroF1: 0.232398	valid_1's multi_logloss: 0.985103	valid_1's macroF1: 0.192026
# Early stopping, best iteration is:
# [11]	training's multi_logloss: 1.29769	training's macroF1: 0.223952	valid_1's multi_logloss: 1.29259	valid_1's macroF1: 0.230864
# ******************** Execution ended in 00h 00m 06.87s ********************
# ============================== 8 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.535524	training's macroF1: 0.215147	valid_1's multi_logloss: 1.00495	valid_1's macroF1: 0.198276
# Early stopping, best iteration is:
# [7]	training's multi_logloss: 1.32465	training's macroF1: 0.21018	valid_1's multi_logloss: 1.31939	valid_1's macroF1: 0.218173
# ******************** Execution ended in 00h 00m 04.67s ********************
# ============================== 9 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.534701	training's macroF1: 0.21348	valid_1's multi_logloss: 0.973036	valid_1's macroF1: 0.182581
# Early stopping, best iteration is:
# [22]	training's multi_logloss: 1.22841	training's macroF1: 0.207621	valid_1's multi_logloss: 1.22536	valid_1's macroF1: 0.219238
# ******************** Execution ended in 00h 00m 05.30s ********************
# ============================== 10 of 10 folds ==============================
# Training until validation scores don't improve for 500 rounds
# [500]	training's multi_logloss: 0.534685	training's macroF1: 0.222659	valid_1's multi_logloss: 0.966278	valid_1's macroF1: 0.168594
# Early stopping, best iteration is:
# [202]	training's multi_logloss: 0.780544	training's macroF1: 0.224423	valid_1's multi_logloss: 1.00171	valid_1's macroF1: 0.185208
# ******************** Execution ended in 00h 00m 11.68s ********************

# %%
submission['Target'] = np.array(predicts_result).mean(axis=0).round().astype(int)
submission.to_csv('submission_shap_randomized_search.csv', index=False)
