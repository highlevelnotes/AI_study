# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_upstage import UpstageDocumentParseLoader

file_path = '(교사용)2022학년도_수능특강_한국사_본문_slice.pdf'
loader = UpstageDocumentParseLoader(file_path, split='page')

pages = loader.load()
for page in pages:
    print(page)
# Out:
# page_content='<h1 id='0' style='font-size:18px'>한국사</h1> <br><h1 id='1' style='font-size:22px'>01</h1> <br><h1 id='2' style='font-size:22px'>선사 문화와 여러 나라의 성장</h1> <h1 id='3' style='font-size:16px'>슴베찌르개</h1> <br><p id='4' data-category='paragraph' style='font-size:20px'>1. 선사 문화의 전개</p> <figure id='5'><img alt="" data-coord="top-left:(173,237); bottom-right:(223,332)" /></figure> <br><p id='6' data-category='paragraph' style='font-size:20px'>(1) 우리 민족의 형성 : 만주와 한반도를 중심으로 동북아시아에 분포, 신석기 시대~청동기 시대에<br>걸쳐 민족의 기틀 형성</p> <br><p id='7' data-category='paragraph' style='font-size:16px'>←슴베</p> <p id='8' data-category='paragraph' style='font-size:16px'>돌날의 양쪽 끝을 뾰족하게 만<br>들어 한쪽 끝을 나무에 박아 만<br>든 석기이다. 슴베찌르개는 자<br>루를 달아 창처럼 만들어 사냥<br>도구 등으로 사용되었다.</p> <br><p id='9' data-category='paragraph' style='font-size:20px'>(2) 구석기 시대</p> <table id='10' style='font-size:16px'><thead></thead><tbody><tr><td>주요 유적</td><td>경기 연천 전곡리, 충남 공주 석장리 등</td></tr><tr><td>도구</td><td>· 뗀석기 사용 : 사냥 도구(주먹도끼, 찍개 등), 조리 도구(긁개, 밀개 등) · 구석기 시대 후기에 슴베찌르개 사용</td></tr><tr><td>주거</td><td>동굴, 바위 그늘, 강가의 막집에서 생활</td></tr><tr><td>사회</td><td>· 무리 지어 이동 생활, 사냥 · 채집으로 식량 마련 · 지배와 피지배 관계가 발생하지 않은 평등한 공동체 사회(경험이 많거나 나이가 많은 사람이 지도자 역할)</td></tr></tbody></table> <p id='11' data-category='paragraph' style='font-size:18px'>자료 플러스 주먹도끼</p> <p id='12' data-category='paragraph' style='font-size:16px'>농경의 시작</p> <br><p id='13' data-category='paragraph' style='font-size:16px'>인류가 채집 경제에서 벗어나<br>직접 식량을 생산하고 정착 생<br>활을 하는 등 역사 발전에서 큰<br>계기가 되었다. 이를 신석기 혁<br>명이라고 부르기도 한다.</p> <br><figure id='14'><img alt="" data-coord="top-left:(340,615); bottom-right:(414,724)" /></figure> <br><p id='15' data-category='paragraph' style='font-size:20px'>1978년 경기 연천 전곡리에서 주먹도끼가 처음 발견되었다. 주먹도끼는 사용할 때<br>손에 쥐고 사용하기 때문에 붙여진 이름이다. 주먹도끼는 짐승을 사냥하는 데는 물론<br>사냥한 짐승의 가죽을 벗기고, 땅을 파서 풀이나 나무뿌리를 캐는 등 여러 가지 용도<br>로 사용되었다.</p> <br><p id='16' data-category='paragraph' style='font-size:14px'>▲ 주먹도끼</p> <p id='17' data-category='paragraph' style='font-size:20px'>(3) 신석기 시대</p> <br><p id='18' data-category='list' style='font-size:20px'>① 주요 유적 : 대체로 강가나 바닷가에 분포(서울 암사동 등)<br>② 도구</p> <br><p id='19' data-category='paragraph' style='font-size:18px'>· 간석기 : 농경용 도구(돌괭이, 돌보습, 돌낫 등)와 조리용 도구(갈돌, 갈판 등) 제작</p> <h1 id='20' style='font-size:20px'>개념 체크</h1> <br><p id='21' data-category='list' style='font-size:18px'>· 토기 : 빗살무늬 토기가 대표적 → 음식물의 저장과 조리에 사용<br>· 가락바퀴, 뼈바늘 : 옷과 그물을 제작하는 등 원시적 수공업에 사용<br>③ 경제 : 농경(잡곡류 경작)과 목축 시작, 여전히 고기잡이와 사냥 · 채집을 통해 식량 확보<br>④ 주거 : 움집에서 생활(정착 생활)<br>⑤ 사회 : 다른 씨족과의 혼인(족외혼)을 통해 부족 사회 형성, 평등 사회<br>⑥ 신앙 : 농경이 시작되고 정착 생활이 이루어지면서 자연의 섭리 인식 → 애니미즘(정령 숭배),<br>토테미즘(동식물 숭배), 샤머니즘(무당과 주술을 믿음) 등 출현<br>⑦ 예술 : 조개껍데기 가면과 치레걸이 등 제작</p> <br><p id='22' data-category='list' style='font-size:16px'>구석기 시대 사람들은 돌을<br>깨뜨려 주먹도끼, 찍개 등<br>의 ( )를 만들어 사용하<br>였다.<br>2 신석기 시대 사람들은 강가나<br>바닷가에 ( )을 짓고 마<br>을을 이루며 정착 생활을 하<br>였다.<br>3 신석기 시대에는 뼈바늘과 실<br>을 뽑는 도구인 ( )를 이<br>용하여 옷이나 그물을 만들<br>었다.</p> <br><p id='23' data-category='paragraph' style='font-size:18px'>자료 플러스 갈돌과 갈판</p> <figure id='24'><img alt="" data-coord="top-left:(340,1224); bottom-right:(491,1350)" /></figure> <p id='25' data-category='paragraph' style='font-size:14px'>정답 1 뗀석기 움집</p> <br><p id='26' data-category='paragraph' style='font-size:16px'>가락바퀴</p> <br><p id='27' data-category='paragraph' style='font-size:14px'>▲</p> <br><table id='28' style='font-size:20px'><thead></thead><tbody><tr><td></td><td>갈돌과 갈판은 신석기 시대부터 사용된 간석기이다. 신석기 시대부터 농경 이 시작되었지만 그 비중이 크지 않아 여전히 사냥과 채집을 중심으로 생활 이 이루어졌다. 신석기인들은 갈돌과 갈판을 이용하여 자연에서 채집한 도 토리나 조, 기장 등 곡물의 껍질을 까거나 알맹이를 갈아서 가루로 만들었</td></tr><tr><td>갈돌과 갈판</td><td>을 것이다. 갈돌과 갈판은 농경이 본격적으로 이루어진 청동기 시대에도 계 속 사용되었다.</td></tr></tbody></table> <footer id='29' style='font-size:16px'>8 EBS 수능특강 한국사_ I 우리 역사의 형성과 고대 국가의 발전</footer>' metadata={'page': 1, 'coordinates': [[{'x': 0.0976, 'y': 0.0395}, {'x': 0.135, 'y': 0.0395}, {'x': 0.135, 'y': 0.0531}, {'x': 0.0976, 'y': 0.0531}], [{'x': 0.1487, 'y': 0.0378}, {'x': 0.2123, 'y': 0.0378}, {'x': 0.2123, 'y': 0.0 ...
# page_content='<h1 id='30' style='font-size:16px'>www.ebsi.co.kr</h1> <p id='31' data-category='paragraph' style='font-size:22px'>2. 고조선의 성립과 여러 나라의 성장</p> <br><h1 id='32' style='font-size:20px'>(1) 청동기 시대</h1> <br><p id='33' data-category='paragraph' style='font-size:14px'>▶ 반달 돌칼</p> <table id='34' style='font-size:16px'><thead></thead><tbody><tr><td>도구</td><td>· 청동기 : 비파형 동검, 거친무늬 거울 등 · 간석기 : 반달 돌칼 등의 농기구 · 토기 : 민무늬 토기, 미송리식 토기 등</td></tr><tr><td>경제</td><td>농경과 목축 확대, 일부 저습지에서 벼농사 실시</td></tr><tr><td>사회</td><td>· 사유 재산과 계급 발생, 정복 전쟁의 활발한 전개 · 군장(족장) 출현(제사와 정치 주관, 스스로를 하늘의 자손으로 여김)</td></tr><tr><td>주거</td><td>움집의 지상 가옥화, 들판을 끼고 있는 구릉이나 강가에 취락 형성</td></tr><tr><td>무덤</td><td>고인돌(지배층의 무덤, 탁자식 · 바둑판식), 돌널무덤 등</td></tr></tbody></table> <p id='35' data-category='paragraph' style='font-size:18px'>자료 플러스 고인돌</p> <figure id='36'><img alt="" data-coord="top-left:(135,458); bottom-right:(351,587)" /></figure> <br><figure id='37'><img alt="" data-coord="top-left:(959,168); bottom-right:(1084,210)" /></figure> <p id='38' data-category='paragraph' style='font-size:16px'>▲ 고인돌(인천 강화)</p> <br><p id='39' data-category='paragraph' style='font-size:20px'>고인돌은 청동기 시대의 대표적인 무덤으로 지상 또는 지하에<br>매장 시설을 만들고 지상에는 큰 돌을 윗돌로 놓아 덮개돌로 사<br>용한다. 대형 고인돌은 덮개돌 무게만 수십 톤에 달해 고인돌에<br>묻힌 사람은 수백 명의 인력을 동원할 수 있는 군장(족장)이나<br>그와 비슷한 지위에 있는 사람 또는 그 가족으로 짐작된다. 우<br>리나라의 고인돌은 고창, 화순, 강화 등지에 다수 분포하고 있</p> <br><p id='40' data-category='paragraph' style='font-size:20px'>으며, 2000년에 유네스코 세계 유산으로 등재되어 보존 · 관리되고 있다.</p> <p id='41' data-category='paragraph' style='font-size:20px'>고조선의 건국과 성장</p> <table id='42' style='font-size:16px'><thead></thead><tbody><tr><td>건국</td><td>청동기 문화를 기반으로 건국</td></tr><tr><td>건국 이야기</td><td>· 『삼국유사』, 『제왕운기』, 「동국통감」 등에 실려 있음 · 농경 사회 형성, 계급 발생, 제정일치의 지배자(단군왕검) 출현 등 반영</td></tr><tr><td>발전</td><td>· 기원전 4세기부터 중국의 연과 대립 · 기원전 3세기경 부왕· 준왕 등이 왕위 세습, 상 ·대부·장군 등의 관직 설치</td></tr><tr><td>위만 집권 이후의 변화</td><td>· 중국의 진· 한 교체기에 유이민 무리가 고조선으로 이주 → 위만이 준왕을 몰아내고 왕위 차지(기원전 194) · 철기 문화를 본격적으로 수용 · 한반도 남부의 진과 중국의 한 사이에서 중계 무역 전개</td></tr><tr><td>멸망</td><td>한 무제의 침략으로 멸망(기원전 108) → 한이 일부 지역에 군현 설치</td></tr><tr><td>사회</td><td>8조법 중 3개 조항이 전해짐(생명 · 노동력 중시, 사유 재산 보호, 형벌 · 노비 존재) → 한 군현 설치 후 법률이 60여 조로 증가</td></tr></tbody></table> <br><p id='43' data-category='paragraph' style='font-size:16px'>청동기 시대에 널리 사용된 농<br>기구로, 곡식을 수확할 때 사용<br>하였다. 구멍을 뚫어 끈을 꿰고<br>그 끈을 손에 걸어 사용한 것으<br>로 짐작된다.</p> <p id='44' data-category='paragraph' style='font-size:16px'>� 미송리식 토기</p> <figure id='45'><img alt="" data-coord="top-left:(972,458); bottom-right:(1070,580)" /></figure> <br><p id='46' data-category='paragraph' style='font-size:16px'>평안북도 의주군 미송리의 동굴<br>유적에서 발견되어 붙여진 이름<br>으로 청천강 이북의 평안북도와<br>자강도 및 중국 지린성 일대에<br>서 주로 출토되고 있다. 목이 있<br>고 몸체에 줄무늬가 가로로 둘<br>려 있으며, 몸체의 양쪽에 손잡<br>이가 달린 것이 특징이다.</p> <p id='47' data-category='paragraph' style='font-size:14px'>D 연(燕)</p> <p id='48' data-category='paragraph' style='font-size:18px'>자료 플러스 8조법</p> <br><p id='49' data-category='paragraph' style='font-size:16px'>중국 주나라의 제후국으로 전<br>국 시대에 패권을 다투던 7개<br>나라 중의 하나이다.</p> <p id='50' data-category='paragraph' style='font-size:18px'>사람을 죽인 자는 즉시 죽이고, 남에게 상처를 입힌 자는 곡식으로 갚는다. 도둑질한 자는 노비로 삼는다. 용<br>서받고자 하는 자는 한 사람마다 50만 전을 내게 한다. - 『한서』 -</p> <br><p id='51' data-category='paragraph' style='font-size:22px'>개념 체크</p> <p id='52' data-category='paragraph' style='font-size:20px'>고조선의 8조법 중 현재 전하는 3개 조항이다. 이를 통해 고조선 사회가 계급 사회였으며, 형벌<br>과 노비가 존재하고 노동력과 사유 재산을 보호하였음을 알 수 있다.</p> <p id='53' data-category='paragraph' style='font-size:20px'>(3) 철기 문화의 수용</p> <br><p id='54' data-category='paragraph' style='font-size:16px'>청동기 시대의 대표적 무덤인</p> <p id='55' data-category='list' style='font-size:20px'>① 도구 : 철제 농기구 · 무기 사용 → 농업 생산력 증대, 활발한 정복 활동 전개<br>② 무덤 : 널무덤과 독무덤<br>③ 중국과 교류 : 명도전, 반량전 등 중국 화폐 출토, 붓 발견(한자 사용)</p> <br><p id='56' data-category='paragraph' style='font-size:14px'>정답 고인돌 ② 위만<br>3 8조법</p> <br><p id='57' data-category='list' style='font-size:16px'>( )은 제작 과정에서 수<br>많은 인력이 동원되었다.<br>② 기원전 2세기 초 ( )은<br>고조선의 준왕을 몰아내고 왕< ...

# %%
print(pages[1].page_content)
# Out:
# <h1 id='30' style='font-size:16px'>www.ebsi.co.kr</h1> <p id='31' data-category='paragraph' style='font-size:22px'>2. 고조선의 성립과 여러 나라의 성장</p> <br><h1 id='32' style='font-size:20px'>(1) 청동기 시대</h1> <br><p id='33' data-category='paragraph' style='font-size:14px'>▶ 반달 돌칼</p> <table id='34' style='font-size:16px'><thead></thead><tbody><tr><td>도구</td><td>· 청동기 : 비파형 동검, 거친무늬 거울 등 · 간석기 : 반달 돌칼 등의 농기구 · 토기 : 민무늬 토기, 미송리식 토기 등</td></tr><tr><td>경제</td><td>농경과 목축 확대, 일부 저습지에서 벼농사 실시</td></tr><tr><td>사회</td><td>· 사유 재산과 계급 발생, 정복 전쟁의 활발한 전개 · 군장(족장) 출현(제사와 정치 주관, 스스로를 하늘의 자손으로 여김)</td></tr><tr><td>주거</td><td>움집의 지상 가옥화, 들판을 끼고 있는 구릉이나 강가에 취락 형성</td></tr><tr><td>무덤</td><td>고인돌(지배층의 무덤, 탁자식 · 바둑판식), 돌널무덤 등</td></tr></tbody></table> <p id='35' data-category='paragraph' style='font-size:18px'>자료 플러스 고인돌</p> <figure id='36'><img alt="" data-coord="top-left:(135,458); bottom-right:(351,587)" /></figure> <br><figure id='37'><img alt="" data-coord="top-left:(959,168); bottom-right:(1084,210)" /></figure> <p id='38' data-category='paragraph' style='font-size:16px'>▲ 고인돌(인천 강화)</p> <br><p id='39' data-category='paragraph' style='font-size:20px'>고인돌은 청동기 시대의 대표적인 무덤으로 지상 또는 지하에<br>매장 시설을 만들고 지상에는 큰 돌을 윗돌로 놓아 덮개돌로 사<br>용한다. 대형 고인돌은 덮개돌 무게만 수십 톤에 달해 고인돌에<br>묻힌 사람은 수백 명의 인력을 동원할 수 있는 군장(족장)이나<br>그와 비슷한 지위에 있는 사람 또는 그 가족으로 짐작된다. 우<br>리나라의 고인돌은 고창, 화순, 강화 등지에 다수 분포하고 있</p> <br><p id='40' data-category='paragraph' style='font-size:20px'>으며, 2000년에 유네스코 세계 유산으로 등재되어 보존 · 관리되고 있다.</p> <p id='41' data-category='paragraph' style='font-size:20px'>고조선의 건국과 성장</p> <table id='42' style='font-size:16px'><thead></thead><tbody><tr><td>건국</td><td>청동기 문화를 기반으로 건국</td></tr><tr><td>건국 이야기</td><td>· 『삼국유사』, 『제왕운기』, 「동국통감」 등에 실려 있음 · 농경 사회 형성, 계급 발생, 제정일치의 지배자(단군왕검) 출현 등 반영</td></tr><tr><td>발전</td><td>· 기원전 4세기부터 중국의 연과 대립 · 기원전 3세기경 부왕· 준왕 등이 왕위 세습, 상 ·대부·장군 등의 관직 설치</td></tr><tr><td>위만 집권 이후의 변화</td><td>· 중국의 진· 한 교체기에 유이민 무리가 고조선으로 이주 → 위만이 준왕을 몰아내고 왕위 차지(기원전 194) · 철기 문화를 본격적으로 수용 · 한반도 남부의 진과 중국의 한 사이에서 중계 무역 전개</td></tr><tr><td>멸망</td><td>한 무제의 침략으로 멸망(기원전 108) → 한이 일부 지역에 군현 설치</td></tr><tr><td>사회</td><td>8조법 중 3개 조항이 전해짐(생명 · 노동력 중시, 사유 재산 보호, 형벌 · 노비 존재) → 한 군현 설치 후 법률이 60여 조로 증가</td></tr></tbody></table> <br><p id='43' data-category='paragraph' style='font-size:16px'>청동기 시대에 널리 사용된 농<br>기구로, 곡식을 수확할 때 사용<br>하였다. 구멍을 뚫어 끈을 꿰고<br>그 끈을 손에 걸어 사용한 것으<br>로 짐작된다.</p> <p id='44' data-category='paragraph' style='font-size:16px'>� 미송리식 토기</p> <figure id='45'><img alt="" data-coord="top-left:(972,458); bottom-right:(1070,580)" /></figure> <br><p id='46' data-category='paragraph' style='font-size:16px'>평안북도 의주군 미송리의 동굴<br>유적에서 발견되어 붙여진 이름<br>으로 청천강 이북의 평안북도와<br>자강도 및 중국 지린성 일대에<br>서 주로 출토되고 있다. 목이 있<br>고 몸체에 줄무늬가 가로로 둘<br>려 있으며, 몸체의 양쪽에 손잡<br>이가 달린 것이 특징이다.</p> <p id='47' data-category='paragraph' style='font-size:14px'>D 연(燕)</p> <p id='48' data-category='paragraph' style='font-size:18px'>자료 플러스 8조법</p> <br><p id='49' data-category='paragraph' style='font-size:16px'>중국 주나라의 제후국으로 전<br>국 시대에 패권을 다투던 7개<br>나라 중의 하나이다.</p> <p id='50' data-category='paragraph' style='font-size:18px'>사람을 죽인 자는 즉시 죽이고, 남에게 상처를 입힌 자는 곡식으로 갚는다. 도둑질한 자는 노비로 삼는다. 용<br>서받고자 하는 자는 한 사람마다 50만 전을 내게 한다. - 『한서』 -</p> <br><p id='51' data-category='paragraph' style='font-size:22px'>개념 체크</p> <p id='52' data-category='paragraph' style='font-size:20px'>고조선의 8조법 중 현재 전하는 3개 조항이다. 이를 통해 고조선 사회가 계급 사회였으며, 형벌<br>과 노비가 존재하고 노동력과 사유 재산을 보호하였음을 알 수 있다.</p> <p id='53' data-category='paragraph' style='font-size:20px'>(3) 철기 문화의 수용</p> <br><p id='54' data-category='paragraph' style='font-size:16px'>청동기 시대의 대표적 무덤인</p> <p id='55' data-category='list' style='font-size:20px'>① 도구 : 철제 농기구 · 무기 사용 → 농업 생산력 증대, 활발한 정복 활동 전개<br>② 무덤 : 널무덤과 독무덤<br>③ 중국과 교류 : 명도전, 반량전 등 중국 화폐 출토, 붓 발견(한자 사용)</p> <br><p id='56' data-category='paragraph' style='font-size:14px'>정답 고인돌 ② 위만<br>3 8조법</p> <br><p id='57' data-category='list' style='font-size:16px'>( )은 제작 과정에서 수<br>많은 인력이 동원되었다.<br>② 기원전 2세기 초 ( )은<br>고조선의 준왕을 몰아내고 왕<br>이 되었다.<br>③ ...

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

chat = ChatOpenAI(model='gpt-4o')
prompt = ChatPromptTemplate.from_messages(
    [
        (
            'system',
            '''You are an advanced question generator designed to create meaningful and contextually relevant questions from provided text.
            Use the given text to generate thought-provoking or comprehension-based questions IN KOREAN.
            Do not include answers.
            \n\n
            {context}''',
        )
    ]
)

chain = prompt | chat

# %%
file_path = '(교사용)2022학년도_수능특강_한국사_본문_slice.pdf'
loader = UpstageDocumentParseLoader(file_path, split='page')

pages = loader.load()
pdf_context = ''
for page in pages:
    print(page)
    pdf_context += page.page_content
# Out:
# page_content='<h1 id='0' style='font-size:18px'>한국사</h1> <br><h1 id='1' style='font-size:22px'>01</h1> <br><h1 id='2' style='font-size:22px'>선사 문화와 여러 나라의 성장</h1> <h1 id='3' style='font-size:16px'>슴베찌르개</h1> <br><p id='4' data-category='paragraph' style='font-size:20px'>1. 선사 문화의 전개</p> <figure id='5'><img alt="" data-coord="top-left:(173,237); bottom-right:(223,332)" /></figure> <br><p id='6' data-category='paragraph' style='font-size:20px'>(1) 우리 민족의 형성 : 만주와 한반도를 중심으로 동북아시아에 분포, 신석기 시대~청동기 시대에<br>걸쳐 민족의 기틀 형성</p> <br><p id='7' data-category='paragraph' style='font-size:16px'>←슴베</p> <p id='8' data-category='paragraph' style='font-size:16px'>돌날의 양쪽 끝을 뾰족하게 만<br>들어 한쪽 끝을 나무에 박아 만<br>든 석기이다. 슴베찌르개는 자<br>루를 달아 창처럼 만들어 사냥<br>도구 등으로 사용되었다.</p> <br><p id='9' data-category='paragraph' style='font-size:20px'>(2) 구석기 시대</p> <table id='10' style='font-size:16px'><thead></thead><tbody><tr><td>주요 유적</td><td>경기 연천 전곡리, 충남 공주 석장리 등</td></tr><tr><td>도구</td><td>· 뗀석기 사용 : 사냥 도구(주먹도끼, 찍개 등), 조리 도구(긁개, 밀개 등) · 구석기 시대 후기에 슴베찌르개 사용</td></tr><tr><td>주거</td><td>동굴, 바위 그늘, 강가의 막집에서 생활</td></tr><tr><td>사회</td><td>· 무리 지어 이동 생활, 사냥 · 채집으로 식량 마련 · 지배와 피지배 관계가 발생하지 않은 평등한 공동체 사회(경험이 많거나 나이가 많은 사람이 지도자 역할)</td></tr></tbody></table> <p id='11' data-category='paragraph' style='font-size:18px'>자료 플러스 주먹도끼</p> <p id='12' data-category='paragraph' style='font-size:16px'>농경의 시작</p> <br><p id='13' data-category='paragraph' style='font-size:16px'>인류가 채집 경제에서 벗어나<br>직접 식량을 생산하고 정착 생<br>활을 하는 등 역사 발전에서 큰<br>계기가 되었다. 이를 신석기 혁<br>명이라고 부르기도 한다.</p> <br><figure id='14'><img alt="" data-coord="top-left:(340,615); bottom-right:(414,724)" /></figure> <br><p id='15' data-category='paragraph' style='font-size:20px'>1978년 경기 연천 전곡리에서 주먹도끼가 처음 발견되었다. 주먹도끼는 사용할 때<br>손에 쥐고 사용하기 때문에 붙여진 이름이다. 주먹도끼는 짐승을 사냥하는 데는 물론<br>사냥한 짐승의 가죽을 벗기고, 땅을 파서 풀이나 나무뿌리를 캐는 등 여러 가지 용도<br>로 사용되었다.</p> <br><p id='16' data-category='paragraph' style='font-size:14px'>▲ 주먹도끼</p> <p id='17' data-category='paragraph' style='font-size:20px'>(3) 신석기 시대</p> <br><p id='18' data-category='list' style='font-size:20px'>① 주요 유적 : 대체로 강가나 바닷가에 분포(서울 암사동 등)<br>② 도구</p> <br><p id='19' data-category='paragraph' style='font-size:18px'>· 간석기 : 농경용 도구(돌괭이, 돌보습, 돌낫 등)와 조리용 도구(갈돌, 갈판 등) 제작</p> <h1 id='20' style='font-size:20px'>개념 체크</h1> <br><p id='21' data-category='list' style='font-size:18px'>· 토기 : 빗살무늬 토기가 대표적 → 음식물의 저장과 조리에 사용<br>· 가락바퀴, 뼈바늘 : 옷과 그물을 제작하는 등 원시적 수공업에 사용<br>③ 경제 : 농경(잡곡류 경작)과 목축 시작, 여전히 고기잡이와 사냥 · 채집을 통해 식량 확보<br>④ 주거 : 움집에서 생활(정착 생활)<br>⑤ 사회 : 다른 씨족과의 혼인(족외혼)을 통해 부족 사회 형성, 평등 사회<br>⑥ 신앙 : 농경이 시작되고 정착 생활이 이루어지면서 자연의 섭리 인식 → 애니미즘(정령 숭배),<br>토테미즘(동식물 숭배), 샤머니즘(무당과 주술을 믿음) 등 출현<br>⑦ 예술 : 조개껍데기 가면과 치레걸이 등 제작</p> <br><p id='22' data-category='list' style='font-size:16px'>구석기 시대 사람들은 돌을<br>깨뜨려 주먹도끼, 찍개 등<br>의 ( )를 만들어 사용하<br>였다.<br>2 신석기 시대 사람들은 강가나<br>바닷가에 ( )을 짓고 마<br>을을 이루며 정착 생활을 하<br>였다.<br>3 신석기 시대에는 뼈바늘과 실<br>을 뽑는 도구인 ( )를 이<br>용하여 옷이나 그물을 만들<br>었다.</p> <br><p id='23' data-category='paragraph' style='font-size:18px'>자료 플러스 갈돌과 갈판</p> <figure id='24'><img alt="" data-coord="top-left:(340,1224); bottom-right:(491,1350)" /></figure> <p id='25' data-category='paragraph' style='font-size:14px'>정답 1 뗀석기 움집</p> <br><p id='26' data-category='paragraph' style='font-size:16px'>가락바퀴</p> <br><p id='27' data-category='paragraph' style='font-size:14px'>▲</p> <br><table id='28' style='font-size:20px'><thead></thead><tbody><tr><td></td><td>갈돌과 갈판은 신석기 시대부터 사용된 간석기이다. 신석기 시대부터 농경 이 시작되었지만 그 비중이 크지 않아 여전히 사냥과 채집을 중심으로 생활 이 이루어졌다. 신석기인들은 갈돌과 갈판을 이용하여 자연에서 채집한 도 토리나 조, 기장 등 곡물의 껍질을 까거나 알맹이를 갈아서 가루로 만들었</td></tr><tr><td>갈돌과 갈판</td><td>을 것이다. 갈돌과 갈판은 농경이 본격적으로 이루어진 청동기 시대에도 계 속 사용되었다.</td></tr></tbody></table> <footer id='29' style='font-size:16px'>8 EBS 수능특강 한국사_ I 우리 역사의 형성과 고대 국가의 발전</footer>' metadata={'page': 1, 'coordinates': [[{'x': 0.0976, 'y': 0.0395}, {'x': 0.135, 'y': 0.0395}, {'x': 0.135, 'y': 0.0531}, {'x': 0.0976, 'y': 0.0531}], [{'x': 0.1487, 'y': 0.0378}, {'x': 0.2123, 'y': 0.0378}, {'x': 0.2123, 'y': 0.0 ...
# page_content='<h1 id='30' style='font-size:16px'>www.ebsi.co.kr</h1> <p id='31' data-category='paragraph' style='font-size:22px'>2. 고조선의 성립과 여러 나라의 성장</p> <br><h1 id='32' style='font-size:20px'>(1) 청동기 시대</h1> <br><p id='33' data-category='paragraph' style='font-size:14px'>▶ 반달 돌칼</p> <table id='34' style='font-size:16px'><thead></thead><tbody><tr><td>도구</td><td>· 청동기 : 비파형 동검, 거친무늬 거울 등 · 간석기 : 반달 돌칼 등의 농기구 · 토기 : 민무늬 토기, 미송리식 토기 등</td></tr><tr><td>경제</td><td>농경과 목축 확대, 일부 저습지에서 벼농사 실시</td></tr><tr><td>사회</td><td>· 사유 재산과 계급 발생, 정복 전쟁의 활발한 전개 · 군장(족장) 출현(제사와 정치 주관, 스스로를 하늘의 자손으로 여김)</td></tr><tr><td>주거</td><td>움집의 지상 가옥화, 들판을 끼고 있는 구릉이나 강가에 취락 형성</td></tr><tr><td>무덤</td><td>고인돌(지배층의 무덤, 탁자식 · 바둑판식), 돌널무덤 등</td></tr></tbody></table> <p id='35' data-category='paragraph' style='font-size:18px'>자료 플러스 고인돌</p> <figure id='36'><img alt="" data-coord="top-left:(135,458); bottom-right:(351,587)" /></figure> <br><figure id='37'><img alt="" data-coord="top-left:(959,168); bottom-right:(1084,210)" /></figure> <p id='38' data-category='paragraph' style='font-size:16px'>▲ 고인돌(인천 강화)</p> <br><p id='39' data-category='paragraph' style='font-size:20px'>고인돌은 청동기 시대의 대표적인 무덤으로 지상 또는 지하에<br>매장 시설을 만들고 지상에는 큰 돌을 윗돌로 놓아 덮개돌로 사<br>용한다. 대형 고인돌은 덮개돌 무게만 수십 톤에 달해 고인돌에<br>묻힌 사람은 수백 명의 인력을 동원할 수 있는 군장(족장)이나<br>그와 비슷한 지위에 있는 사람 또는 그 가족으로 짐작된다. 우<br>리나라의 고인돌은 고창, 화순, 강화 등지에 다수 분포하고 있</p> <br><p id='40' data-category='paragraph' style='font-size:20px'>으며, 2000년에 유네스코 세계 유산으로 등재되어 보존 · 관리되고 있다.</p> <p id='41' data-category='paragraph' style='font-size:20px'>고조선의 건국과 성장</p> <table id='42' style='font-size:16px'><thead></thead><tbody><tr><td>건국</td><td>청동기 문화를 기반으로 건국</td></tr><tr><td>건국 이야기</td><td>· 『삼국유사』, 『제왕운기』, 「동국통감」 등에 실려 있음 · 농경 사회 형성, 계급 발생, 제정일치의 지배자(단군왕검) 출현 등 반영</td></tr><tr><td>발전</td><td>· 기원전 4세기부터 중국의 연과 대립 · 기원전 3세기경 부왕· 준왕 등이 왕위 세습, 상 ·대부·장군 등의 관직 설치</td></tr><tr><td>위만 집권 이후의 변화</td><td>· 중국의 진· 한 교체기에 유이민 무리가 고조선으로 이주 → 위만이 준왕을 몰아내고 왕위 차지(기원전 194) · 철기 문화를 본격적으로 수용 · 한반도 남부의 진과 중국의 한 사이에서 중계 무역 전개</td></tr><tr><td>멸망</td><td>한 무제의 침략으로 멸망(기원전 108) → 한이 일부 지역에 군현 설치</td></tr><tr><td>사회</td><td>8조법 중 3개 조항이 전해짐(생명 · 노동력 중시, 사유 재산 보호, 형벌 · 노비 존재) → 한 군현 설치 후 법률이 60여 조로 증가</td></tr></tbody></table> <br><p id='43' data-category='paragraph' style='font-size:16px'>청동기 시대에 널리 사용된 농<br>기구로, 곡식을 수확할 때 사용<br>하였다. 구멍을 뚫어 끈을 꿰고<br>그 끈을 손에 걸어 사용한 것으<br>로 짐작된다.</p> <p id='44' data-category='paragraph' style='font-size:16px'>� 미송리식 토기</p> <figure id='45'><img alt="" data-coord="top-left:(972,458); bottom-right:(1070,580)" /></figure> <p id='46' data-category='paragraph' style='font-size:18px'>자료 플러스 8조법</p> <br><p id='47' data-category='paragraph' style='font-size:16px'>평안북도 의주군 미송리의 동굴<br>유적에서 발견되어 붙여진 이름<br>으로 청천강 이북의 평안북도와<br>자강도 및 중국 지린성 일대에<br>서 주로 출토되고 있다. 목이 있<br>고 몸체에 줄무늬가 가로로 둘<br>려 있으며, 몸체의 양쪽에 손잡<br>이가 달린 것이 특징이다.</p> <p id='48' data-category='paragraph' style='font-size:18px'>사람을 죽인 자는 즉시 죽이고, 남에게 상처를 입힌 자는 곡식으로 갚는다. 도둑질한 자는 노비로 삼는다. 용<br>서받고자 하는 자는 한 사람마다 50만 전을 내게 한다. - 『한서』 -</p> <br><p id='49' data-category='paragraph' style='font-size:14px'>D 연(燕)</p> <br><p id='50' data-category='paragraph' style='font-size:16px'>중국 주나라의 제후국으로 전<br>국 시대에 패권을 다투던 7개<br>나라 중의 하나이다.</p> <p id='51' data-category='paragraph' style='font-size:20px'>고조선의 8조법 중 현재 전하는 3개 조항이다. 이를 통해 고조선 사회가 계급 사회였으며, 형벌<br>과 노비가 존재하고 노동력과 사유 재산을 보호하였음을 알 수 있다.</p> <br><p id='52' data-category='paragraph' style='font-size:22px'>개념 체크</p> <p id='53' data-category='paragraph' style='font-size:20px'>(3) 철기 문화의 수용</p> <br><p id='54' data-category='paragraph' style='font-size:16px'>청동기 시대의 대표적 무덤인</p> <p id='55' data-category='list' style='font-size:20px'>① 도구 : 철제 농기구 · 무기 사용 → 농업 생산력 증대, 활발한 정복 활동 전개<br>② 무덤 : 널무덤과 독무덤<br>③ 중국과 교류 : 명도전, 반량전 등 중국 화폐 출토, 붓 발견(한자 사용)</p> <br><p id='56' data-category='paragraph' style='font-size:14px'>정답 고인돌 ② 위만<br>3 8조법</p> <br><p id='57' data-category='list' style='font-size:16px'>( )은 제작 과정에서 수<br>많은 인력이 동원되었다.<br>② 기원전 2세기 초 ( )은<br>고조선의 준왕을 몰아내 ...

# %%
pdf_context
# Out:
# '<h1 id=\'0\' style=\'font-size:18px\'>한국사</h1> <br><h1 id=\'1\' style=\'font-size:22px\'>01</h1> <br><h1 id=\'2\' style=\'font-size:22px\'>선사 문화와 여러 나라의 성장</h1> <h1 id=\'3\' style=\'font-size:16px\'>슴베찌르개</h1> <br><p id=\'4\' data-category=\'paragraph\' style=\'font-size:20px\'>1. 선사 문화의 전개</p> <figure id=\'5\'><img alt="" data-coord="top-left:(173,237); bottom-right:(223,332)" /></figure> <br><p id=\'6\' data-category=\'paragraph\' style=\'font-size:20px\'>(1) 우리 민족의 형성 : 만주와 한반도를 중심으로 동북아시아에 분포, 신석기 시대~청동기 시대에<br>걸쳐 민족의 기틀 형성</p> <br><p id=\'7\' data-category=\'paragraph\' style=\'font-size:16px\'>←슴베</p> <p id=\'8\' data-category=\'paragraph\' style=\'font-size:16px\'>돌날의 양쪽 끝을 뾰족하게 만<br>들어 한쪽 끝을 나무에 박아 만<br>든 석기이다. 슴베찌르개는 자<br>루를 달아 창처럼 만들어 사냥<br>도구 등으로 사용되었다.</p> <br><p id=\'9\' data-category=\'paragraph\' style=\'font-size:20px\'>(2) 구석기 시대</p> <table id=\'10\' style=\'font-size:16px\'><thead></thead><tbody><tr><td>주요 유적</td><td>경기 연천 전곡리, 충남 공주 석장리 등</td></tr><tr><td>도구</td><td>· 뗀석기 사용 : 사냥 도구(주먹도끼, 찍개 등), 조리 도구(긁개, 밀개 등) · 구석기 시대 후기에 슴베찌르개 사용</td></tr><tr><td>주거</td><td>동굴, 바위 그늘, 강가의 막집에서 생활</td></tr><tr><td>사회</td><td>· 무리 지어 이동 생활, 사냥 · 채집으로 식량 마련 · 지배와 피지배 관계가 발생하지 않은 평등한 공동체 사회(경험이 많거나 나이가 많은 사람이 지도자 역할)</td></tr></tbody></table> <p id=\'11\' data-category=\'paragraph\' style=\'font-size:18px\'>자료 플러스 주먹도끼</p> <p id=\'12\' data-category=\'paragraph\' style=\'font-size:16px\'>농경의 시작</p> <br><p id=\'13\' data-category=\'paragraph\' style=\'font-size:16px\'>인류가 채집 경제에서 벗어나<br>직접 식량을 생산하고 정착 생<br>활을 하는 등 역사 발전에서 큰<br>계기가 되었다. 이를 신석기 혁<br>명이라고 부르기도 한다.</p> <br><figure id=\'14\'><img alt="" data-coord="top-left:(340,615); bottom-right:(414,724)" /></figure> <br><p id=\'15\' data-category=\'paragraph\' style=\'font-size:20px\'>1978년 경기 연천 전곡리에서 주먹도끼가 처음 발견되었다. 주먹도끼는 사용할 때<br>손에 쥐고 사용하기 때문에 붙여진 이름이다. 주먹도끼는 짐승을 사냥하는 데는 물론<br>사냥한 짐승의 가죽을 벗기고, 땅을 파서 풀이나 나무뿌리를 캐는 등 여러 가지 용도<br>로 사용되었다.</p> <br><p id=\'16\' data-category=\'paragraph\' style=\'font-size:14px\'>▲ 주먹도끼</p> <p id=\'17\' data-category=\'paragraph\' style=\'font-size:20px\'>(3) 신석기 시대</p> <br><p id=\'18\' data-category=\'list\' style=\'font-size:20px\'>① 주요 유적 : 대체로 강가나 바닷가에 분포(서울 암사동 등)<br>② 도구</p> <br><p id=\'19\' data-category=\'paragraph\' style=\'font-size:18px\'>· 간석기 : 농경용 도구(돌괭이, 돌보습, 돌낫 등)와 조리용 도구(갈돌, 갈판 등) 제작</p> <h1 id=\'20\' style=\'font-size:20px\'>개념 체크</h1> <br><p id=\'21\' data-category=\'list\' style=\'font-size:18px\'>· 토기 : 빗살무늬 토기가 대표적 → 음식물의 저장과 조리에 사용<br>· 가락바퀴, 뼈바늘 : 옷과 그물을 제작하는 등 원시적 수공업에 사용<br>③ 경제 : 농경(잡곡류 경작)과 목축 시작, 여전히 고기잡이와 사냥 · 채집을 통해 식량 확보<br>④ 주거 : 움집에서 생활(정착 생활)<br>⑤ 사회 : 다른 씨족과의 혼인(족외혼)을 통해 부족 사회 형성, 평등 사회<br>⑥ 신앙 : 농경이 시작되고 정착 생활이 이루어지면서 자연의 섭리 인식 → 애니미즘(정령 숭배),<br>토테미즘(동식물 숭배), 샤머니즘(무당과 주술을 믿음) 등 출현<br>⑦ 예술 : 조개껍데기 가면과 치레걸이 등 제작</p> <br><p id=\'22\' data-category=\'list\' style=\'font-size:16px\'>구석기 시대 사람들은 돌을<br>깨뜨려 주먹도끼, 찍개 등<br>의 ( )를 만들어 사용하<br>였다.<br>2 신석기 시대 사람들은 강가나<br>바닷가에 ( )을 짓고 마<br>을을 이루며 정착 생활을 하<br>였다.<br>3 신석기 시대에는 뼈바늘과 실<br>을 뽑는 도구인 ( )를 이<br>용하여 옷이나 그물을 만들<br>었다.</p> <br><p id=\'23\' data-category=\'paragraph\' style=\'font-size:18px\'>자료 플러스 갈돌과 갈판</p> <figure id=\'24\'><img alt="" data-coord="top-left:(340,1224); bottom-right:(491,1350)" /></figure> <p id=\'25\' data-category=\'paragraph\' style=\'font-size:14px\'>정답 1 뗀석기 움집</p> <br><p id=\'26\' data-category=\'paragraph\' style=\'font-size:16px\'>가락바퀴</p> <br><p id=\'27\' data-category=\'paragraph\' style=\'font-size:14px\'>▲</p> <br><table id=\'28\' style=\'font-size:20px\'><thead></thead><tbody><tr><td></td><td>갈돌과 갈판은 신석기 시대부터 사용된 간석기이다. 신석기 시대부터 농경 이 시작되었지만 그 비중이 크지 않아 여전히 사냥과 채집을 중심으로 생활 이 이루어졌다. 신석기인들은 갈돌과 갈판을 이용하여 자연에서 채집한 도 토리나 조, 기장 등 곡물의 껍질을 까거나 알맹이를 갈아서 가루로 만들었</td></tr><tr><td>갈돌과 갈판</td><td>을 것이다. 갈돌과 갈판은 농경이 본격적으로 이루어진 청동기 시대에도 계 속 사용되었다.</td></tr></tbody></table> <footer id=\'29\' style=\'font-size:16px\'>8 EBS 수능특강 한국사_ I 우리 역사의 형성과 고대 국가의 발전</footer><h1 id=\'30\' style=\'font-size:16px\'>www.ebsi.co.kr</h1> <p id=\'31\' data-category=\'par ...

# %%
response = chain.invoke({'context': pdf_context})

# %%
print(response.content)
# Out:
# 1. 신석기 시대에 농경 혁명이 중요한 이유는 무엇인가요?
#
# 2. 구석기 시대와 신석기 시대의 주요 도구의 차이점은 무엇인가요?
#
# 3. 청동기 시대에 고인돌이 중요한 이유는 무엇인가요?
#
# 4. 고조선의 8조법을 통해 알 수 있는 당시 사회의 특징은 무엇인가요?
#
# 5. 철기 문화의 수용이 한반도에 미친 영향은 무엇인가요?
#
# 6. 고조선의 건국 이야기에는 어떤 사회적 변화가 반영되어 있나요?
#
# 7. 고조선이 멸망한 이유와 그 결과는 무엇인가요?
#
# 8. 구석기 시대와 신석기 시대의 주거 형태의 차이점은 무엇인가요?
#
# 9. 위만이 고조선에서 왕위에 오른 과정은 어떻게 이루어졌나요?
#
# 10. 고조선 사회에서의 계급 발생과 관련된 증거는 무엇인가요?

# %%
import gradio as gr
from gradio.themes.base import Base
from gradio_pdf import PDF

import os
from langchain_upstage import UpstageDocumentParseLoader
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory

class Seafoam(Base):
    pass
seafoam = Seafoam()

chat_history_for_chain = ChatMessageHistory()
chat = ChatOpenAI(model='gpt-4o')

with gr.Blocks(theme=seafoam) as demo:
    def question_generator(pdf, chatbot_history):
        loader = UpstageDocumentParseLoader(pdf, split='page')

        pages = loader.load()
        pdf_context = ''
        for page in pages:
            pdf_context += page.page_content

        prompt_text = f'''
            You are an advanced question generator designed to create a meaningful and contextually relevant question from provided text.
            Use the given text to generate a thought-provoking or comprehension-based question IN KOREAN.
            Do not include answers.
            {pdf_context}'''
        
        chat_history_for_chain.add_ai_message(prompt_text)

        chatbot_history.append(('', chat.invoke(prompt_text).content))

        return chatbot_history
    
    def response(message, chatbot_history):
        prompt = ChatPromptTemplate.from_messages(
            [
                (
                    'system',
                    '''
                    If user answered correctly, please give the next question.
                    If user did not answer or got it wrong, kindly explain it based on the text provided.
                    YOU MUST ANSWER IN KOREAN.
                    '''
                ),
                ('placeholder', '{chat_history}'),
                ('human', '{input}')
            ]
        )
        chain = prompt | chat

        chain_with_message_history = RunnableWithMessageHistory(
            chain,
            lambda session_id: chat_history_for_chain,
            input_messages_key='input',
            history_messages_key='chat_history'
        )

        response = chain_with_message_history.invoke(
            {'input': message},
            {'configurable': {'session_id': '123'}},
        )

        chatbot_history.append((message, response.content))
        return chatbot_history
    
    with gr.Row():
        with gr.Column(scale=4):
            gr.HTML('''<div style='text-align: center; max-width:1000px; margin: 10px auto;'>
                        <div>
                            <h1>📖 PDF로 AI와 공부하기 📖</h1>
                        </div>
                        <p style='margin-bottom: 10px; font-size: 95%'>
                            💭 학습자료 PDF를 업로드 해보세요. AI가 자료에서 질문을 만들어 줄거예요. 대화를 주고 받아 보세요. </a>
                        </p>
                    </div>
                    ''')
    
    with gr.Row():
        with gr.Column(scale=1):
            pdf = PDF(label='Upload a PDF', interactive=True)
            name = gr.Textbox(label='PDF 파일명')
            pdf.upload(lambda f: f, pdf, name)
            btn = gr.Button('PDF 제출', variant='primary')
        
        with gr.Column(scale=3):
            chatbot = gr.Chatbot()

            btn.click(question_generator, [pdf, chatbot], [chatbot])
            
            msg = gr.Textbox(placeholder='AI가 출제한 문제에 답을 하거나 질문을 해보세요.', label='입력')

            with gr.Row():
                gr.HTML('''<div style='text-align: center; max-width: 500px; margin: 0px auto;'>
                        <div>
                            <h1>    </h1>
                        </p>
                    </div>''')
                gr.HTML('''<div style='text-align: center; max-width: 500px; margin: 0px auto;'>
                        <div>
                            <h1>     </h1>
                        </p>
                    </div>''')
                btn = gr.Button('Submit', variant='primary')
                clear = gr.Button('Clear')
        
        btn.click(fn=response, inputs=[msg, chatbot], outputs=[chatbot])
        msg.submit(response, [msg, chatbot], [chatbot])

        clear.click(lambda: None, None, msg, queue=False)
    
    demo.launch(debug=True, share=True)
# Out:
# <ipython-input-3-5638c8db328e>:92: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot()
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://99c04264f57cbcaaa1.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://99c04264f57cbcaaa1.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://99c04264f57cbcaaa1.gradio.live
